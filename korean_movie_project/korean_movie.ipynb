# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Nov 19 17:50:38 2018

@author: ohmgs
"""

from bs4 import BeautifulSoup
import requests
import time
import json

def get_soup_of_page(page_num):
    url = "https://movie.naver.com/movie/point/af/list.nhn?target=after&page=%d"
    return BeautifulSoup(requests.get(url % page_num).text, features='lxml')

# %%
def get_parsed_data_of_page(page_num):
    soup = get_soup_of_page(page_num)
    ids = [int(x.text) for x in soup.select('.ac.num')]
    ratings = [int(x.text) for x in soup.select('.point')]
    div_titles = soup.select('.title')
    titles = []
    reviews = []
    for div_title in div_titles:
        elems = [elem for elem in list(div_title.children) if elem != '\n']
        try:
            titles.append(elems[0].text.strip())
        except Exception:
            print("exception found: maybe title is empty?")
            titles.append('')
        try:    
            reviews.append(elems[2].strip())
        except Exception:
            print("exception found: maybe review is empty?")
            reviews.append('')
        
    naver_movie_reviews = {}
    for rating_id, rating, title, review in zip(ids, ratings, titles, reviews):
        naver_movie_reviews[rating_id] = {
                "rating": rating,
                "title": title,
                "review": review
            }
    
    return naver_movie_reviews

# %%
def collect_reviews(num_review):
    merged_data = {}
    collision_count = 0
    for page_num in range(1, 100000):
        try:
            parsed_data = get_parsed_data_of_page(page_num)
            for rating_id, review_data in parsed_data.items():
                if rating_id in merged_data:
                    collision_count += 1
                    print('{cnt}-th collision detected!'.format(cnt=collision_count))
                merged_data[rating_id] = review_data
            
            print("{i}-th crawl: {length} data entries are collected".format(i=page_num, length=len(merged_data)))
        except Exception as e:
            print("{i}-th crawl is skipped due to an exception: {error}".format(i=page_num, error=e))
        if len(merged_data) >= num_review:
            break
        time.sleep(5)
    return merged_data

num_review = int(input("enter the number of reviews you want to collect: "))
collected = collect_reviews(num_review)

with open("collected_movie_reviews.txt", "w") as f:
    f.write(json.dumps(collected, indent=4))
# Out:
# enter the number of reviews you want to collect: 9220
# 1-th crawl: 10 data entries are collected
# 1-th collision detected!
# 2-th crawl: 19 data entries are collected
# 2-th collision detected!
# 3-th crawl: 28 data entries are collected
# 3-th collision detected!
# 4-th crawl: 37 data entries are collected
# 4-th collision detected!
# 5-th crawl: 46 data entries are collected
# 6-th crawl: 56 data entries are collected
# 7-th crawl: 66 data entries are collected
# 5-th collision detected!
# 8-th crawl: 75 data entries are collected
# 6-th collision detected!
# 9-th crawl: 84 data entries are collected
# 10-th crawl: 94 data entries are collected
# 7-th collision detected!
# 11-th crawl: 103 data entries are collected
# 12-th crawl: 113 data entries are collected
# 8-th collision detected!
# 13-th crawl: 122 data entries are collected
# 9-th collision detected!
# 14-th crawl: 131 data entries are collected
# 10-th collision detected!
# 15-th crawl: 140 data entries are collected
# 16-th crawl: 150 data entries are collected
# 11-th collision detected!
# 17-th crawl: 159 data entries are collected
# 12-th collision detected!
# 13-th collision detected!
# 18-th crawl: 167 data entries are collected
# 14-th collision detected!
# 19-th crawl: 176 data entries are collected
# 15-th collision detected!
# 20-th crawl: 185 data entries are collected
# 21-th crawl: 195 data entries are collected
# 22-th crawl: 205 data entries are collected
# 23-th crawl: 215 data entries are collected
# 24-th crawl: 225 data entries are collected
# 25-th crawl: 235 data entries are collected
# 26-th crawl: 245 data entries are collected
# 16-th collision detected!
# 27-th crawl: 254 data entries are collected
# 28-th crawl: 264 data entries are collected
# 29-th crawl: 274 data entries are collected
# 30-th crawl: 284 data entries are collected
# 17-th collision detected!
# 31-th crawl: 293 data entries are collected
# 32-th crawl: 303 data entries are collected
# 33-th crawl: 313 data entries are collected
# 34-th crawl: 323 data entries are collected
# 35-th crawl: 333 data entries are collected
# 36-th crawl: 343 data entries are collected
# 37-th crawl: 353 data entries are collected
# 18-th collision detected!
# 19-th collision detected!
# 20-th collision detected!
# 38-th crawl: 360 data entries are collected
# 21-th collision detected!
# 22-th collision detected!
# 39-th crawl: 368 data entries are collected
# 40-th crawl: 378 data entries are collected
# 41-th crawl: 388 data entries are collected
# 42-th crawl: 398 data entries are collected
# 23-th collision detected!
# 43-th crawl: 407 data entries are collected
# 44-th crawl: 417 data entries are collected
# 24-th collision detected!
# 45-th crawl: 426 data entries are collected
# 25-th collision detected!
# 46-th crawl: 435 data entries are collected
# 47-th crawl: 445 data entries are collected
# 48-th crawl: 455 data entries are collected
# 49-th crawl: 465 data entries are collected
# 50-th crawl: 475 data entries are collected
# 51-th crawl: 485 data entries are collected
# 52-th crawl: 495 data entries are collected
# 53-th crawl: 505 data entries are collected
# 54-th crawl: 515 data entries are collected
# 26-th collision detected!
# 27-th collision detected!
# 55-th crawl: 523 data entries are collected
# 28-th collision detected!
# 29-th collision detected!
# 56-th crawl: 531 data entries are collected
# 30-th collision detected!
# 57-th crawl: 540 data entries are collected
# 31-th collision detected!
# 58-th crawl: 549 data entries are collected
# 59-th crawl: 559 data entries are collected
# 60-th crawl: 569 data entries are collected
# 61-th crawl: 579 data entries are collected
# 62-th crawl: 589 data entries are collected
# 63-th crawl: 599 data entries are collected
# 64-th crawl: 609 data entries are collected
# 32-th collision detected!
# 65-th crawl: 618 data entries are collected
# 66-th crawl: 628 data entries are collected
# 33-th collision detected!
# 34-th collision detected!
# 35-th collision detected!
# 67-th crawl: 635 data entries are collected
# 68-th crawl: 645 data entries are collected
# 69-th crawl: 655 data entries are collected
# 70-th crawl: 665 data entries are collected
# 71-th crawl: 675 data entries are collected
# 72-th crawl: 685 data entries are collected
# 36-th collision detected!
# 73-th crawl: 694 data entries are collected
# 74-th crawl: 704 data entries are collected
# 75-th crawl: 714 data entries are collected
# 76-th crawl: 724 data entries are collected
# 77-th crawl: 734 data entries are collected
# 78-th crawl: 744 data entries are collected
# 79-th crawl: 754 data entries are collected
# 37-th collision detected!
# 80-th crawl: 763 data entries are collected
# 81-th crawl: 773 data entries are collected
# 82-th crawl: 783 data entries are collected
# 38-th collision detected!
# 39-th collision detected!
# 83-th crawl: 791 data entries are collected
# 84-th crawl: 801 data entries are collected
# 85-th crawl: 811 data entries are collected
# 86-th crawl: 821 data entries are collected
# 87-th crawl: 831 data entries are collected
# 40-th collision detected!
# 41-th collision detected!
# 88-th crawl: 839 data entries are collected
# 89-th crawl: 849 data entries are collected
# 90-th crawl: 859 data entries are collected
# 91-th crawl: 869 data entries are collected
# 92-th crawl: 879 data entries are collected
# 42-th collision detected!
# 93-th crawl: 888 data entries are collected
# 43-th collision detected!
# 94-th crawl: 897 data entries are collected
# 95-th crawl: 907 data entries are collected
# 96-th crawl: 917 data entries are collected
# 97-th crawl: 927 data entries are collected
# 98-th crawl: 937 data entries are collected
# 99-th crawl: 947 data entries are collected
# 44-th collision detected!
# 100-th crawl: 956 data entries are collected
# 101-th crawl: 966 data entries are collected
# 45-th collision detected!
# 102-th crawl: 975 data entries are collected
# 103-th crawl: 985 data entries are collected
# 104-th crawl: 995 data entries are collected
# 105-th crawl: 1005 data entries are collected
# 106-th crawl: 1015 data entries are collected
# 107-th crawl: 1025 data entries are collected
# 108-th crawl: 1035 data entries are collected
# 46-th collision detected!
# 109-th crawl: 1044 data entries are collected
# 110-th crawl: 1054 data entries are collected
# 111-th crawl: 1064 data entries are collected
# 47-th collision detected!
# 112-th crawl: 1073 data entries are collected
# 113-th crawl: 1083 data entries are collected
# 114-th crawl: 1093 data entries are collected
# 115-th crawl: 1103 data entries are collected
# 116-th crawl: 1113 data entries are collected
# 117-th crawl: 1123 data entries are collected
# 118-th crawl: 1133 data entries are collected
# 119-th crawl: 1143 data entries are collected
# 48-th collision detected!
# 49-th collision detected!
# 120-th crawl: 1151 data entries are collected
# 50-th collision detected!
# 121-th crawl: 1160 data entries are collected
# 122-th crawl: 1170 data entries are collected
# 123-th crawl: 1180 data entries are collected
# 124-th crawl: 1190 data entries are collected
# 51-th collision detected!
# 125-th crawl: 1199 data entries are collected
# 126-th crawl: 1209 data entries are collected
# 127-th crawl: 1219 data entries are collected
# 52-th collision detected!
# 128-th crawl: 1228 data entries are collected
# 53-th collision detected!
# 129-th crawl: 1237 data entries are collected
# 130-th crawl: 1247 data entries are collected
# 131-th crawl: 1257 data entries are collected
# 132-th crawl: 1267 data entries are collected
# 133-th crawl: 1277 data entries are collected
# 134-th crawl: 1287 data entries are collected
# 135-th crawl: 1297 data entries are collected
# 136-th crawl: 1307 data entries are collected
# 137-th crawl: 1317 data entries are collected
# 138-th crawl: 1327 data entries are collected
# 54-th collision detected!
# 55-th collision detected!
# 139-th crawl: 1335 data entries are collected
# 140-th crawl: 1345 data entries are collected
# 141-th crawl: 1355 data entries are collected
# 56-th collision detected!
# 142-th crawl: 1364 data entries are collected
# 143-th crawl: 1374 data entries are collected
# 144-th crawl: 1384 data entries are collected
# 145-th crawl: 1394 data entries are collected
# 146-th crawl: 1404 data entries are collected
# 147-th crawl: 1414 data entries are collected
# 57-th collision detected!
# 148-th crawl: 1423 data entries are collected
# 149-th crawl: 1433 data entries are collected
# 150-th crawl: 1443 data entries are collected
# 151-th crawl: 1453 data entries are collected
# 152-th crawl: 1463 data entries are collected
# 153-th crawl: 1473 data entries are collected
# 58-th collision detected!
# 154-th crawl: 1482 data entries are collected
# 155-th crawl: 1492 data entries are collected
# 156-th crawl: 1502 data entries are collected
# 59-th collision detected!
# 157-th crawl: 1511 data entries are collected
# 158-th crawl: 1521 data entries are collected
# 159-th crawl: 1531 data entries are collected
# 160-th crawl: 1541 data entries are collected
# 161-th crawl: 1551 data entries are collected
# 162-th crawl: 1561 data entries are collected
# 60-th collision detected!
# 163-th crawl: 1570 data entries are collected
# 164-th crawl: 1580 data entries are collected
# 61-th collision detected!
# 165-th crawl: 1589 data entries are collected
# 166-th crawl: 1599 data entries are collected
# 62-th collision detected!
# 167-th crawl: 1608 data entries are collected
# 63-th collision detected!
# 64-th collision detected!
# 168-th crawl: 1616 data entries are collected
# 169-th crawl: 1626 data entries are collected
# 170-th crawl: 1636 data entries are collected
# 171-th crawl: 1646 data entries are collected
# 172-th crawl: 1656 data entries are collected
# 173-th crawl: 1666 data entries are collected
# 174-th crawl: 1676 data entries are collected
# 65-th collision detected!
# 175-th crawl: 1685 data entries are collected
# 176-th crawl: 1695 data entries are collected
# 177-th crawl: 1705 data entries are collected
# 178-th crawl: 1715 data entries are collected
# 66-th collision detected!
# 67-th collision detected!
# 179-th crawl: 1723 data entries are collected
# 180-th crawl: 1733 data entries are collected
# 68-th collision detected!
# 69-th collision detected!
# 181-th crawl: 1741 data entries are collected
# 182-th crawl: 1751 data entries are collected
# 183-th crawl: 1761 data entries are collected
# 70-th collision detected!
# 184-th crawl: 1770 data entries are collected
# 71-th collision detected!
# 72-th collision detected!
# 185-th crawl: 1778 data entries are collected
# 186-th crawl: 1788 data entries are collected
# 73-th collision detected!
# 187-th crawl: 1797 data entries are collected
# 74-th collision detected!
# 188-th crawl: 1806 data entries are collected
# 189-th crawl: 1816 data entries are collected
# 190-th crawl: 1826 data entries are collected
# 191-th crawl: 1836 data entries are collected
# 75-th collision detected!
# 192-th crawl: 1845 data entries are collected
# 76-th collision detected!
# 77-th collision detected!
# 193-th crawl: 1853 data entries are collected
# 194-th crawl: 1863 data entries are collected
# 78-th collision detected!
# 195-th crawl: 1872 data entries are collected
# 196-th crawl: 1882 data entries are collected
# 197-th crawl: 1892 data entries are collected
# 198-th crawl: 1902 data entries are collected
# 79-th collision detected!
# 199-th crawl: 1911 data entries are collected
# 200-th crawl: 1921 data entries are collected
# 201-th crawl: 1931 data entries are collected
# 202-th crawl: 1941 data entries are collected
# 203-th crawl: 1951 data entries are collected
# 204-th crawl: 1961 data entries are collected
# 80-th collision detected!
# 205-th crawl: 1970 data entries are collected
# 81-th collision detected!
# 206-th crawl: 1979 data entries are collected
# 207-th crawl: 1989 data entries are collected
# 82-th collision detected!
# 208-th crawl: 1998 data entries are collected
# 209-th crawl: 2008 data entries are collected
# 210-th crawl: 2018 data entries are collected
# 83-th collision detected!
# 211-th crawl: 2027 data entries are collected
# 212-th crawl: 2037 data entries are collected
# 213-th crawl: 2047 data entries are collected
# 214-th crawl: 2057 data entries are collected
# 215-th crawl: 2067 data entries are collected
# exception found: maybe review is empty?
# 216-th crawl: 2077 data entries are collected
# 217-th crawl: 2087 data entries are collected
# 218-th crawl: 2097 data entries are collected
# 219-th crawl: 2107 data entries are collected
# 220-th crawl: 2117 data entries are collected
# 221-th crawl: 2127 data entries are collected
# 84-th collision detected!
# 222-th crawl: 2136 data entries are collected
# 223-th crawl: 2146 data entries are collected
# 85-th collision detected!
# 86-th collision detected!
# 224-th crawl: 2154 data entries are collected
# 87-th collision detected!
# 225-th crawl: 2163 data entries are collected
# 226-th crawl: 2173 data entries are collected
# 88-th collision detected!
# 227-th crawl: 2182 data entries are collected
# 89-th collision detected!
# 228-th crawl: 2191 data entries are collected
# 229-th crawl: 2201 data entries are collected
# 230-th crawl: 2211 data entries are collected
# 231-th crawl: 2221 data entries are collected
# 232-th crawl: 2231 data entries are collected
# 233-th crawl: 2241 data entries are collected
# 234-th crawl: 2251 data entries are collected
# 235-th crawl: 2261 data entries are collected
# 236-th crawl: 2271 data entries are collected
# 90-th collision detected!
# 91-th collision detected!
# 237-th crawl: 2279 data entries are collected
# 238-th crawl: 2289 data entries are collected
# 239-th crawl: 2299 data entries are collected
# 92-th collision detected!
# 240-th crawl: 2308 data entries are collected
# 241-th crawl: 2318 data entries are collected
# 242-th crawl: 2328 data entries are collected
# 243-th crawl: 2338 data entries are collected
# 244-th crawl: 2348 data entries are collected
# 245-th crawl: 2358 data entries are collected
# 246-th crawl: 2368 data entries are collected
# 93-th collision detected!
# 247-th crawl: 2377 data entries are collected
# 248-th crawl: 2387 data entries are collected
# 249-th crawl: 2397 data entries are collected
# 250-th crawl: 2407 data entries are collected
# 94-th collision detected!
# 251-th crawl: 2416 data entries are collected
# 95-th collision detected!
# 252-th crawl: 2425 data entries are collected
# 253-th crawl: 2435 data entries are collected
# 254-th crawl: 2445 data entries are collected
# 255-th crawl: 2455 data entries are collected
# 256-th crawl: 2465 data entries are collected
# 96-th collision detected!
# 257-th crawl: 2474 data entries are collected
# 258-th crawl: 2484 data entries are collected
# 259-th crawl: 2494 data entries are collected
# 97-th collision detected!
# 260-th crawl: 2503 data entries are collected
# 98-th collision detected!
# 261-th crawl: 2512 data entries are collected
# 262-th crawl: 2522 data entries are collected
# 99-th collision detected!
# 100-th collision detected!
# 263-th crawl: 2530 data entries are collected
# 101-th collision detected!
# 264-th crawl: 2539 data entries are collected
# 102-th collision detected!
# 265-th crawl: 2548 data entries are collected
# 266-th crawl: 2558 data entries are collected
# 267-th crawl: 2568 data entries are collected
# 103-th collision detected!
# 268-th crawl: 2577 data entries are collected
# 104-th collision detected!
# 269-th crawl: 2586 data entries are collected
# 270-th crawl: 2596 data entries are collected
# 105-th collision detected!
# 106-th collision detected!
# 271-th crawl: 2604 data entries are collected
# 272-th crawl: 2614 data entries are collected
# 273-th crawl: 2624 data entries are collected
# 274-th crawl: 2634 data entries are collected
# 107-th collision detected!
# 275-th crawl: 2643 data entries are collected
# 108-th collision detected!
# 276-th crawl: 2652 data entries are collected
# 277-th crawl: 2662 data entries are collected
# 109-th collision detected!
# 278-th crawl: 2671 data entries are collected
# 279-th crawl: 2681 data entries are collected
# 280-th crawl: 2691 data entries are collected
# 110-th collision detected!
# 281-th crawl: 2700 data entries are collected
# 282-th crawl: 2710 data entries are collected
# 111-th collision detected!
# 283-th crawl: 2719 data entries are collected
# 284-th crawl: 2729 data entries are collected
# 285-th crawl: 2739 data entries are collected
# 112-th collision detected!
# 286-th crawl: 2748 data entries are collected
# 113-th collision detected!
# 287-th crawl: 2757 data entries are collected
# 288-th crawl: 2767 data entries are collected
# 289-th crawl: 2777 data entries are collected
# 290-th crawl: 2787 data entries are collected
# 114-th collision detected!
# 291-th crawl: 2796 data entries are collected
# 292-th crawl: 2806 data entries are collected
# 293-th crawl: 2816 data entries are collected
# 294-th crawl: 2826 data entries are collected
# 295-th crawl: 2836 data entries are collected
# 296-th crawl: 2846 data entries are collected
# 297-th crawl: 2856 data entries are collected
# 298-th crawl: 2866 data entries are collected
# 115-th collision detected!
# 299-th crawl: 2875 data entries are collected
# 116-th collision detected!
# 300-th crawl: 2884 data entries are collected
# 301-th crawl: 2894 data entries are collected
# 302-th crawl: 2904 data entries are collected
# 303-th crawl: 2914 data entries are collected
# 304-th crawl: 2924 data entries are collected
# 305-th crawl: 2934 data entries are collected
# 306-th crawl: 2944 data entries are collected
# 307-th crawl: 2954 data entries are collected
# 117-th collision detected!
# 118-th collision detected!
# 308-th crawl: 2962 data entries are collected
# 119-th collision detected!
# 120-th collision detected!
# 309-th crawl: 2970 data entries are collected
# 310-th crawl: 2980 data entries are collected
# 121-th collision detected!
# 311-th crawl: 2989 data entries are collected
# 122-th collision detected!
# 312-th crawl: 2998 data entries are collected
# 123-th collision detected!
# 313-th crawl: 3007 data entries are collected
# 314-th crawl: 3017 data entries are collected
# 315-th crawl: 3027 data entries are collected
# 316-th crawl: 3037 data entries are collected
# 317-th crawl: 3047 data entries are collected
# 318-th crawl: 3057 data entries are collected
# 319-th crawl: 3067 data entries are collected
# 320-th crawl: 3077 data entries are collected
# 321-th crawl: 3087 data entries are collected
# 124-th collision detected!
# 322-th crawl: 3096 data entries are collected
# 323-th crawl: 3106 data entries are collected
# 125-th collision detected!
# 324-th crawl: 3115 data entries are collected
# 325-th crawl: 3125 data entries are collected
# 126-th collision detected!
# 326-th crawl: 3134 data entries are collected
# 127-th collision detected!
# 327-th crawl: 3143 data entries are collected
# 328-th crawl: 3153 data entries are collected
# 329-th crawl: 3163 data entries are collected
# 330-th crawl: 3173 data entries are collected
# 128-th collision detected!
# 129-th collision detected!
# 331-th crawl: 3181 data entries are collected
# 130-th collision detected!
# 332-th crawl: 3190 data entries are collected
# 333-th crawl: 3200 data entries are collected
# 334-th crawl: 3210 data entries are collected
# 335-th crawl: 3220 data entries are collected
# 131-th collision detected!
# 336-th crawl: 3229 data entries are collected
# 132-th collision detected!
# 337-th crawl: 3238 data entries are collected
# 338-th crawl: 3248 data entries are collected
# 339-th crawl: 3258 data entries are collected
# 133-th collision detected!
# 134-th collision detected!
# 340-th crawl: 3266 data entries are collected
# 341-th crawl: 3276 data entries are collected
# 342-th crawl: 3286 data entries are collected
# 343-th crawl: 3296 data entries are collected
# 344-th crawl: 3306 data entries are collected
# 345-th crawl: 3316 data entries are collected
# 346-th crawl: 3326 data entries are collected
# 347-th crawl: 3336 data entries are collected
# 348-th crawl: 3346 data entries are collected
# 349-th crawl: 3356 data entries are collected
# 350-th crawl: 3366 data entries are collected
# 351-th crawl: 3376 data entries are collected
# 352-th crawl: 3386 data entries are collected
# 353-th crawl: 3396 data entries are collected
# 354-th crawl: 3406 data entries are collected
# 135-th collision detected!
# 136-th collision detected!
# 355-th crawl: 3414 data entries are collected
# 356-th crawl: 3424 data entries are collected
# 137-th collision detected!
# 138-th collision detected!
# 357-th crawl: 3432 data entries are collected
# 139-th collision detected!
# 358-th crawl: 3441 data entries are collected
# 140-th collision detected!
# 359-th crawl: 3450 data entries are collected
# 141-th collision detected!
# 360-th crawl: 3459 data entries are collected
# 361-th crawl: 3469 data entries are collected
# 142-th collision detected!
# 362-th crawl: 3478 data entries are collected
# 363-th crawl: 3488 data entries are collected
# 364-th crawl: 3498 data entries are collected
# 365-th crawl: 3508 data entries are collected
# 143-th collision detected!
# 366-th crawl: 3517 data entries are collected
# 144-th collision detected!
# 367-th crawl: 3526 data entries are collected
# 368-th crawl: 3536 data entries are collected
# 145-th collision detected!
# 146-th collision detected!
# 369-th crawl: 3544 data entries are collected
# 147-th collision detected!
# 370-th crawl: 3553 data entries are collected
# 148-th collision detected!
# 371-th crawl: 3562 data entries are collected
# 149-th collision detected!
# 372-th crawl: 3571 data entries are collected
# 373-th crawl: 3581 data entries are collected
# 374-th crawl: 3591 data entries are collected
# 150-th collision detected!
# 375-th crawl: 3600 data entries are collected
# 376-th crawl: 3610 data entries are collected
# 151-th collision detected!
# 377-th crawl: 3619 data entries are collected
# 378-th crawl: 3629 data entries are collected
# 152-th collision detected!
# 379-th crawl: 3638 data entries are collected
# 380-th crawl: 3648 data entries are collected
# 381-th crawl: 3658 data entries are collected
# 382-th crawl: 3668 data entries are collected
# 383-th crawl: 3678 data entries are collected
# 384-th crawl: 3688 data entries are collected
# 385-th crawl: 3698 data entries are collected
# 153-th collision detected!
# 154-th collision detected!
# 386-th crawl: 3706 data entries are collected
# 387-th crawl: 3716 data entries are collected
# 388-th crawl: 3726 data entries are collected
# 389-th crawl: 3736 data entries are collected
# 155-th collision detected!
# 390-th crawl: 3745 data entries are collected
# 391-th crawl: 3755 data entries are collected
# 392-th crawl: 3765 data entries are collected
# 393-th crawl: 3775 data entries are collected
# 156-th collision detected!
# 394-th crawl: 3784 data entries are collected
# 395-th crawl: 3794 data entries are collected
# 157-th collision detected!
# 396-th crawl: 3803 data entries are collected
# 397-th crawl: 3813 data entries are collected
# 158-th collision detected!
# 398-th crawl: 3822 data entries are collected
# 399-th crawl: 3832 data entries are collected
# 400-th crawl: 3842 data entries are collected
# 159-th collision detected!
# 401-th crawl: 3851 data entries are collected
# 402-th crawl: 3861 data entries are collected
# 403-th crawl: 3871 data entries are collected
# 404-th crawl: 3881 data entries are collected
# 405-th crawl: 3891 data entries are collected
# 160-th collision detected!
# 161-th collision detected!
# 406-th crawl: 3899 data entries are collected
# 162-th collision detected!
# 407-th crawl: 3908 data entries are collected
# 408-th crawl: 3918 data entries are collected
# 163-th collision detected!
# 409-th crawl: 3927 data entries are collected
# 410-th crawl: 3937 data entries are collected
# 411-th crawl: 3947 data entries are collected
# 412-th crawl: 3957 data entries are collected
# 413-th crawl: 3967 data entries are collected
# 414-th crawl: 3977 data entries are collected
# 415-th crawl: 3987 data entries are collected
# 416-th crawl: 3997 data entries are collected
# 164-th collision detected!
# 417-th crawl: 4006 data entries are collected
# 418-th crawl: 4016 data entries are collected
# 419-th crawl: 4026 data entries are collected
# 165-th collision detected!
# 420-th crawl: 4035 data entries are collected
# 421-th crawl: 4045 data entries are collected
# 422-th crawl: 4055 data entries are collected
# 166-th collision detected!
# 423-th crawl: 4064 data entries are collected
# 424-th crawl: 4074 data entries are collected
# 425-th crawl: 4084 data entries are collected
# 426-th crawl: 4094 data entries are collected
# 427-th crawl: 4104 data entries are collected
# 428-th crawl: 4114 data entries are collected
# 429-th crawl: 4124 data entries are collected
# 430-th crawl: 4134 data entries are collected
# 167-th collision detected!
# 431-th crawl: 4143 data entries are collected
# 432-th crawl: 4153 data entries are collected
# 433-th crawl: 4163 data entries are collected
# 434-th crawl: 4173 data entries are collected
# 168-th collision detected!
# 435-th crawl: 4182 data entries are collected
# 436-th crawl: 4192 data entries are collected
# 437-th crawl: 4202 data entries are collected
# 169-th collision detected!
# 438-th crawl: 4211 data entries are collected
# 170-th collision detected!
# 171-th collision detected!
# 439-th crawl: 4219 data entries are collected
# 172-th collision detected!
# 440-th crawl: 4228 data entries are collected
# 173-th collision detected!
# 441-th crawl: 4237 data entries are collected
# 442-th crawl: 4247 data entries are collected
# 443-th crawl: 4257 data entries are collected
# 444-th crawl: 4267 data entries are collected
# 445-th crawl: 4277 data entries are collected
# 446-th crawl: 4287 data entries are collected
# 447-th crawl: 4297 data entries are collected
# 448-th crawl: 4307 data entries are collected
# 174-th collision detected!
# 449-th crawl: 4316 data entries are collected
# 450-th crawl: 4326 data entries are collected
# 451-th crawl: 4336 data entries are collected
# 452-th crawl: 4346 data entries are collected
# 453-th crawl: 4356 data entries are collected
# 454-th crawl: 4366 data entries are collected
# 175-th collision detected!
# 455-th crawl: 4375 data entries are collected
# 456-th crawl: 4385 data entries are collected
# 457-th crawl: 4395 data entries are collected
# 176-th collision detected!
# 458-th crawl: 4404 data entries are collected
# 177-th collision detected!
# 459-th crawl: 4413 data entries are collected
# 460-th crawl: 4423 data entries are collected
# 461-th crawl: 4433 data entries are collected
# 462-th crawl: 4443 data entries are collected
# 463-th crawl: 4453 data entries are collected
# 464-th crawl: 4463 data entries are collected
# 465-th crawl: 4473 data entries are collected
# 178-th collision detected!
# 466-th crawl: 4482 data entries are collected
# 179-th collision detected!
# 467-th crawl: 4491 data entries are collected
# 468-th crawl: 4501 data entries are collected
# 469-th crawl: 4511 data entries are collected
# 180-th collision detected!
# 470-th crawl: 4520 data entries are collected
# 471-th crawl: 4530 data entries are collected
# 472-th crawl: 4540 data entries are collected
# 473-th crawl: 4550 data entries are collected
# 181-th collision detected!
# 182-th collision detected!
# 474-th crawl: 4558 data entries are collected
# 475-th crawl: 4568 data entries are collected
# 476-th crawl: 4578 data entries are collected
# 477-th crawl: 4588 data entries are collected
# 478-th crawl: 4598 data entries are collected
# 183-th collision detected!
# 479-th crawl: 4607 data entries are collected
# 480-th crawl: 4617 data entries are collected
# 481-th crawl: 4627 data entries are collected
# 482-th crawl: 4637 data entries are collected
# 483-th crawl: 4647 data entries are collected
# 184-th collision detected!
# 185-th collision detected!
# 186-th collision detected!
# 484-th crawl: 4654 data entries are collected
# 485-th crawl: 4664 data entries are collected
# 486-th crawl: 4674 data entries are collected
# 487-th crawl: 4684 data entries are collected
# 488-th crawl: 4694 data entries are collected
# 489-th crawl: 4704 data entries are collected
# 490-th crawl: 4714 data entries are collected
# 491-th crawl: 4724 data entries are collected
# 492-th crawl: 4734 data entries are collected
# 493-th crawl: 4744 data entries are collected
# 494-th crawl: 4754 data entries are collected
# 187-th collision detected!
# 495-th crawl: 4763 data entries are collected
# exception found: maybe review is empty?
# 496-th crawl: 4773 data entries are collected
# 497-th crawl: 4783 data entries are collected
# 188-th collision detected!
# 498-th crawl: 4792 data entries are collected
# 189-th collision detected!
# 499-th crawl: 4801 data entries are collected
# 500-th crawl: 4811 data entries are collected
# 501-th crawl: 4821 data entries are collected
# 502-th crawl: 4831 data entries are collected
# 503-th crawl: 4841 data entries are collected
# 504-th crawl: 4851 data entries are collected
# 505-th crawl: 4861 data entries are collected
# 506-th crawl: 4871 data entries are collected
# 507-th crawl: 4881 data entries are collected
# 508-th crawl: 4891 data entries are collected
# 509-th crawl: 4901 data entries are collected
# 510-th crawl: 4911 data entries are collected
# 190-th collision detected!
# 511-th crawl: 4920 data entries are collected
# 191-th collision detected!
# 512-th crawl: 4929 data entries are collected
# 513-th crawl: 4939 data entries are collected
# 192-th collision detected!
# 514-th crawl: 4948 data entries are collected
# 515-th crawl: 4958 data entries are collected
# 516-th crawl: 4968 data entries are collected
# 193-th collision detected!
# 517-th crawl: 4977 data entries are collected
# 518-th crawl: 4987 data entries are collected
# 519-th crawl: 4997 data entries are collected
# 194-th collision detected!
# 520-th crawl: 5006 data entries are collected
# 521-th crawl: 5016 data entries are collected
# 522-th crawl: 5026 data entries are collected
# 523-th crawl: 5036 data entries are collected
# 524-th crawl: 5046 data entries are collected
# 525-th crawl: 5056 data entries are collected
# 526-th crawl: 5066 data entries are collected
# 527-th crawl: 5076 data entries are collected
# 528-th crawl: 5086 data entries are collected
# 529-th crawl: 5096 data entries are collected
# 530-th crawl: 5106 data entries are collected
# 531-th crawl: 5116 data entries are collected
# 532-th crawl: 5126 data entries are collected
# 533-th crawl: 5136 data entries are collected
# 195-th collision detected!
# 196-th collision detected!
# 534-th crawl: 5144 data entries are collected
# 535-th crawl: 5154 data entries are collected
# 536-th crawl: 5164 data entries are collected
# 537-th crawl: 5174 data entries are collected
# 538-th crawl: 5184 data entries are collected
# 539-th crawl: 5194 data entries are collected
# 197-th collision detected!
# 540-th crawl: 5203 data entries are collected
# 198-th collision detected!
# 541-th crawl: 5212 data entries are collected
# 542-th crawl: 5222 data entries are collected
# 199-th collision detected!
# 543-th crawl: 5231 data entries are collected
# 200-th collision detected!
# 544-th crawl: 5240 data entries are collected
# 201-th collision detected!
# 545-th crawl: 5249 data entries are collected
# 546-th crawl: 5259 data entries are collected
# 202-th collision detected!
# 547-th crawl: 5268 data entries are collected
# 548-th crawl: 5278 data entries are collected
# 549-th crawl: 5288 data entries are collected
# 550-th crawl: 5298 data entries are collected
# 551-th crawl: 5308 data entries are collected
# 552-th crawl: 5318 data entries are collected
# 553-th crawl: 5328 data entries are collected
# 203-th collision detected!
# 554-th crawl: 5337 data entries are collected
# 204-th collision detected!
# 205-th collision detected!
# 555-th crawl: 5345 data entries are collected
# 556-th crawl: 5355 data entries are collected
# 206-th collision detected!
# 557-th crawl: 5364 data entries are collected
# 558-th crawl: 5374 data entries are collected
# 559-th crawl: 5384 data entries are collected
# 207-th collision detected!
# 560-th crawl: 5393 data entries are collected
# 208-th collision detected!
# 561-th crawl: 5402 data entries are collected
# 562-th crawl: 5412 data entries are collected
# 209-th collision detected!
# 563-th crawl: 5421 data entries are collected
# 210-th collision detected!
# 564-th crawl: 5430 data entries are collected
# 565-th crawl: 5440 data entries are collected
# 566-th crawl: 5450 data entries are collected
# 567-th crawl: 5460 data entries are collected
# 211-th collision detected!
# 568-th crawl: 5469 data entries are collected
# 569-th crawl: 5479 data entries are collected
# 212-th collision detected!
# 213-th collision detected!
# 570-th crawl: 5487 data entries are collected
# 571-th crawl: 5497 data entries are collected
# 214-th collision detected!
# 572-th crawl: 5506 data entries are collected
# 215-th collision detected!
# 573-th crawl: 5515 data entries are collected
# 216-th collision detected!
# 217-th collision detected!
# 574-th crawl: 5523 data entries are collected
# 575-th crawl: 5533 data entries are collected
# 218-th collision detected!
# 576-th crawl: 5542 data entries are collected
# 577-th crawl: 5552 data entries are collected
# 219-th collision detected!
# 220-th collision detected!
# 221-th collision detected!
# 578-th crawl: 5559 data entries are collected
# 579-th crawl: 5569 data entries are collected
# 580-th crawl: 5579 data entries are collected
# 581-th crawl: 5589 data entries are collected
# 582-th crawl: 5599 data entries are collected
# 222-th collision detected!
# 583-th crawl: 5608 data entries are collected
# 584-th crawl: 5618 data entries are collected
# 223-th collision detected!
# 224-th collision detected!
# 585-th crawl: 5626 data entries are collected
# 225-th collision detected!
# 586-th crawl: 5635 data entries are collected
# 587-th crawl: 5645 data entries are collected
# 588-th crawl: 5655 data entries are collected
# 589-th crawl: 5665 data entries are collected
# 590-th crawl: 5675 data entries are collected
# 226-th collision detected!
# 227-th collision detected!
# 591-th crawl: 5683 data entries are collected
# 592-th crawl: 5693 data entries are collected
# 228-th collision detected!
# 593-th crawl: 5702 data entries are collected
# 229-th collision detected!
# 594-th crawl: 5711 data entries are collected
# 230-th collision detected!
# 595-th crawl: 5720 data entries are collected
# 231-th collision detected!
# 596-th crawl: 5729 data entries are collected
# 597-th crawl: 5739 data entries are collected
# 598-th crawl: 5749 data entries are collected
# 599-th crawl: 5759 data entries are collected
# 232-th collision detected!
# 600-th crawl: 5768 data entries are collected
# 601-th crawl: 5778 data entries are collected
# 602-th crawl: 5788 data entries are collected
# 233-th collision detected!
# 603-th crawl: 5797 data entries are collected
# 604-th crawl: 5807 data entries are collected
# 605-th crawl: 5817 data entries are collected
# 606-th crawl: 5827 data entries are collected
# 234-th collision detected!
# 235-th collision detected!
# 607-th crawl: 5835 data entries are collected
# 608-th crawl: 5845 data entries are collected
# 236-th collision detected!
# 237-th collision detected!
# 609-th crawl: 5853 data entries are collected
# 610-th crawl: 5863 data entries are collected
# 611-th crawl: 5873 data entries are collected
# 612-th crawl: 5883 data entries are collected
# 613-th crawl: 5893 data entries are collected
# 614-th crawl: 5903 data entries are collected
# 238-th collision detected!
# 615-th crawl: 5912 data entries are collected
# 616-th crawl: 5922 data entries are collected
# 617-th crawl: 5932 data entries are collected
# 239-th collision detected!
# 618-th crawl: 5941 data entries are collected
# 240-th collision detected!
# 619-th crawl: 5950 data entries are collected
# 620-th crawl: 5960 data entries are collected
# 621-th crawl: 5970 data entries are collected
# 622-th crawl: 5980 data entries are collected
# 623-th crawl: 5990 data entries are collected
# 241-th collision detected!
# 624-th crawl: 5999 data entries are collected
# 625-th crawl: 6009 data entries are collected
# 626-th crawl: 6019 data entries are collected
# 627-th crawl: 6029 data entries are collected
# 628-th crawl: 6039 data entries are collected
# 242-th collision detected!
# 629-th crawl: 6048 data entries are collected
# 630-th crawl: 6058 data entries are collected
# 243-th collision detected!
# 631-th crawl: 6066 data entries are collected
# 632-th crawl: 6076 data entries are collected
# 633-th crawl: 6086 data entries are collected
# 244-th collision detected!
# 634-th crawl: 6095 data entries are collected
# 635-th crawl: 6105 data entries are collected
# 636-th crawl: 6115 data entries are collected
# 637-th crawl: 6125 data entries are collected
# 638-th crawl: 6135 data entries are collected
# 639-th crawl: 6145 data entries are collected
# 640-th crawl: 6155 data entries are collected
# 641-th crawl: 6165 data entries are collected
# 245-th collision detected!
# 246-th collision detected!
# 642-th crawl: 6173 data entries are collected
# 643-th crawl: 6183 data entries are collected
# 644-th crawl: 6193 data entries are collected
# 247-th collision detected!
# 645-th crawl: 6202 data entries are collected
# 646-th crawl: 6212 data entries are collected
# 248-th collision detected!
# 249-th collision detected!
# 647-th crawl: 6220 data entries are collected
# 648-th crawl: 6230 data entries are collected
# 649-th crawl: 6240 data entries are collected
# 650-th crawl: 6250 data entries are collected
# 651-th crawl: 6260 data entries are collected
# 652-th crawl: 6270 data entries are collected
# 250-th collision detected!
# 251-th collision detected!
# 653-th crawl: 6278 data entries are collected
# 654-th crawl: 6288 data entries are collected
# 252-th collision detected!
# 655-th crawl: 6297 data entries are collected
# 253-th collision detected!
# 656-th crawl: 6306 data entries are collected
# 657-th crawl: 6316 data entries are collected
# 658-th crawl: 6326 data entries are collected
# 659-th crawl: 6336 data entries are collected
# 660-th crawl: 6346 data entries are collected
# 254-th collision detected!
# 661-th crawl: 6355 data entries are collected
# 662-th crawl: 6365 data entries are collected
# 255-th collision detected!
# 663-th crawl: 6374 data entries are collected
# 664-th crawl: 6384 data entries are collected
# 256-th collision detected!
# 665-th crawl: 6393 data entries are collected
# 666-th crawl: 6403 data entries are collected
# 667-th crawl: 6413 data entries are collected
# 668-th crawl: 6423 data entries are collected
# 257-th collision detected!
# 258-th collision detected!
# 669-th crawl: 6431 data entries are collected
# 670-th crawl: 6441 data entries are collected
# 671-th crawl: 6451 data entries are collected
# 672-th crawl: 6461 data entries are collected
# 673-th crawl: 6471 data entries are collected
# 259-th collision detected!
# 674-th crawl: 6480 data entries are collected
# 675-th crawl: 6490 data entries are collected
# 676-th crawl: 6500 data entries are collected
# 260-th collision detected!
# 261-th collision detected!
# 677-th crawl: 6508 data entries are collected
# 678-th crawl: 6518 data entries are collected
# 679-th crawl: 6528 data entries are collected
# 680-th crawl: 6538 data entries are collected
# 262-th collision detected!
# 681-th crawl: 6547 data entries are collected
# 682-th crawl: 6557 data entries are collected
# 263-th collision detected!
# 683-th crawl: 6566 data entries are collected
# 684-th crawl: 6576 data entries are collected
# 685-th crawl: 6586 data entries are collected
# 686-th crawl: 6596 data entries are collected
# 687-th crawl: 6606 data entries are collected
# 688-th crawl: 6616 data entries are collected
# 689-th crawl: 6626 data entries are collected
# 690-th crawl: 6636 data entries are collected
# 264-th collision detected!
# 691-th crawl: 6645 data entries are collected
# 692-th crawl: 6655 data entries are collected
# 693-th crawl: 6665 data entries are collected
# 694-th crawl: 6675 data entries are collected
# 695-th crawl: 6685 data entries are collected
# 696-th crawl: 6695 data entries are collected
# 697-th crawl: 6705 data entries are collected
# 265-th collision detected!
# 698-th crawl: 6714 data entries are collected
# 699-th crawl: 6724 data entries are collected
# 700-th crawl: 6734 data entries are collected
# 266-th collision detected!
# 267-th collision detected!
# 701-th crawl: 6742 data entries are collected
# 702-th crawl: 6752 data entries are collected
# 703-th crawl: 6762 data entries are collected
# 704-th crawl: 6772 data entries are collected
# 705-th crawl: 6782 data entries are collected
# 706-th crawl: 6792 data entries are collected
# 707-th crawl: 6802 data entries are collected
# 708-th crawl: 6812 data entries are collected
# 709-th crawl: 6822 data entries are collected
# 710-th crawl: 6832 data entries are collected
# 268-th collision detected!
# 269-th collision detected!
# 270-th collision detected!
# 711-th crawl: 6839 data entries are collected
# 712-th crawl: 6849 data entries are collected
# 713-th crawl: 6859 data entries are collected
# 714-th crawl: 6869 data entries are collected
# 715-th crawl: 6879 data entries are collected
# 716-th crawl: 6889 data entries are collected
# 717-th crawl: 6899 data entries are collected
# 718-th crawl: 6909 data entries are collected
# 271-th collision detected!
# 719-th crawl: 6918 data entries are collected
# 272-th collision detected!
# 720-th crawl: 6927 data entries are collected
# 721-th crawl: 6937 data entries are collected
# 722-th crawl: 6947 data entries are collected
# 723-th crawl: 6957 data entries are collected
# 724-th crawl: 6967 data entries are collected
# 273-th collision detected!
# 725-th crawl: 6976 data entries are collected
# 726-th crawl: 6986 data entries are collected
# 274-th collision detected!
# 727-th crawl: 6995 data entries are collected
# 728-th crawl: 7005 data entries are collected
# 729-th crawl: 7015 data entries are collected
# 730-th crawl: 7025 data entries are collected
# 731-th crawl: 7035 data entries are collected
# 732-th crawl: 7045 data entries are collected
# 733-th crawl: 7055 data entries are collected
# 734-th crawl: 7065 data entries are collected
# 735-th crawl: 7075 data entries are collected
# 275-th collision detected!
# 736-th crawl: 7084 data entries are collected
# 737-th crawl: 7094 data entries are collected
# 276-th collision detected!
# 277-th collision detected!
# 738-th crawl: 7102 data entries are collected
# 739-th crawl: 7112 data entries are collected
# 278-th collision detected!
# 740-th crawl: 7121 data entries are collected
# 741-th crawl: 7131 data entries are collected
# 742-th crawl: 7141 data entries are collected
# 743-th crawl: 7151 data entries are collected
# 744-th crawl: 7161 data entries are collected
# 745-th crawl: 7171 data entries are collected
# 746-th crawl: 7181 data entries are collected
# 279-th collision detected!
# 747-th crawl: 7190 data entries are collected
# 748-th crawl: 7200 data entries are collected
# 749-th crawl: 7210 data entries are collected
# 750-th crawl: 7220 data entries are collected
# 751-th crawl: 7230 data entries are collected
# 752-th crawl: 7240 data entries are collected
# 280-th collision detected!
# 753-th crawl: 7249 data entries are collected
# 754-th crawl: 7259 data entries are collected
# 755-th crawl: 7269 data entries are collected
# 756-th crawl: 7279 data entries are collected
# 281-th collision detected!
# 757-th crawl: 7288 data entries are collected
# 282-th collision detected!
# 283-th collision detected!
# 758-th crawl: 7296 data entries are collected
# 759-th crawl: 7306 data entries are collected
# 760-th crawl: 7316 data entries are collected
# 284-th collision detected!
# 285-th collision detected!
# 761-th crawl: 7324 data entries are collected
# 762-th crawl: 7334 data entries are collected
# 763-th crawl: 7344 data entries are collected
# 764-th crawl: 7354 data entries are collected
# 765-th crawl: 7364 data entries are collected
# 766-th crawl: 7374 data entries are collected
# 767-th crawl: 7384 data entries are collected
# 768-th crawl: 7394 data entries are collected
# 769-th crawl: 7404 data entries are collected
# 770-th crawl: 7414 data entries are collected
# 771-th crawl: 7424 data entries are collected
# 772-th crawl: 7434 data entries are collected
# 286-th collision detected!
# 773-th crawl: 7443 data entries are collected
# 774-th crawl: 7453 data entries are collected
# 775-th crawl: 7463 data entries are collected
# 776-th crawl: 7473 data entries are collected
# 777-th crawl: 7483 data entries are collected
# 778-th crawl: 7493 data entries are collected
# 779-th crawl: 7503 data entries are collected
# 287-th collision detected!
# 288-th collision detected!
# 780-th crawl: 7511 data entries are collected
# 781-th crawl: 7521 data entries are collected
# 289-th collision detected!
# 782-th crawl: 7530 data entries are collected
# 290-th collision detected!
# 783-th crawl: 7539 data entries are collected
# 784-th crawl: 7549 data entries are collected
# 785-th crawl: 7559 data entries are collected
# 786-th crawl: 7569 data entries are collected
# 787-th crawl: 7579 data entries are collected
# 291-th collision detected!
# 292-th collision detected!
# 788-th crawl: 7587 data entries are collected
# 789-th crawl: 7597 data entries are collected
# 293-th collision detected!
# 294-th collision detected!
# 790-th crawl: 7605 data entries are collected
# 791-th crawl: 7615 data entries are collected
# 792-th crawl: 7625 data entries are collected
# 295-th collision detected!
# 793-th crawl: 7634 data entries are collected
# 794-th crawl: 7644 data entries are collected
# 795-th crawl: 7654 data entries are collected
# 796-th crawl: 7664 data entries are collected
# 797-th crawl: 7674 data entries are collected
# 798-th crawl: 7684 data entries are collected
# 799-th crawl: 7694 data entries are collected
# 800-th crawl: 7704 data entries are collected
# 801-th crawl: 7714 data entries are collected
# 802-th crawl: 7724 data entries are collected
# 803-th crawl: 7734 data entries are collected
# 804-th crawl: 7744 data entries are collected
# 805-th crawl: 7754 data entries are collected
# 806-th crawl: 7764 data entries are collected
# 807-th crawl: 7774 data entries are collected
# 808-th crawl: 7784 data entries are collected
# 296-th collision detected!
# 809-th crawl: 7793 data entries are collected
# 297-th collision detected!
# 810-th crawl: 7802 data entries are collected
# 811-th crawl: 7812 data entries are collected
# 812-th crawl: 7822 data entries are collected
# 813-th crawl: 7832 data entries are collected
# 814-th crawl: 7842 data entries are collected
# 815-th crawl: 7852 data entries are collected
# 816-th crawl: 7862 data entries are collected
# 817-th crawl: 7872 data entries are collected
# 298-th collision detected!
# 818-th crawl: 7881 data entries are collected
# 819-th crawl: 7891 data entries are collected
# 820-th crawl: 7901 data entries are collected
# 299-th collision detected!
# 821-th crawl: 7910 data entries are collected
# exception found: maybe review is empty?
# 822-th crawl: 7920 data entries are collected
# 823-th crawl: 7930 data entries are collected
# 824-th crawl: 7940 data entries are collected
# 825-th crawl: 7950 data entries are collected
# 826-th crawl: 7960 data entries are collected
# 827-th crawl: 7970 data entries are collected
# 828-th crawl: 7980 data entries are collected
# 829-th crawl: 7990 data entries are collected
# 830-th crawl: 8000 data entries are collected
# 831-th crawl: 8010 data entries are collected
# 300-th collision detected!
# 301-th collision detected!
# 832-th crawl: 8018 data entries are collected
# 833-th crawl: 8028 data entries are collected
# 834-th crawl: 8038 data entries are collected
# 835-th crawl: 8048 data entries are collected
# 836-th crawl: 8058 data entries are collected
# 837-th crawl: 8068 data entries are collected
# 838-th crawl: 8078 data entries are collected
# 302-th collision detected!
# 839-th crawl: 8087 data entries are collected
# 303-th collision detected!
# 840-th crawl: 8096 data entries are collected
# 841-th crawl: 8106 data entries are collected
# 842-th crawl: 8116 data entries are collected
# 843-th crawl: 8126 data entries are collected
# 844-th crawl: 8136 data entries are collected
# 304-th collision detected!
# 845-th crawl: 8145 data entries are collected
# 305-th collision detected!
# 306-th collision detected!
# 846-th crawl: 8153 data entries are collected
# 847-th crawl: 8163 data entries are collected
# 848-th crawl: 8173 data entries are collected
# 849-th crawl: 8183 data entries are collected
# 307-th collision detected!
# 850-th crawl: 8192 data entries are collected
# 851-th crawl: 8202 data entries are collected
# 852-th crawl: 8212 data entries are collected
# 853-th crawl: 8222 data entries are collected
# 854-th crawl: 8232 data entries are collected
# 855-th crawl: 8242 data entries are collected
# 856-th crawl: 8252 data entries are collected
# 308-th collision detected!
# 857-th crawl: 8261 data entries are collected
# 858-th crawl: 8271 data entries are collected
# 309-th collision detected!
# 859-th crawl: 8280 data entries are collected
# 860-th crawl: 8290 data entries are collected
# 861-th crawl: 8300 data entries are collected
# 862-th crawl: 8310 data entries are collected
# 310-th collision detected!
# 863-th crawl: 8319 data entries are collected
# 311-th collision detected!
# 864-th crawl: 8328 data entries are collected
# 865-th crawl: 8338 data entries are collected
# 866-th crawl: 8348 data entries are collected
# 867-th crawl: 8358 data entries are collected
# 868-th crawl: 8368 data entries are collected
# 869-th crawl: 8378 data entries are collected
# 870-th crawl: 8388 data entries are collected
# 871-th crawl: 8398 data entries are collected
# 872-th crawl: 8408 data entries are collected
# 873-th crawl: 8418 data entries are collected
# 874-th crawl: 8428 data entries are collected
# 875-th crawl: 8438 data entries are collected
# 876-th crawl: 8448 data entries are collected
# 312-th collision detected!
# 313-th collision detected!
# 877-th crawl: 8456 data entries are collected
# 878-th crawl: 8466 data entries are collected
# 879-th crawl: 8476 data entries are collected
# 314-th collision detected!
# 880-th crawl: 8485 data entries are collected
# 881-th crawl: 8495 data entries are collected
# 315-th collision detected!
# 882-th crawl: 8504 data entries are collected
# 883-th crawl: 8514 data entries are collected
# 884-th crawl: 8524 data entries are collected
# 885-th crawl: 8534 data entries are collected
# 886-th crawl: 8544 data entries are collected
# 887-th crawl: 8554 data entries are collected
# 888-th crawl: 8564 data entries are collected
# 889-th crawl: 8574 data entries are collected
# 316-th collision detected!
# 890-th crawl: 8583 data entries are collected
# 317-th collision detected!
# 891-th crawl: 8592 data entries are collected
# 892-th crawl: 8602 data entries are collected
# 893-th crawl: 8612 data entries are collected
# 318-th collision detected!
# 894-th crawl: 8621 data entries are collected
# 895-th crawl: 8631 data entries are collected
# 896-th crawl: 8641 data entries are collected
# 897-th crawl: 8651 data entries are collected
# 898-th crawl: 8661 data entries are collected
# 899-th crawl: 8671 data entries are collected
# 319-th collision detected!
# 900-th crawl: 8680 data entries are collected
# 320-th collision detected!
# 901-th crawl: 8689 data entries are collected
# 321-th collision detected!
# 902-th crawl: 8698 data entries are collected
# 903-th crawl: 8708 data entries are collected
# 904-th crawl: 8718 data entries are collected
# 322-th collision detected!
# 905-th crawl: 8727 data entries are collected
# 906-th crawl: 8737 data entries are collected
# 907-th crawl: 8747 data entries are collected
# 323-th collision detected!
# 908-th crawl: 8756 data entries are collected
# 324-th collision detected!
# 909-th crawl: 8765 data entries are collected
# 910-th crawl: 8775 data entries are collected
# 911-th crawl: 8785 data entries are collected
# 912-th crawl: 8795 data entries are collected
# 325-th collision detected!
# 913-th crawl: 8804 data entries are collected
# 914-th crawl: 8814 data entries are collected
# 326-th collision detected!
# 915-th crawl: 8823 data entries are collected
# 327-th collision detected!
# 916-th crawl: 8832 data entries are collected
# 917-th crawl: 8842 data entries are collected
# 918-th crawl: 8852 data entries are collected
# 328-th collision detected!
# 919-th crawl: 8861 data entries are collected
# 920-th crawl: 8871 data entries are collected
# 921-th crawl: 8881 data entries are collected
# 922-th crawl: 8891 data entries are collected
# 923-th crawl: 8901 data entries are collected
# 924-th crawl: 8911 data entries are collected
# 925-th crawl: 8921 data entries are collected
# 926-th crawl: 8931 data entries are collected
# 329-th collision detected!
# 927-th crawl: 8940 data entries are collected
# 330-th collision detected!
# 331-th collision detected!
# 928-th crawl: 8948 data entries are collected
# 332-th collision detected!
# 929-th crawl: 8957 data entries are collected
# 930-th crawl: 8967 data entries are collected
# 931-th crawl: 8977 data entries are collected
# 932-th crawl: 8987 data entries are collected
# 933-th crawl: 8997 data entries are collected
# 934-th crawl: 9007 data entries are collected
# 935-th crawl: 9017 data entries are collected
# 936-th crawl: 9027 data entries are collected
# 937-th crawl: 9037 data entries are collected
# 938-th crawl: 9047 data entries are collected
# 939-th crawl: 9057 data entries are collected
# 333-th collision detected!
# 940-th crawl: 9066 data entries are collected
# 334-th collision detected!
# 941-th crawl: 9075 data entries are collected
# 942-th crawl: 9085 data entries are collected
# 943-th crawl: 9095 data entries are collected
# 335-th collision detected!
# 944-th crawl: 9104 data entries are collected
# 336-th collision detected!
# 945-th crawl: 9113 data entries are collected
# 946-th crawl: 9123 data entries are collected
# 947-th crawl: 9133 data entries are collected
# 337-th collision detected!
# 948-th crawl: 9142 data entries are collected
# 338-th collision detected!
# 949-th crawl: 9151 data entries are collected
# 339-th collision detected!
# 950-th crawl: 9160 data entries are collected
# 951-th crawl: 9170 data entries are collected
# 952-th crawl: 9180 data entries are collected
# 953-th crawl: 9190 data entries are collected
# 954-th crawl: 9200 data entries are collected
# 340-th collision detected!
# 341-th collision detected!
# 955-th crawl: 9208 data entries are collected
# 956-th crawl: 9218 data entries are collected
# 957-th crawl: 9228 data entries are collected

# %%
"""
Created on Mon Nov 19 17:50:38 2018

@author: ohmgs
"""
# Prep
import json
import pandas as pd
import numpy as np
import konlpy
from konlpy.tag import Komoran
from konlpy.tag import Okt
from time import time
import pickle
import os
import nltk
import seaborn as sns
import matplotlib.pyplot as plt

with open('./collected_movie_reviews.txt') as data_file:
    data = json.load(data_file)

L = list(data.values())
print(L[0])
# Out:
# {'review': '끝나고 나서도 여운이 가시질 않는다ㅠㅠ', 'rating': 10, 'title': '호두까기 인형과 4개의 왕국'}

# %%
print(L[2])
print(len(L))
# Out:
# {'review': '?? 브루스 윌리스 선천적 대머리는 아니였나봐요?', 'rating': 6, 'title': '마지막 보이 스카웃'}
# 9228

# %%
# 리뷰와 평점에 대한 데이터를 데이터프레임에 저장
df_movie = pd.DataFrame({
    "rating" : [ L[i]['rating'] for i in range(len(data))],
    "review" : [ L[i]['review'] for i in range(len(data))],
})

# 평점을 Negative(0), Neutral(4-8), Positive(8-10) 로 나누고, class 라는 column으로 데이터프레임에 저장
emotion_class = ["POS" if df_movie.iloc[i]['rating'] >= 8
                 else
                 "NEU" if df_movie.iloc[i]['rating'] >= 4
                 else
                 "NEG"
                 for i in range(df_movie.shape[0])]
df_movie["class"] = emotion_class

# 피클로 저장하기
df_movie.to_pickle("./df_movie_review.pkl")
df_movie = pd.read_pickle("./df_movie_review.pkl")

# %%
dist = df_movie.groupby(["class"]).size()
dist = dist / dist.sum()
fig, ax = plt.subplots(figsize=(12,8))
sns.barplot(dist.keys(), dist.values);

# %%
twitter = Okt()
def tokenizer_twitter_morphs(doc):
    return twitter.morphs(doc)

def tokenizer_twitter_noun(doc):
    return twitter.nouns(doc)

def tokenizer_twitter_pos(doc):
    return twitter.pos(doc, norm=True, stem=True)
    
    
komoran = Komoran()
def tokenizer_noun(doc):
    return komoran.nouns(doc)

def tokenizer_morphs(doc):
    return komoran.morphs(doc)

# %%
# Tokenized review 도 데이터프레임에 추가
df_movie['token_review'] = df_movie['review'].apply(tokenizer_twitter_morphs)

# Stop words 정의하기
stop_words = """. 으로 이 에 가 을 는 은 다 이다 게 돼 있지 없지 에서 입니다 ,, 였고 않는 하고 같아요 였다 때문 하는 명의 왔습니다 으로서
 이렇게 그렇게 저렇게 그런 그래도 된다 번은 에선 가면 뭔가 하시는데 싶게 이라 줍니다 봤는데 이제 이었어요 었어요
 크히히 나니 있는 라고 이었습니다 이런게 하며 아니라며 웬만하면 있네요 였습니다 로다 이라는 할만큼 이라 해서 하고 
 사 고 하라 하기 주는 보니 하게 까지 해서인지 였네요 에게 에 게 ~ ~~ ~~~ 하며 하고 했네 ...? ..? ....? 라니 더니
 그냥 없다 있다 하면 엇 급 진심 따름 이나 그리고 도 나 너 우리 ! !! !!! ? 함 임 거 겠죠 더 였어요 의 ~ 이런 저런 는데 됐 없는 수 
 한당 들
"""
stop_words=stop_words.split()

# Preprocessing/filtering function
def filtering_function(token_list):
    result = []
    for e in token_list:
        if e not in stop_words and len(e) >= 2:
            result.append(e)
    return result

# Token_review 를 filtering_function 이용하여 필터링
df_movie["token_review"] = df_movie["token_review"].apply(filtering_function)
# filtering function
# input: token list
# output: filtered token list

# 전체 데이터프레임 Top 10 출력    
print(df_movie.head())    

# 문장 단위의 토큰을 하나의 리스트로 모아서 모든 리뷰의 문장의 토큰을 확인
tokens = [ t for d in df_movie['token_review'] for t in d if t not in stop_words and len(t) >= 2]
print(tokens[:20])
print(len(tokens))

# 토큰 데이터를 nltk.Text로 묶는다.
text = nltk.Text(tokens, name = 'NMSC')
print("=================Number of Tokens=============")
print(len(text.tokens))
print("\n")
# set 으로 묶음으로서 중복 제거한 토큰의 갯수
print("===============Number of Unique Tokens===========")
print(len(set(text.tokens)))
print("\n")
# 가장 많이 나온 Top 10개의 토큰
print("==================Top 10 Token==================")
print(text.vocab().most_common(10))
print("\n")

# 가장 적게 나온 하위 10개의 토큰
print("=======+==Top 10 Token from the bottom==+=======")
print(text.vocab().most_common()[:-20:-1])
print("\n")
# Out:
#    rating                                             review class  \
# 0      10                              끝나고 나서도 여운이 가시질 않는다ㅠㅠ   POS
# 1      10                                    너무 너무 재미있었어요 강추   POS
# 2       6                        ?? 브루스 윌리스 선천적 대머리는 아니였나봐요?   NEU
# 3      10                                    잘 만든 영화인 것 같아요~   POS
# 4      10  유기견들을데리고 CG안하고 찍은점과 촬영후 250마리의 모든 유기견들의 가족을찾아준...   POS
#
#                                         token_review
# 0                       [끝나고, 나서도, 여운, 가시질, 않는다, ㅠㅠ]
# 1                               [너무, 너무, 재미있었어요, 강추]
# 2                  [??, 브루스, 윌리스, 선천, 대머리, 아니였나, 봐요]
# 3                                          [만든, 영화인]
# 4  [유기견, 데리, CG, 찍은, 촬영, 250, 마리, 모든, 유기견, 가족, 찾아...
# ['끝나고', '나서도', '여운', '가시질', '않는다', 'ㅠㅠ', '너무', '너무', '재미있었어요', '강추', '??', '브루스', '윌리스', '선천', '대머리', '아니였나', '봐요', '만든', '영화인', '유기견']
# 87206
# =================Number of Tokens=============
# 87206
#
#
# ===============Number of Unique Tokens===========
# 18075
#
#
# ==================Top 10 Token==================
# [('영화', 3376), ('..', 1503), ('너무', 1205), ('...', 1076), ('진짜', 850), ('연기', 647), ('생각', 538), ('스토리', 503), ('정말', 456), ('배우', 414)]
#
#
# =======+==Top 10 Token from the bottom==+=======
# [('불평등하고', 1), ('가안', 1), ('일반인', 1), ('전자', 1), ('5.5', 1), ('싶으니', 1), ('믿어주던', 1), ('원화', 1), ('가져가는게', 1), ('적셨다고해', 1), ('Them', 1), ('달콤함', 1), ('있기나', 1), ('version', 1), ('gg', 1), ('끝났나', 1), ('장진영', 1), ('쉬웠고', 1), ('잔인했다', 1)]

# %%
import numpy
from matplotlib import pyplot
# 각 Token의 갯수의 평균/분포
result = [len(token) for token in tokens]
# Tokenized 된 각각의 리뷰를 띄어쓰기 조인한 갯수
result = [len(' '.join(token)) for token in df_movie["token_review"]]
# 오리지날 리뷰의 단어 갯수 (tokenization 전)
result = [len(token) for token in df_movie["review"]]

print("Mean %.2f words (%f)" % (numpy.mean(result), numpy.std(result)))
# plot review length
pyplot.boxplot(result)
pyplot.show()
# Out:
# Mean 39.40 words (32.010275)

# %%
sns.set_style("darkgrid")
sns.set_palette('hls')
text.plot(20)

# %%
#TfidfVectorizer usage example

from sklearn.feature_extraction.text import TfidfVectorizer
corpus = [
    'This is the first document.',
     'This document is the second document.',
    'And this is the third one.',
    'Is this the first document?',
]
vectorizer = TfidfVectorizer(max_features=5, analyzer='word', stop_words=['the', 'and'])
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())
print(X) # len(corpus) X len(tokens)

#    1 2 3 6 8 -> document first is the this -> this is the first document
# Out:
# ['document', 'first', 'is', 'one', 'this']
#   (0, 4)	0.41599287732132745
#   (0, 2)	0.41599287732132745
#   (0, 1)	0.6284926983612038
#   (0, 0)	0.5088190052882249
#   (1, 4)	0.35390037003624897
#   (1, 2)	0.35390037003624897
#   (1, 0)	0.865741910835101
#   (2, 4)	0.41988017955138635
#   (2, 2)	0.41988017955138635
#   (2, 3)	0.8046124965719778
#   (3, 4)	0.41599287732132745
#   (3, 2)	0.41599287732132745
#   (3, 1)	0.6284926983612038
#   (3, 0)	0.5088190052882249

# %% [markdown]
# ## Define stop words and vectorizer

# %%
# Define Stop words 
stop_words = ". , 으로 헐 헉 이 에 가 을 는 은 다 이다 게 돼 있지 없지 에서 입니다 ; ,, ,,, 였고 않는 하고 같아요 였다 때문 하는 명의 왔습니다 으로서 이렇게 그렇게 저렇게 그런 그래도 된다 번은 에선 가면 뭔가 하시는데 싶게 이라 줍니다 봤는데 이제 이었어요 었어요 크히히 나니 있는 라고 이었습니다 이런게 하며 아니라며 웬만하면 있네요 였습니다 로다 이라는 할만큼 이라 해서 하고 사고 하라 하기 .... 주는 보니 하게 까지 해서인지 였네요 에게 에 게 ~ ~~ ~~~ 하며 하고 했네 ...? ..? ....? 라니 더니 그냥 없다 있다 하면 엇 급 진심 따름 이나 그리고 도 나 너 우리 ! !! !!! ? 함 임 거 겠죠 더 였어요 의 ~ 이런 저런 는데 됐 없는 수 한당 들"
stop_words=stop_words.split(' ')

# Convert a collection of raw documents to a matrix of TF-IDF features.
vectorizer = TfidfVectorizer(max_features=300, analyzer='word', stop_words=stop_words, tokenizer=tokenizer_twitter_morphs)
#X = vectorizer.fit_transform(df_movie["review"])
#print(vectorizer.get_feature_names())

# %% [markdown]
# ## Classifiers with accuracy scores

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

lr_tfidf = Pipeline([('vect', vectorizer), ('classifier', LogisticRegression(C=10.0, penalty='l2', random_state=0, solver='lbfgs', multi_class='auto'))])

# Split train and test data
num_data = len(df_movie)
num_train = int(num_data * 0.8)
num_valid = int(num_data * 0.1)
num_test = num_data - num_train - num_valid

X_train, y_train = df_movie["review"][:num_train], df_movie["class"][:num_train]
X_valid, y_valid = df_movie["review"][num_train:num_train+num_valid], df_movie["class"][num_train:num_train+num_valid]
X_test, y_test = df_movie["review"][num_train+num_valid:], df_movie["class"][num_train+num_valid:]


lr_tfidf.fit(X_train, y_train)
y_pred = lr_tfidf.predict(X_valid)
print('first classifier:', accuracy_score(y_valid, y_pred))
print('all POS classifier:', accuracy_score(y_valid, ['POS'] * num_valid))
print('all NEU classifier:', accuracy_score(y_valid, ['NEU'] * num_valid))
print('all NEG classifier:', accuracy_score(y_valid, ['NEG'] * num_valid))
# Out:
# C:\Users\ohmgs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:757: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# first classifier: 0.7310195227765727
# all POS classifier: 0.6908893709327549
# all NEU classifier: 0.1420824295010846
# all NEG classifier: 0.16702819956616052

# %% [markdown]
# ### Naive Bayes

# %% [markdown]
# The multinomial Naive Bayes classifier is suitable for classification with discrete features (e.g., word counts for text classification). The movie review ratings are composed of intergers, so it would be suitable to use the multinomial Naive Bayes classifier to evaluate the accuracy. The multinomial distribution normally requires integer feature counts.

# %%
# We will use Multinominal Naive Bayes as our model
from sklearn.naive_bayes import MultinomialNB

# %%
# Train a Multimoda Naive Bayes classifier

nb_clf = Pipeline([('vect', vectorizer), ('classifier', MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))])
nb_clf.fit(X_train, y_train)
y_pred = nb_clf.predict(X_valid)
print('first classifier:', accuracy_score(y_valid, y_pred))
# Out:
# first classifier: 0.7331887201735358

# %%
print('all POS classifier:', accuracy_score(y_valid, ['POS'] * num_valid))
print('all NEU classifier:', accuracy_score(y_valid, ['NEU'] * num_valid))
print('all NEG classifier:', accuracy_score(y_valid, ['NEG'] * num_valid))
# Out:
# all POS classifier: 0.6908893709327549
# all NEU classifier: 0.1420824295010846
# all NEG classifier: 0.16702819956616052

# %% [markdown]
# ### SGC(Stochastic Gradient Descent)

# %%
from sklearn.linear_model import SGDClassifier

sgc_clf = Pipeline([('vect', vectorizer), ('classifier', SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=42))])
sgc_clf.fit(X_train, y_train)
y_pred = sgc_clf.predict(X_valid)
print('first classifier:', accuracy_score(y_valid, y_pred))
print('all POS classifier:', accuracy_score(y_valid, ['POS'] * num_valid))
print('all NEU classifier:', accuracy_score(y_valid, ['NEU'] * num_valid))
print('all NEG classifier:', accuracy_score(y_valid, ['NEG'] * num_valid))
# Out:
# C:\Users\ohmgs\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:144: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# first classifier: 0.720173535791757
# all POS classifier: 0.6908893709327549
# all NEU classifier: 0.1420824295010846
# all NEG classifier: 0.16702819956616052

# %% [markdown]
# Regardless of the classifiers, we can note that the accuracy scores of positive ratings of the movie reviews are much higher than the neutral and negative ratings. This observation may indicate that the classifiers work better on predicting positive ratings..?

# %% [markdown]
# ### Logistic Regression and Ridge Classifier

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import GradientBoostingRegressor

classifiers = [
    ('Logistic Regression', LogisticRegression(penalty='l2', random_state=0, solver='lbfgs', multi_class='auto')),
    ('Ridge Regression', RidgeClassifier()),
    
]

for classifier_name, classifier in classifiers:
    clf_tfidf = Pipeline([('vect', vectorizer), ('clf', classifier)])
    clf_tfidf.fit(X_train, y_train)
    acc_train = accuracy_score(clf_tfidf.predict(X_train), y_train)
    y_pred = clf_tfidf.predict(X_valid)
    print(classifier_name, acc_train, accuracy_score(y_valid, y_pred))
# Out:
# Logistic Regression 0.7730967217556218 0.737527114967462
# Ridge Regression 0.7680845299376863 0.7429501084598699

# %%
print(classifiers[0][1])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
print(classifiers[1][1])
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='auto',
#         tol=0.001)

# %% [markdown]
# #### Ridge Regression Accuracy

# %%
rg_tfidf = Pipeline([('vect', vectorizer), ('classifier', RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
        max_iter=None, normalize=False, random_state=None, solver='auto',
        tol=0.001))])

# %%
rg_tfidf.fit(X_train, y_train)
y_pred = rg_tfidf.predict(X_valid)
print('first classifier:', accuracy_score(y_valid, y_pred))
print('all POS classifier:', accuracy_score(y_valid, ['POS'] * num_valid))
print('all NEU classifier:', accuracy_score(y_valid, ['NEU'] * num_valid))
print('all NEG classifier:', accuracy_score(y_valid, ['NEG'] * num_valid))
# Out:
# first classifier: 0.7429501084598699
# all POS classifier: 0.6908893709327549
# all NEU classifier: 0.1420824295010846
# all NEG classifier: 0.16702819956616052

# %% [markdown]
# ## CNN

# %%
import re
import csv
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from keras import callbacks
from keras.preprocessing import sequence
from keras.models import load_model
from keras.utils.vis_utils import plot_model
from keras.utils import np_utils

# %%
# Creating Callbacks
# ModelCheckpoints is used to save the model after every epoch
# EarlyStopping is used to stop training when the validation loss has not improved after 2 epochs
# Tensorboard is used tovisualize dynamic graphs of the training and test metrics
cbks = [callbacks.ModelCheckpoint(filepath='./checkpoint_model.h5', monitor='val_loss', save_best_only=True),
            callbacks.EarlyStopping(monitor='val_loss', patience=2),callbacks.TensorBoard(log_dir='./logs', histogram_freq=0, write_graph=True, write_images=False)]

# %%
# Final Model Architecture
# embedding layer size

from sklearn.preprocessing import OneHotEncoder
from collections import defaultdict
embedding_vector_length = 32

X_train_token = df_movie["token_review"][:num_train]
X_valid_token = df_movie["token_review"][num_train:num_train+num_valid]
X_test_token = df_movie["token_review"][num_train+num_valid:]

all_tokens = []
for tokens in X_train_token:
    all_tokens += tokens

token2ind = defaultdict(lambda:7777)
ind2token = []
for ind, token in enumerate(set(all_tokens)):
    token2ind[token] = ind
    ind2token.append(token)

X_cnn_train = X_train_token.apply(lambda x:list(map(lambda i:token2ind[i], x)))
X_cnn_valid = X_valid_token.apply(lambda x:list(map(lambda i:token2ind[i], x)))
X_cnn_test = X_test_token.apply(lambda x:list(map(lambda i:token2ind[i], x)))

def to_one_hot(y):
    enc = OneHotEncoder(sparse=True) # Key here is sparse=False!
    return enc.fit_transform(np.array(y).reshape(len(y), 1))

y_cnn_train = to_one_hot(y_train)
y_cnn_valid = to_one_hot(y_valid)
y_cnn_test = to_one_hot(y_test)
#print(y_cnn_train)

#y_cnn_train = y_train.apply(lambda x:0 if x == 'NEG' else 1 if x == 'NEU' else 2)

# %%
#np.resize(input_tr, (-1, <image shape>)

model = Sequential()
model.add(Embedding(19479, embedding_vector_length, dropout=0.2))
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=2))
# 1 layer of 100 units in the hidden layers of the LSTM cells
model.add(LSTM(100))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())

model.fit(X_cnn_train, y_cnn_train, validation_split=0.20, epochs=5, verbose=1, batch_size=32, callbacks=cbks)
# Out:
# C:\Users\ohmgs\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.
#   after removing the cwd from sys.path.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_55 (Embedding)     (None, None, 32)          623328
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, None, 32)          3104
# _________________________________________________________________
# max_pooling1d_55 (MaxPooling (None, None, 32)          0
# _________________________________________________________________
# lstm_55 (LSTM)               (None, 100)               53200
# _________________________________________________________________
# dense_55 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 679,935
# Trainable params: 679,935
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 5905 samples, validate on 1477 samples
# Epoch 1/5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-190-8ec9b7f4c80c> in <module>()
#      11 print(model.summary())
#      12
# ---> 13 model.fit(X_cnn_train, y_cnn_train, validation_split=0.20, epochs=5, verbose=1, batch_size=32, callbacks=cbks)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2617                 array_vals.append(
#    2618                     np.asarray(value,
# -> 2619                                dtype=tf.as_dtype(tensor.dtype).as_numpy_dtype))
#    2620         if self.feed_dict:
#    2621             for key in sorted(self.feed_dict.keys()):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: setting an array element with a sequence.

# %%
print(model.predict(input_valid))

# %% [markdown]
# ### Get the prediction output

# %% [markdown]
# Using Logtistic Regression classifier

# %%
# Logistic Regression
selected_clf = classifiers[0][1]
clf_tfidf = Pipeline([('vect', vectorizer), ('clf', selected_clf)])
clf_tfidf.fit(X_train, y_train)

y_pred = clf_tfidf.predict(X_valid)
for review, answer, predicted in zip(X_valid, y_valid, y_pred):
    print("Review {}\nOriginal Rating: {}\nPredicted Rating: {}\n".format(review, answer, predicted))
# Out:
# Review 재미있어요 좋아요 지루할때쯤 빵빵터짐 무겁지만 재미있게 풀어낸 이야기
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저녕 볼만햇네욯ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공포영화인듯 아닌듯?!ㅋㅋㅋ 근데 공포영화보다 더 무서웡ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 진짜 스토리 탄탄하고 김윤석 배우님은 말할것 없고주지훈 연기 미쳤네요 영화보는내내 답답해죽는줄 알았어요 연기 너무잘해서 마지막에 너무 애잔하고 실화바탕이어서 그런지 마음에 더 와닿는 영화였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여자친구가 귀신은 안무서워 하는데사람은 많이 무서워하넹^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개무서워서 혼낫네 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김성오 배우분이 연기를 너무 잘해서 재밌게봤어요 모든 잘 어울리는 배우인거 같네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아름답고 신비한 영화였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제나 다시봐도 명작 마지막 컷  주인공 가정부와  친구의 대화가 진한 여운을..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미가 너무 아름다웟다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 편집을 심각하게 한건지 영화가 심각한건지 구분이 안된다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 난 정말 재미나게 봤다. 산사태가 어이없었지만 실제 있었던 일이라 그려러니 함.살려달라는 말에 아무도 나와보지 않는.. 그러나 그게 현실이며 나역시 나가보지 않을거임. 영화를 보면서 방관자 입장일때는 공감을 많이 했고 목격자일때는 너무 무서웠던 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 때깔보고 존나 삐급영환가보네 했는데 출연진보고 개놀랐네 어쩐지 연기들은 좋더만
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 영화는 대작인데 견자단이 마지막에 죽은게 안타깝네ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아쉬운 부분이 많지만 브루스칸 액션은 역대급
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 무서운 영화, 혼자라서 더욱 공감되요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 12세딱지때부터 느낌이 싸했으나, 디즈니 느낌으로다 보면 즐겁게 감상하고 올수있음 크게 실망할 정돈아님
# Original Rating: POS
# Predicted Rating: POS
#
# Review 맘에 들고 안들고를 떠나서, 이런 영화는 그냥 10점 줍시다~!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연출도 좋고 다괜찮은데 억지가 좀 있습니다 억지가 한두개가 아니에요ㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 어느 쪽이 알바인지 알수가 없네 ㅎㅎㅎ
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 의심이란 병은 하나님도 치료 하시지 못하는군요. 진실을 보는 현명함을 주소서!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인물들의 행동에 개연성이 없는점,갑작스런 인물등장과 소개미흡 이 두개만으로도 이 영화는 1점이다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 졸라 재미없음 최악. 영화 진짜 현실성없고 억지임. 저정도면 공효진이 공범. 그리고 요즘 저렇게하는 경찰 없음. 이 영화 쓴 사람은 이렇게 돈벌어먹으면 천벌 받음.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 90년대 중반 영화를 감안하면 수준급 연출이나 당시 배우들의 연기력은 안쓰럽다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 최근 본 영화중에는 참..참담하네요 ㅎ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 바람 같던 우리들의 바람
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이때 까지 본 스릴러 장르중에 제일 재밌음ㅋㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 이게 적당하다고 생각합니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 부모를 위험으로 내몰고, 개는 미세먼지에 아무렇지도 않으며,하여간 개연성 없음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 재밌는데 졸린거왜그럼
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 완전 인생영화!!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제일검이 제일검같지도 않고... 현실적인 검대결을 생각하는건 알겠는데.. 검동작은 거의 두가지.. 휘두르고 뒤집어서 휘두르고.. 갑자기 왕내면 얘기가 나오더니.. 진짜 어려운 영화인지.. 어술픈 영화인지 감이 안잡힘..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 초등학생 아이들과 재미나게 잘 봤습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범죄영화의 초점은 늘 여자가 피해 보는 현실성 영화지... 현실같은 영화라 손에 땀이 날 정도로 봤다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 50년도 넘은 세월너머 동화책 속에 빠져있던 어린 내모습이 생생하게 보이네요.이건 나같은 어른들을 위한 영화같습니다. 이야기속에 현실세계를 보여주는 진실함에 고개를 끄덕였습니다.9점정도는 됩니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㄹㅇ 와 예매권 받아서 봤는데 진짜 예쁘누ㅠ뉴뉴ㅠㅠㅠ 반전도 있고 재밌게 봤당 돈 주고 봐도 아깝지 않겠더요 그리고 ?인간들 개웃기누 니들 재미없다고 사람들 다 재미없어야 되냐 수준 유딩이고 ㅋㅋㅋㅋ 난 ㅈㄴ재밌었다 개추천 ㅠㅠ ~~~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 갓에이미세요 주체적인 캐릭터 캬
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 꼭봐야하는 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 염력보다는 재미있었다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진 너무 좋아요ㅠㅠㅠㅠ연기대박
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 심장이 두근두근
# Original Rating: POS
# Predicted Rating: POS
#
# Review 계속 긴장감도 있고 재밌었습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 노래가 좋았습니다, 요즘 맨날듣고 있어요ㅕ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 흠  약간 아바타정도 스케일임   매드맥스보단   재밋다.  제발 알바들  도어락인가 뭐시기랑 비교  ㄴㄴ
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 아 진빠져....영화다보고 너무 힘들었음..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점1점 박고 주디 터는놈들 특: 개 아싸, 비공감 개 많음 ㅋㅋㅋ사회에 섞이지 못함
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 오~~~~의외로 꿀잼
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재미없다 ..돈아깝다..
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 현시대의 상황이 답답하고 답이없다면 왜그러는지 이유라도 알아야돼지 않겠는가? 절대 잊어서는안될 나라가 망한날. 윤리와도덕이 돈앞에 짖밟히기 시작한날.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 고구마 코로 씹어먹는기분 답답하고 답답하고 또답답
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 몰입도ㅆㅅㅌㅊ 이정도면볼만하다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 노잼에 일관성도 부족. 절제미도 없고 양식도 없고 그냥 겉멋만 들어서 모든 것이 너무 과함.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 엄청 무서워요,, 진짜 자취하는 여성분들은 더 더욱 그럴거 같아요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는내내손에땀을쥐게한~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미없어요 보지마세요 조작된고같음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 어릴때 엄마 아빠가 보길래 어린 마음에 쎈 척 하고 싶어서 봤다가 그 트라우마가 10대 시절 내내 날 괴롭힘;;; 이제 내나이 곧 30인데 지금도 불 다 끄고 잠 못잠 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 조조영화 각보고 있는데 평점이랑 CGV 개봉시간 보는데 아다리 맞음 영화 시간대 다른 영화에 비해 현저히 적음 차라리 도어락봐야겠음 ㅋㅋ 개이득
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 학생으로서 공감 가긴 하지만 결국은 일진들에게 기회를 많이 줘야된다는 개소리를 외쳐버리네.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 개봉하자마자 보러갔는데 기절할뻔 친구랑 손 꼭 안잡고보면 기절합니다 강철심장만 보세요 ,, 집와서도 침대밑만 보게되고 싸이코범인 밖에 생각안납니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 재미만 있는데요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연달아서 두번 본 첫 영화입니다. 홍보가 너무 B급스러웠어서 안 유명해진것 같아요. 대화 거의없이 독백이고 설정도 특이한데 연기 톤도 너무 좋아요. 신파도 안좋아하고 멜로도 그닥인 저에게 최고의 영화에요. 지금도 가장 좋아하는 영화는 김씨표류기에요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 옛 군대에서 바뀌어가는 모습을 잘 표현했습니다.근데..군대 다녀온 사람들이한거 맞습니까?요즘 어린 친구들의 군생활이겠죠.요즘에 티비에서 하는 연예인들 군생활하지 않았으면 좋겄습니다.글쓴이 해병1037기 2시단 입니다실무생활 해봤어?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 개연성이없고  각본이나 감독의 연출력도 부족한 수준이 낮은영화. 소재는 참좋았음.좀더 치밀하고 완성도있게 만들었다면 꽤 괜찮았을 영화.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 굳굳굳굳 재미있었어요 ㅎㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이와 시간 보내기에 괜찮은편입니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 말이 필요없는 명작. 로맨스와 신파의 완벽한 하모니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역사드라마, 공포, 레즈, SF액션을 섞었는데 SF 액션은 없었으면 더 좋았을 것 같다. 키히라 '주보비' 연기는 인상적이었고 박보영은 일본사람으로 태어났더라면 더 인기 많았을 것 같다. 이해영이 소녀들과 일하고 싶어서 찍은게 아닐까?
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 7.8정도가 적당함 주작 8.63 에바 그래서 1점 준다 ㅎㅎ 암튼 돈 아깝지는 않음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반에는 엄청난 소재와 그래픽에 흥분했고후반에는 엄청난 각본과 중국자본에 흥분하는 박진감 넘치고 손에 땀을 쥐게하며 내적으로 소리지르게되는 스릴만점 영화!!
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 상영관 좀 늘려주세요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 상영관 수가 적어 밤12시에 봤는데졸음이 오지 않는 영화입니다.2시간이 정말 빠르게 지나갑니다.안보면 후회 할 영화입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고최고 발동동 구르며 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 공포감 킬링타임용 강추. 역시사람이 제일무섭다ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화가 이래야죠.관객을긴장하게하는영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 손을 꽉 움켜쥐고,소리내지 말아야겠다하면서 봤는데,역시나.끝까지 긴장감을 가지고 봤어요.강추!!입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김혜수 김혜수 김혜수 이 세글자로 끝이다 이 영화는.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 동심으로 돌아온 것 같아요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화중에 앞사람이 인스타해도 화안나는영화...자극적이지만 더럽게 맛없는 요리같은 영화...
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이준혁씨 모습.연기가 그나마 압권..나머지는 무의미..배우들이 아깝다..감독이 독립영화수준정도..
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 재미있게 보았습니다. 이런게 S F 죠
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 무서워서 도중에 뛰쳐나오고 싶었음...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 혼탁해진 내 정신과 육체가 깨어나는 느낌. 부림사건의 가해자들은 아직도 떵떵거리고 살고 있다는 것에 분노를 느낀다. 진심으로 그 변호사를 존경하며 우리곁에 없다는 것이 정말 그립고 슬프다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 웬만하면 야구 다큐는 기본은 하는데~
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진이연기를너무잘한다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review ㄹㅇ감동적인영화한번더보고싶다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 36개월아들 재미있게 잘 봤어요!ㅎㅎㅎ아빠없는 주말 잘 보냈네용ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 첫번째 봤을때는 음악에 감동하고, 두번째 봤을때는 인생에 감동하는 영화. 세번째 보면 어떤 느낌일지 기대되는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보고나면 찝찝하지만 그만큼 잘만들었음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 모두 난해하다고 평한 것에 비해 나는 즐기며 보았다.영화를 위한 영화라는 표현에 공감.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 순간순간 마음 졸이고 놀라게되니 방심은 금물
# Original Rating: POS
# Predicted Rating: POS
#
# Review 반전의 반전의 서스펜스
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴러 영화의 정석입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 원래 액션 SF 그냥좋아함잘봤어요~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실화라서 더 감동적 이네요 제 인생 영화가 아닐까 합니다. 물론 8분 보고 껐습니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 오랜만에 꿀잠잤다 ....
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 영화는 정말 재미있게 잘 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 감정이입 하나도 안되고 보는 내내 졸았다 하.. 내 11000원
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 말이 필요한가? 일단 봐라
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재미없어요. 졸다 나왔습니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내가 여지껏 경험한 것들 중 가장 완벽한 창작물.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 형제자매들이 죽어가던때 인간적인 마음으로 얼마나 똑같이 응징하고 싶었을까. 그러나 순간마다 예수님의 말씀을 기억하며 그 고난들을 통과해나갔던 제자들..오늘날 우리가 기억해야할 부분..신체가학성 강조한 패션오브크라이스트와 비교안되는 훌륭한 영화.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 알바들이신가.. 물론 지금 개봉한거중에서는 나름 볼만한 급인건 맞는데.. 노잼에 똑같은 래퍼토리 반전스토리.. 개연성 부족하고 답답하기 그지없고 보기 불편한 영화인데
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 공효진 연기 짱잘해 ㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 다른건.이미다른분들이 다써서.. 하필그때와이프가불키고. 하필그때 전화오고..잘싸우다가 망치는 왜두고 도망가고..경찰은 너무쉽게 기습당하고..의도하는바는 알겄으나..ㅜ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 재밋어요 너무 잼있어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 손예진 그냥 여신이다. 커피한잔같이 하면 소원이없을듯
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 각자의 취향에 따라 최고도 최하도 된다. SF 좋아하고 상상력 좋아하고 볼거리를 추구한다면 이 영화가 딱이다. 재미보다 감동, 교훈이 좋은 사람에겐 비추한다. 이런 영화는 시각적으로 환상적이니 이왕이면 대형화면이 좋다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 타임킬링용 영화. 스토리 자체는 누구나 한번쯤 생각했던 스토리. 그래도 스릴은 인정.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이미 있는 동화를 90분 동안 전개하려면 스토리 구성에 신경을 써야했는데 너무 부실함. 영상미도 최근 개봉한 곰돌이푸, 미녀와야수, 신데렐라에 비해 너무 허접함. OCN에서 보여주는 옛날 영화랑 별 다를 게 없음. 클라라와 생쥐가 캐리함.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 차라리 연극을 하는 게... 참으로 불편한 연출.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 똥망 스토리. ㅗ ㅗ ㅗ ㅗ
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 보는 내내 공연에 소름. 예술가의 삶
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소름끼치고 무서웠어요 귀신보다 사람이 더 무섭네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 닥터 스트레인지하고 비슷한 느낌..그래픽은 좋고 스케일도 큰데 스토리나 개연성에 흠이 있음
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 아이들이 좋아하네요^^
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 순수하게 재미있는 영화는 다시봐도 재미있다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청 무서울정도는 아니지만 재밌게 잘 본거같아요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반에는 약간 볼만하다가 나중에는 실소 나옵니다. ㅋㅋㅋ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 컨트롤씨 컨트롤브이 음악시대에좋은 교훈을 주는 아티스트다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말너무너무너무너무잼난다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여운이 깊은 영화였다. 먼가 빨리감기같아서 조금 아쉬웠지만  재미있었고 퀸이 왜 전설인지 알것같았다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이게 전미박스오피스 1위라면 내가 폰으로 아무거나 찍어도 1위 하겠다. 살인마나 등장인물이나 하나같이 암걸리게 만드는 개졸작
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 여기다 스포한ㅅㄲ땜에 18
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화보고  돈 아깝다는 생각이 ...이영화 저영화  짜집기에 유치하기  짝이없고.딱  집에서  보기에  알맞은 정도
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 존x 지루함 진짜..대박이네
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이 영화는 청소년들 보다는 부모님의 곁을 떠난 성인들이나 자식을 둔 부모님들이 보기에 매우 적합한 영화라고 생각합니다.... 진짜 보면서 공감되는 점도 많았고 나중에 기회가 되면 부모님에게 보여드리고 사랑한다고 전해드리고 싶네요ㅠㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몇안되는 평가 정말 조작같다.. 아무리 독립영화라해도 너무 어설픈연기..발음..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 3개의 다른 왕국들이 하나같이 아름답고 예뻤다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 테러하는 것들은 내 기준 다 댓글알바다 그래서 10점짜리는 결코 아닌데 10점 준다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜곡도 정도껏합시다 참
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 0점 못주나.. 철지난 드립 개그 초반 지수와 동철이 차에서 나눈 만담은 내가 창피했고 수 많은 명대사를 기대했지만 그러지 못했다. 결론 평점은 주작쓰다.
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 심장이 쫄깃!!배우들 연기도 너무 좋았어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미가 장난 아니던데.... 엄청 재밌을것 같습니다!!! 알바 용돈 모으면 이번달 말에 꼭 보고 싶네여!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막장면에 황정민이 유아인 반죽여 놨으면 더 속 시원했을 영화 마지막이 아쉬움
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 뒤에 이야기를 꼭 보셔야 합니다 삼전도의 굴욕 이후에 최명길과 김상헌이 청나라 감옥에서 서로 오해를 플고 화해하며 시로 우정을 나누는 모습이 큰 감동을 줍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한국 영화중 최고인것같아요이런 긴장감주는 스릴러물  드물어요  꼭보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 북한인간들은 뼛속 깊이 통수를 치는 dna를 가진거같다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 좋고, 음악 멋지고, 스펙타클함
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 동상 걸렸다며 업히거나 부축받아 다니던 여기자가 갑자기 총알 쏟아지자, 절벽위로 뛰어가는 모습  ㅋㅋㅋ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 3번봤다... 개인적으로 ABBA도 영화화했으면
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도저히...보기가 힘들정도로 별로였다. 결국 중간에 시청중단..
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 진짜 별한개도아깝다 개뻔한전개 와이딴영화가 20OOO에나온다니ㅋㅋ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 지금 봐도 옛날 영화라는 생각이 안들정도로 촌스럽지 않다..놀랍..(￣O￣;)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼴페미코인 편승하려는 수준낮은 감독이만든 수준낮은 영화.  전작만봐도 이걸 극장에서봐야하나 말아야하나 감이올거임
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반부터 스릴 대박이던데 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 1점 주기도 아깝다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 뮤서워서 혼났어용 ㅠ 으헝 진짜 꼭 보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 수납형침대로 바꿔야겠군..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 눈물나요 ㅠㅠ안타깝고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 메갈들도 보쥣물 질질싸게만들 그래픽만으로도 충분히 아이맥스로 볼 가치가 있다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 손에 땀을 쥐게하는 스릴 넘치는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화가 끝나고도 눈물이 나는 영화 집에있는 우리 강아지들이 너무 보고싶어지는 영화 잘봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리도 너무 좋고 남주여주 케미도 너무 좋아서 너무 재밌게 보았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 라면 지가 다처먹었으면서.. 진짜 팍머리를 쥐어박고싶당ㅎㅎㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 남친이랑 보러갔는데 남친 롱패딩 입은 이유가 무서운 장면 나오면 가릴려고 가림막용으로 갖구 온듯-!그렇게 무섭진 않았는데 긴장감이 컷음ㅎㅎ 하지만 영화가 영화인지라...결말은 안봐두...ㅋㅋㅋㅋ뻔할 뻔 스토리ㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 시작부터 숨막히던데여ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 뒤로갈수록 아는노래 많이나와서 신나게 감상하고 옴
# Original Rating: POS
# Predicted Rating: POS
#
# Review 눈이 즐겁고 기분이 좋아지는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 앞부분은 좀 유치하고 지루함. 뒷부분은 그럭저럭 볼만한데 전개가 아동용 동화스러움. 원래 호두까끼 줄거리가 이런가.. 제일 기억에 남는건 쥐. 쥐가 귀여웠네요. 아무튼 그래도 판타지영화를 좋아해서 5점..후하게 드렸네요..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 인생 최고의 영화...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 결국 또하나의 선택지에서 약을 포기하는걸 보고 아 이게 미소구나. 싶었던.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 참 애매한 영화. 박보영 예쁘고 연기 잘하지만 순 억지 투성이인 전개와 우연에만 의존한 스토리 진행... 영화인걸 감안해도 참 몰입하기 힘든 영화였음. 딱 오락영화, 그 정도 수준.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 걍...기생수 미국판아님?" 스파이더맨 어쩌고해서봣더니 기생수 미국판인데? 그래도 밥먹으면서 볼만함
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 조미료 없는 집밥치유와 화해의 바당
# Original Rating: POS
# Predicted Rating: POS
#
# Review 억지로 공포를 조성하는 다른 영화와는 다르게 일상 생활에서 누구나 겪을만한 일들을 소재로 해서 더 무섭게 다가온것 같습니다. 범인도 누군지 계속 헷갈리는 점도 좋았습니다. 끝까지 긴장을 멈출 수 없엇고 잊혀지지 않는 1784....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화후기 처음 남겨봄. 너무 재미없고 기분이 나쁜 영화였다. 스릴러 장르를 좋아해서 봤는데 돈이 아까울정도... 공효진의 연기는 좋았으나 캐릭터가 너무 고구마였다.  공포심만을 주기 위해 만든 영화같고 반전같지도 않은 반전이 영화를 더 재미없게 함.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 마무리가 조금 아쉽긴했지만 기대했던만큼 재밌게 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 코미디영화인줄 ㅎㅎ 재미있게 봤습니다아~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각지 못했던 달의 의미,꼬이고 꼬인 너저분한 관계,평행세계같은 판타지적인 요소,박민수씨의 하드캐리가 돋보이는 수작.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진이 아깝 지루햇네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 알바 너무 심함 이게 무슨 9점이 넘냐
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 스릴대박 완전 무서웠음ㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한줄평 첨남겨요..슬프거나 그러거전혀없는데 내눈엔 눈물이 주르륵. .
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무신났당 다따라불렀당
# Original Rating: POS
# Predicted Rating: POS
#
# Review 탄탄한 구성과 실감나는 장면이맔은 편안하게 볼 수있는 영화네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 좋은 영화같다. 그렇지만 느린 전개와  기억의 편린들이 뒤죽박죽 섞여  짜증이 난다.  탈북자의 액받이가 된 기분이다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 어린 조카가 너무 좋아해요!!ㅋㅋㅋ 또 보자고 하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어거스트가 웃을때 진짜 행복해 보여ㅜㅜ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화보고 난 후 이 여운만큼은 타이타닉과 견줄만하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도대체 영화가 뭘 말하고 싶은 건지 모르겠다. 좋아하는 CG가 트랜스포머 변신 로봇처럼 멋지게 여러 차례 나왔으나, 영화의 의도를 전혀 모르겠다. '"왜?"를 끊임없이 묻고 싶다..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 정말 즐거워했어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제나 스파이더맨1편은  왜  이리도  엉성하냐!    샘  레이미의  2편은   정말  대역작 이엇구나 라고  다시한번  느낌.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 도어락 정말 무섭게봣어여
# Original Rating: POS
# Predicted Rating: POS
#
# Review 프리미엄관에서 19000주고 본내자신이 ㅈㄴ한심하다 멋진 세계관인건 맞는데 등장인물들 지능수준이 의심될정도로 전개가 엉망
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 너무너무재미있었네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오늘 OCN으로 봤는데, 바토 역을 맏은 배우 연기가 가장 쓰레기고, 모토코와 바토의 관계는 플라토닉해야 원작의 그 맛이 사는데 이건 뭐 진짜 완전 망했다. 보는 내내 욕만 나온다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review ㄹㅇ 1점 주려다 여주 외모때문에 3점 준다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 전설스 최고스 오져스 대박스
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 심장 쫄깃한 영화봤네요 추격자이후로 이렇게 조마조마한건 첨 공블리 연기도 좋았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 되게 뻔한 이야기인줄 알았으나굉장한 수작이 된이야기..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 경민의 모습은 우리 시대의 많은 여성들을 대변하는 듯 하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 긴장감있고 무서웠어요ㅠㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무리 멀리 떨어져 있어도 마음속에 간직하고 있지.기억할게.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이들이 참 좋아하고 잼있습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대한민국 국민, 전세계 사람들이 봐야 한다. 보면서 가슴이 먹먹해지고 억울하고 분노가 치솟았습니다. 더이상의 아픔은 되풀이 되지도, 그저 돈으로만 가치를 매기며 배상이라는 것이라는 이름으로 받아드리면 안된다고 다시 한번 뼈저리게 느꼈습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한 번 더 영화보러 가야겠다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 난 재밌게 봤음. 염정아의 선택이 좀 아쉽지만 아이를 가슴에 묻은엄마의 심정을 헤아릴수없으니 받아들였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 보세요 두번 보세요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굿 입니다 좀더 빨리볼걸
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 결말 행운의 편지ㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴있는영환데 졸려서 힘들었음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이건 진짜 극장에서 안보면 후회할뻔..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한편의 동화 같은 영화. 처음부터 끝까지 아름다운 영상미와 멋진 음악이 함께한다. 스토리는 좀 유치한면이 있지만, 전연령이 볼수 있는 동화를 같이 본다고 생각하면 될듯. 미녀와 야수에 이어서 흑인 배우들을 많이 캐스팅하여 PC적 요소를 넣은건 감점
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 여운을 주는 액션 영화 흥미로운 스토리입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 친구가 새벽에 보러가자해서 저는 제목만 보고서는 "에이 무슨 이런 영화를 봐"라며 투정부렸는데요.. 이 친구가 본인이 티켓살테니 재밌으면 티켓값 돌려달라해서 보러갔습니다. 그리고 영화 끝난 후 9천원 바로 현금으로 줬습니다..갓띵작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무슨 뜻인지 하나도 모를 영화 그냥 아마추어가 대충 짜집기 한 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 덜덜 떨면서 봤음... 도어락이라는 소재로 이렇게 긴장감 넘치게 만들다니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 문득 몇년전 우리집 도어락 누르던 사람이 생각나네
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 긴장감이 최고! 현실에서 일어날 수 있을 법한 이야기라 더 무서웠던거 같아요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사라엄마ㅠㅠ 왜 먼지 속 들어갈 때 물 적신 수건을 안가져간거야..ㅠㅠ 그걸로 입만 막고 갔어도....
# Original Rating: POS
# Predicted Rating: POS
#
# Review
# Original Rating: POS
# Predicted Rating: POS
#
# Review 일단 배우들은 넘좋았음. 김기정역이랑 관리역할 하신분 첨보는 얼굴이었는데 연기 넘잘함. 도어락이란 소재는 현실성이 있어서 와닿았음. 재밌게봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 긴장감이 꾸준하게 이어지는게 좋았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 저 이거 시사회로 봤는데.. 진짜 무섭습니다ㅠㅠ 특히 혼자사는 여자분들 보지 마세요.. 보다가 막판 15분? 정도 못보겠어서 그냥 나왔어요.. 끝날때 들어가서 엔딩크레딧만 보구요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이천희 불쌍하네.... 스릴넘치고 재미써욤
# Original Rating: POS
# Predicted Rating: POS
#
# Review 매켄지 포이의 얼굴과 크리스마스 분위기가 가득한 아름다운 영상미 말고는 노잼인 영화.. CG* 에서만 상영해요
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 유럽에게는 기독교귀신을, 아시아에게는 불교귀신을.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무조건 큰화면에서 봐라. 진짜 재밌음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미는 넘이쁘고 화려한데 스토리가 약하니 보고나서 아쉬움이 많이남네요. 매킨지포이가 헉소리나게 이뻐요.키이라나이틀리 연기는 약간 신동범의 티나가 연상되요ㅋㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 한국 군인은 별거아니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화를 보고난 뒤에 춘천MBC에서 제작한 '코레아일라' 다큐를 보게 되었다. 너무 울어서 얼굴 부었네요~ 문재인정권이 아니였음 흥행도 되고 많이 이슈화되었을듯 한대 아쉽네요. 북괴군의 만행이 너무 적나라하게 고증되니깐 좌빨들 불편하겠죠?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 비주얼이 완전 좋음. 매켄지포이도 완전 예쁨
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아버지 이제야 깨달아요 어찌 그렇게 사셨나요 - 싸이"아버지"中 -
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 북유럽의 경관을 본다는 것만으로도~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 보고 꾹 참고 봤는데 시간 아깝고 모성애도 없고이기적인 엄마라는 이름의 여자..마지막 장면 뭔지...쓰레기영화
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 똥 같은 주인공. 개 같은 경찰. 멍청한 범인
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 마지막에 좀 서운했지만ㅋㅋ 2편 기다려봅니다 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리는 무난평범 예상가는데연기들이 미쳐서몰입도가 높아서 거의 VR이였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여자분들꼭보시오ㅋㅋ나름공감이지만이쁜사람한테만 꼬이는거
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 최악. 상업성도 없는 B급 영화 수준. 어디 대학교 졸업작도 아닌 입학작이 아닌가 생각이 드는 클라스. 저 밑에 별점들은 다 지인들인가여배우 연기는 좋았음. 근데 남자주인공 발연기;;
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 마트를 벗어나는 순간이 거의 없이 같은 톤의 전개인데도 신기할정도로 졸립거나 지루하지 않았다. 누구나 기저에 깔고 살아가는 삶의 고독을 인지할 수 있는 사람이라면 충분히 몰입 가능한 영화. 특히 추운 겨울밤 심야영화로써 멋진 선택.
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 살아생전 못 본 프레디 머큐리의 모습을 보았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감동이 있네요..ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고의 영화임 반전도 쩔고 이상하게 몰입 잘되는 영화.근데 결말 잦 같아서 6점 드림 그냥 짜증남 싫음 마음에 안듦재미있는건 확실함.훌륭한 영화임 결말은 꺼져
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 한참 이슈된지 지나고봤는데 정말 수작이긴 수작임..할리우드판 곡성이라는데 곡성은 생각조차나지않을정도로 기괴하고 우아하고 소름끼친다.엄마역의 토니콜렛 표정연기가 다 한 영화...캐스팅도 찰떡같이 잘한듯,공포스럽게 스멀스멀 옥죄여오는 작품성있는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 잼있는영화 봤음 ^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘만든 영화 재밌게 보고왔어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한국산 좀비물 영화인데기대한 만큼 재미있지는 않았다뜬금없이 주인공이 좀비가 되는 설정도 좀 아쉬웠다
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 여주인공이 사라지는 이유의 타당성을 받아들일 수 있어야지  이 영화를 재밌다고 감동적이라고 할 수 있을거 같다. 늘 하루를 밝게 최선을 다해 살던 소녀의 결말이 저런거라니 너무 허무해서 뒷 내용은 전혀 눈에 들어오지 않았다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 잠이나잘껄... 가슴이답답하다 답답해
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 비주얼은 정말 뛰어났지만 내용을 전달하는 능력은 부족했던 영화. 극중 대부분의 사건을 극적인 장치로만 연결지어버리면 감독은 편할지 몰라도 관객은 흥미를 잃고 지쳐간다. 또한 너무나도 익숙한 레퍼토리는 영화를 보며 앞으로의 내용전개의 기대감을 떨어뜨렸다
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 재미있네요  기대감 크네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 예뻐요 , 재밌게 잘봤어요 !
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기도 만족스럽고 볼만한 스릴..?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜진짜 너무 무섭고 스릴넘쳤다 ㅠㅠ 너무 재맜다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이영화보고 내가 아미라는게 너무 자랑스럽고 오빠들한테도 정말 수고했고 앞으로 건강 잘 챙겼으면 좋겠다고 말하고싶었다ㅜㅜㅜㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사상 최고의 히어로 무비
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌게 봤습니다 아버지들이 가정을 위해 얼마나 힘들게 사시는지를 다시 깨닫게 해준 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이상하게 눈물 나는 영화!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아오..힘들어 디지것네
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 보면서 계속 데드풀이랑 비교했는데 데드풀보다는 별로였던 것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 볼만햇네요ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어휴....이러니까 우리 한국영화가 발전이 없지.이좋은배우들로.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 슈라이크가 아쉬워서 2점 깍음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오랜만에 액션영화 잘봤어요시원시원하고 영화관서 보기 좋아요 사운드ㅎㅎ평점테러하시는 분은 보고 차이셨나ㅡㅡ;;리벤져 흥해라~!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 약간 무서운 내용이지만... 2시간 킬링타임이다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점이 좋아 보고 왔는데요퀸만 알았지 프레디에 대해선 잘 몰랐던 부분을 영화를 보고서 알 수 있었네요 안타깝고 얼마나 외로웠을지 중간중간 울컥했습니다 마지막 10분 공연 첫 피아노 치면서 부르는 노래 마음이 아프고 먹먹했습니다 재밌게 잘 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 행복했던 시간이었습니다 :)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 남들하고 다르다는거 그거 참 힘들어.강동원을 괴물로 만든건 편견과 차별 그리고 남과 다름을 인정하지않는 세상이 아닐까..점점 평범하게 사는게 힘든 세상이 되고있는것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 하이퍼리얼리즘의 공포영화....독박육아는 이렇게 위험합니다....그럼에도불구하고 좋아요 ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실제로 있을법한 일이고 현재 원룸 살아서 넘 무서웠는데 침대프레임이 없어 다행이에요 ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무섭다는 애들 진심인지.. 에휴
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 사랑해요.. 어제부터 키스신 무한반복으로 돌리고 있습니당..ㅠㅠ헝 오승훈씨 잘생겼어요 ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 많은 의미를 담기에는 영화가 너무 작다. 새로운 소재와 주제이긴 하나 워터보이즈와 비교하게 되는건 소재때문일 것이다. 제주도 구경했다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 김혜수님.. 자기관리 짱.. 멋져요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이 영화 볼 돈으로 똥 닦는게 더 이득이다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 믿고 보는 배우 공효진, 집이라는 공간이 주는 공포감이란.. 영화를 보고 집에 가는 길이 너무나 무서웠다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점이 언좋아서 별로인가 했는데 괜찮았음 여주도 그렇게 답답하지 않고 다만 좀 잔인..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 실화같아서 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 리차드 매든 ~~멋있어^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 청불 받을만한 수위가 아닌데...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이런 걸 보고 혁신이라 부르나보다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 유치하다. 아직도 이런 영화만드는 종자들이 있네^^
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 진세연 비키니 뻬고는 볼 게 없음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내용이 개연성이 없고, 마지막 장면을 보고 나면 왜 봤지라는 말이 자연스럽게 나옴.
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 무서윗어요실감나고 혼자산다고생각하믄무섭네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미와 스릴도 도어락으로 잠궜음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 재밌다 미나 너무 이뻐 잘하자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무슨말이필요하랴..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개인적으로 너무 뻔했음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 극장에서 해볼 수 없었던 경험을 선사해주는 영화! 최고다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 브르스 칸의 액션은 마치 과거 이소룡을 보는 것 같았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 노잼인데 테데우스 딸이 예뻐서 별 두개
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 억지스런 스토리 이상한 사투리 모든게 이상하다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 구겨진 부도어음들고 연기하는 허준호님 보고 눈물났네요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 남자들을 잠재적 범죄자로 몰고 가더군요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 난 오늘 전설을 보았다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 어허였음....
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 믿고보는 갓혜수! 오열하면서 봤어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김혜수가 다 했다... 하이퍼리얼리즘
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜때문에 생각보다 재밌는거죠? 진심 놀람.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 가장 재밌게 본 영화들 중 하나.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어이없이끝나네요아쉬여요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 와 실력파 배우들 대단하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 개무섭네요 시간가는줄 모름 재밌음ㅇㅇ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 혜수언니.. 진짜 너무 멋있었어요. 영화 보는 내내 집중해서 숨멎해서 봤어요. 영화 보다가 너무 암담해서 중간에 울었습니다 ㅠㅠ 혜수언니 평생 연기해주세요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 계속 울고울고또울고 꼭보세여
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공배우의 최고의 열연작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 항상 그는 우리곁에 있었다.  그게 퀸이였다는걸 지금 알게 되엇다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 레이디가가가 노래를 이리잘불렀다니! 노래도 너무좋고 최고!최소 100만은 넘겨야하는 영환데 흥행은 실패ㅡㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 유쾌하고 재밌어요 보는내내 재밌네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전범기 논란 있었던 거 알면서도 왜 이렇게 보는지 모르겠다 전범기 CG처리하고 나온 배우 중 하나는 전범기 찍어서 인스타에까지 올렸던데ㅋㅋ 욱일기 빨아주는 것도 아니고 더러워
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 친구 팔 잡고 봤는데 공효진이 너무 연기를 잘해서 내가 격은쥴알앗다 손떨려서 리뷰도 잘못쓰겠음 후 진짜 무서웠다 갑툭튀랑 달리 심리적 압박감 진짜...ㅎㅏ...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 심장이 파탁파탁 투쿤투쿤
# Original Rating: POS
# Predicted Rating: POS
#
# Review 애들이 좋아하네요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고.. 숨죽이고 볼 수 밖에..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 트와이스 좋아하는데 콘서트 못간 원스라면 꼭 보시길 추천드립니다!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 침대 밑과 죽을 조심하라...난 침대 프레임없이 매트리스만 있지롱..오늘은 고양이 안고 자야겟다 덜덜
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반부 15분정도후  부터  흥미진진해집니다.영화 잘감상하세요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공포영화에 정치색을 너무 넣었다;
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 숨 막히게 그럴싸한 이야기여서....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 너무 예쁘미ㅜㅜ 역시 믿고보는 디즈니 !!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보헤미안 랩소디 넘~넘 감동적임 영화가 끝난후에도 관객석에서 쉽게 일어나지못함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 솔직히 공포 그자체로는 좋았으나, 생각이 있고 영화 볼 줄 안다면 좀 시시하지 않았음 솔직히?? 연출력도 코웃음나는 수준이고..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지나친 비현실성이 무시될 정도로 시나리오의 완성도가 높네요... 아울러 주.조연 가릴거 없이 전 배우들의 연기도 나무랄데 없구 예전의 김수현 작가의 드라마를 보는듯..오랜만에 귀가 호강한건 특별보너스인가...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대의가 뭔지 알려주는 슬로운
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도어락떼고 열쇠달아야 할정도로 무서웠음  ㅠㅠ몰입도 최고임
# Original Rating: POS
# Predicted Rating: POS
#
# Review 지붕이 없다면 하늘을 뚫어내자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜ㄹㅇ개노잼임...웬만한거 다보는데..진짜 노잼
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 영화가 끝나고도 느껴지는 공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몰입도 짱~시간 금방가요 너무 무서워요모두들 집에 cctv  달아요ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 연출 하나하나가 다 주옥같아서 놓칠 수 없어요...
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 많은 생각이 들게 만드는 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 미쳤고 여주도 너무 아름다워요 ㅠㅠ근데 아쉽게도 스토리 부분에선 조금 부족 했던거 같아요 그래도 재밌게 잘 보고 왔습니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 동화속을 그대로 들여보는 기분!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 이쁘고 보는내내 집중해서 재밌게 잘봤어요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 가서 직접 보시면 압니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 막달라마리아의 한국적해석
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오랜만에 긴장감으로 즐긴 한국 스릴러 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그때 생각이 나면서 울컥하더이다...공감하면서 보는 40대들 많을듯요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음에 판도라 쇼~~!!하면서 계속 언급되서 엄청난 인물인줄 알았더니....실망....주인공인 그 딸도 엄청난 활약을 할줄알았는데 실망....중간부터 지루해지기 시작해요 ㅠㅠ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 수작이네요 고민하고있다면 보세요.하늘에 맹세코 꿀잼입니다 다른사람들도 봐야되요 알바한테 속지말고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제가 트와이스 팬이어서 영화가 나왔다길레 바로 보았습니다.저 트와이흐 랜드보고 감동 받았습니다ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무 정보 없이 봐서인지 꽤 신선하고 초반에 압도적인 영상과 스케일에 빠져들게 함, 상상력에 감탄했고 이런 영화에 동일한 돈을 내고 봐도 될까 싶었으나.. 후반부로 갈수록 전형적인 용두사미. 그럼에도 한번은 볼만한 영화였음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 저 또 보러갑니다 이영화는 혼자 곱씹으며 봐야해요 음악에 영혼을 맡기세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역시 네이버평점은 믿어선 안됩니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 좀비영화도 아니고  재난영화도아니고  코메디도아니고  감독연출로 말아먹은 영화  현빈연기만 남았네
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 댓글 존나웃겨서 보는중 ....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시간여행을 다룬 영화 중 최고다!
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 귀신 나오는 공포영화보다 훨씬 무섭고 스릴있고 진짜 시간가는 줄 모르고 봤습니다 ㅠㅠ 배우분들 다 연기 짱짱
# Original Rating: POS
# Predicted Rating: POS
#
# Review 내 인생 최고의 영화였습니다 현빈과 손예진 여러 조연들의 열연과 뛰어난 시나리오와 연출 어느 것 하나 빠진거 없이 한국 영화 사상 최고의 영화였습니다 그래서 저는 감히 추천합니다 곧 vod가 나오니 망설이지 말고 바로 구매해서 감상하시길 바랍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제쯤이라야 국민을 위한 정치가 오려나요~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소재는 좋았는대 내용이 구리네여 역시 중국 자본들어간 영화는 내용구림
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 동생이랑 엄마 모시고 봤는데 너무 재밌게봤어요 :)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미있었어요 마동석 겁나조음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 음악 영화로써가 아니라 올해 최고의 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기력이 엄청나네요 실제 콘서트장 같아요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 미국과 IMF와 대한민국과의 관계를 파고들고 그것이 영화를 보는 시간동안 답답하게 만들었지만 Not bad, 김혜수의 연기는 정말 대단함...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 왜 평점이 이리 높은지 이해가 잘..,   최근 본 영화중 제일 남는게 없네요...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 스릴있고 혼자사는 여성분들 보시면 진짜 무서울듯 공블리 연기 좋았어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 재미있었어요~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여러분 주문토끼가 평점테러를 당하고 있습니다! 도와주세요! 할짓없는 백수들에 의하여 테러당하고 있습니다! 물론 노겜노라 주문토끼 둘다 재밌게 다 봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몰입도 현실감 공포감 다 좋습니다. 너무 재밌는데 너무 무서워서 두번은 못보겠어요ㅠㅠㅠ도어락 바꾸려구요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범인이 있는 집으로 계속 들어가는 주인공... 뜬금없는 야채죽... 영화보고 약간 체한느낌이에요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 보자마자 인생영화 됐어요.주인공 너무 멋있습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기가 좋았어요 현실에 있을 법한 일이라 무서웠음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제정 러시아의 초호화 비쥬얼. 그러나 스토리는 범상하다.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 진짜 웃겨요 소리지르면서 웃었어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥.. 남는게 없는영화..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 잠시나마 행복했다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 미국에서 망한 이유가 있었음 스토리 부실
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 막 엄청 재밌진 않았는데 영화보는 내내 지루하지않고 상영시간이 금방 갔어요 ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사실 디즈니영화는 다 좋아하고 해서 기대를 많이 했는데..생각보다 지루했고..그치만 갈수록 잔잔함과감동이 있긴했어요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review Jihye 지혜!!개간지작살 ㄷㄷㄷㄷ "I'm late for church"스타워즈 새로운희망+미국:악의축+트럼프vs중국무역전쟁
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 감독의 중요성을 알겠다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 영화 스토리는 좋은거같은데 주인공 ㄹㅇ 개답답함 진짜 극암영화 보면 암걸려요 진짜로
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 메켄지 포이 짱짱!!완전 멋있어!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 올해 본 영화중 최고다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 당시에는 두루마리 휴지 썼던영화지금보니 개뿔...갔다버려라
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 ...어설픈 장면이 하나둘이 아니었어요,킬링타임용 이상은 아님요,
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 싫어함 이런거..;;;
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 아버지 어머니 생각이나서 계속 울컥했네요그 시절 힘든티 안 내시고 버티시느라 고생하셨겠구나..우리자식들이 사는 세상은 더 나은 세상이되도록 관심가지고 깨어있어야겠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 웃음포인트는 9점을 줄수 있지 않을까 싶은데~ 그동안의 마형의 액션영화들 중 평균이상 찍은거 같고 개그콤비 브라더는 정말 호흡이 환상적이었어요~ 배꼽잡음~ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우와진짜 방금 영화 보고 나왔는데 심장이 아파요 놀래서 ㅠㅠ 아오 혼자 사시는분들 보고나면 좀 무서울듯 왠만한 공포영화보다 더 무서워요 저희 신랑도 저한테 막 기대어 눈가리고 봤어요 흐엉 대박입니당 진짜로
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전쟁은 어쩔 수 없다고? 전쟁 없는 역사는 없었다고? 이 영화를 봐라 그 잘난 전쟁이라는 실체가 뭔 줄 알거다. 레전드 전쟁 영화 명작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이랑 너무 재미나게 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청난 영화. 희대의 명작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기는 좋았는데,, 줄거리랑 마무리도 좀 아쉽네요..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 남자중에 누가범인일까 알아맞춰보세요인데 남자가죄다범인같아 멀쩡한놈이없음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review We are the Champion
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나도 펀치를 날리고 사랑하고싶다 OO은 세상
# Original Rating: POS
# Predicted Rating: POS
#
# Review 10년도 넘게 전에 본 걸 오늘 다시 감독판으로 보고... 하... 이걸 어쩌지... 너무 좋아... 하- 책으로 보기 다시 도전해보렵니다♡
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무섭네요ㅠㅠ 되게 현실적이고 평범한영화 그런데도 무서운영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 라이브에이드때 눈물좀찔끔함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각했던거보다는 ㅠ..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이 영화는 평점높게 준거면 알바다 진짜;
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 다시 30년 전 대학시절로 간 것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 참나  보다보다 시간 아깝다    현빈 멱린인줄알았다   역린도 내용부진이였는데  이건  불쌍타  정해인 연기는  또 저게뭔지 ㅉㅉ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 집중좀 하려고하면 바로 뒤에 여자들은 중간중간 계속 소리지르고 저뒤에서 아줌마들은 소리지르는것도 모자라 웃고 떠들고 최악이었다 좀 조용히 집중해서 보자니까 아줌마들왈 무서운데 집중이 되냐고 하더라 진짜 욕을 한바가지 해주려다 참았다
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 뚠뚠뚜~~뚠뚠뚜~ 브금..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 평생 잊지 못 할 영화, 정말 감명깊었다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 메켄지 포이는 이쁘고 영상미 좋은데 내용이 없음.. 뭘 말하고 싶은지도 머르겠고 조금 지루함..전쟁할때 졸았고.. 어떤사람 코골고 자더라..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 정말 재미있게 보았습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 콘서트를 주제로해서 새로웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 하....  오늘도 낚였습니다 알바들 진짜 걸러야됨 ㅋㅋㅋㅋ 도어락 제목부터 걸렀어야하는데 비싼 도어락 광고인줄..공효진 상두야 학교가자 찍니??ㅋㅋ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 내 생애 아름답던 날 강추!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 10점 짜리 알바들 아이디 클릭하면 예전 영화 평가한거 보고  끄덕 끄덕
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 잔인한 잔인하고 잔인하...
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 볼만 합니다 한번쯤 볼만해요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 OST. 빼곤 아쉬움. 가득
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 시대흐름 못따라가는 최악의영화
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반엔 설국열차+하울의움직이는성 느낌으로 재밌었는데 뒤로 갈수록 뭐가..없음..여주가 처음엔 존멋이었는데 남주 만나고 급 소극적+나약하게변함.. 클라이막스를 향해 가다가 빵터뜨리는게 없고 한 7할은 도망다니는것만 보여줌..스케일은 쩌는데 알맹이가 없당
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 대본쓴사람 빠따 때리고 싶다. 긴장도없고옥의타도 많고
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 오늘 내 심장이 잘뛰고 있다는거 지대로 느낌
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청 무서운데 엄청 재밌는 영화임!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김원희보다 유진화가 더 이쁘던데? ㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 딱 이정도 점수다 ! 답답
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 전체적인 개연성도 떨어지고 그냥 반전없는 누구니 생각할 수 있는 뻔한영화. 재미없었음 다만 경각심은 느끼게해주네요 아니다 이것도 없다. 0점은 없나?
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 재미없습니다 졸았습니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 어른 입장에서는 황당; 아이들은 좋아하네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 재밌다 ㄹㅇ 오늘 아침 9시35분꺼봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미는 예뻤으나 스토리는 빈약 그자체..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 야이 색히야 기예르모 빨리 원위치 안시키냐?
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 최고최고! 아이와 나랑 정말 재미있게 잘봄... 결말이...ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 재밌는데 중간에 나온 러시아어 좀 해석해주세요
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 단 한가지의 관점만 있는 기록. 구제금융을 받는 입장에서 과연 한팀장같은 자세와 태도가 맞는가?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 봐야할 영화 무지하지 말자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고의 영화 보고나서 내내 여운이 남습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잼잼잼 노잼잼잼~ㅠㅠ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 예진님나오니무조건10점
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인생영화 등극 소름소름소름
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우리 냄새 다음 작품이 기대됩니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나름 볼만했고 그냥 한번 보기에 나쁘지 않은 영화였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반 좋은데 뒤에 정리가 좀 안되는... 그리고 시점이나 실내 배경은 장화 홍련, 야외는 링이나 곡성의 미장센만 뽑았어도 좋았을것을...감독이 전작 숨바꼭질만큼 공들이지 않은 느낌.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 간만에 괜찮은 영화 본거 아염
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잔잔한 반전과 소름인데 너무 가슴이아파서 오랫동안 생각하게하는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점내리기하니?....
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 어떻게 살아가야 잘사는 모습인가???를 생각하게 해줍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 지루할틈없이시간순삭.이가섭뒷모습다부져서멋짐.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 원작이 너무 재밌어서 그런가... 실망한 영화. 그리고 너무 뻔한 신파극 이게 천만이 넘는건 아이러니...
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 경각심을 일깨워 준 영화..그 시대, 시기를 겪어내신 부모님들 존경합니다...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잼은그닥  지루해서 중간에 나오고싶었다는
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 굿이네요 정말 재밌습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그래픽은 확실히 좋네요 시나리오가 살짝 평범한편인듯요~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 홈아이오티 광고 및 저상형 침대 홍보 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 내 시간도 거꾸로 간다면 이렇게 살 수 있을까?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 20대분들 안보셨으면.. 애기라면 좋아하겠네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 뭔가 모를 이 비참함...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무조건 봐야합니다 희대의 한국 최고의 명작영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 퀸 콘서트에 갔다 온 기분입니다!!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 공포감 최고에요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review imf란걸 잘몰랐으나이영화를 보고 윗대가리들이 얼마나 무능하고 자기배 채우기 바쁜지 알았다 쓰렉이 색퀴들
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에저예산굿영화~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜 사람들이 그렇게 김혜수 김혜수 하는지 알겠다. 새삼 연기 소름끼치게 잘하네. 작품 고르는 안목도 좋은 듯. 올해 나온 한국영화 중 단연 돋보였다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아니 요새 혼자살아서 무서움에 떠는 여자가 얼마나 많은데 티비 틀어놓을때마다 이거 광고에 자주 나오면 짜증나죽겠습니다. 솔직히 감독 이 영화 무슨 생각으로 만든건지
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 보고 깜짝 놀랐어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review '환상적인 꿈을 꾼 느낌'
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 어떻게 이 영화를 욕 할수 있지;;
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 하는 평타치는 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지금은 역변했다는 클로이 모레츠가 눈에 띈다. 정적이면서도 동적인 액션연출이 만족스러웠다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아부지랑 같이 보러가기 겁나는 영화 ㅜㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어른에게도 꽤 재밌었던영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 빨리 통일이 이루어지길 바라며
# Original Rating: POS
# Predicted Rating: POS
#
# Review 냄비근성들!그렇게 매니아아니면 모르는 그룹인디? 남들이 좋다면 뜻도모르고 좋다는...이영화보단 쎄OO이 훨 낫더라~.알아들을수 있고 따라부를수 있어서
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 반전이 많아 좀 어렵네요. 원작을 읽어야 할 듯. 으스스한 추리물이 딱 내 스타일~
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 친절한금자씨의 평점이 너무 낮아 10점드림
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이 영화의 최대피해자는 누렁이임 아지매와 한방에서 잘살다가 노인과 청년에게 다뺏기고.. 노인과 읍읍씬에서 얼마나 화가 났으면 문지방붙들고 으르렁거렸겠노 이 영화에서 누렁이를 빼놓고 아지매와 노인 청년 새댁의 관점에서만 봤다면 당신은 영화볼줄 모르는것임
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜..보세요두세번보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아놔 진짜 너무 웃겨ㅋㅋ이거왜이리웃겨 엉뚱하고 넘 재밌음 ㅎ이렇게재밌을줄알았으면 진작봤을걸. 주변추천으로뒤늦게봤는데 완전 소장각임..이시영 오정세 정말 넘 능청스럽게 연기잘하고 각본도넘웃김, 작가누구야 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인생최고영화중하나였다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 리벤져 액션  넘나 취향인 것....섹시 그 자체
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고입니다  영화를 춤추며보긴첨입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리가 진부하다고 느낄 수 있으나 여지 껏 보지 못한 활 액션은 진짜라고 생각함  완전 참신한 시도보다 익숙함 속에 파격적 인 시도를 한 영화였다고 생각함  평점 한 7.5. 점  정도 되겠으나  1점 대가 많이 보여서 10점
# Original Rating: POS
# Predicted Rating: NEU
#
# Review ....펭귄을 사고 싶다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 평점이 낮아서 기대 안했는데 기대 이상이에요^^ 애인이랑 같이 봤는데 너~무 좋아하네요! 추천합니다. -글 작성시 이 문구는 삭제후 올리시길 바랍니다.-
# Original Rating: POS
# Predicted Rating: POS
#
# Review 깜짝놀래키기와 비명소리의 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이 영화들 안봤나? 러닝타임내내 계속 웃으면서 봤는데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대한민국의 현재진행형 ~ing
# Original Rating: POS
# Predicted Rating: POS
#
# Review 암걸리니깐 보지마세요
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 그냥저냥이었습니다 ㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 너무재미있게 봤습니다 재밌어요!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고다. 크리스마스에는 이런 영화.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나 룸메랑 봤는데 난 무서운거 잘 봐서 이건 그럭저럭했음 재미뜸 현실적이고 실제로 일어날수도있는거 같아서 흥미진진함 꼭 보셈♥
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 별루.. 아이들은 잘봣는데 끝맺음이 드라마 처럼 찝찝해요 ㅠㅠ그냥 대놓고 궁굼하면 2편보시오 ㅋㅋ 하는
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이들이 재미있게 웃으며보내요 ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이렇게 마음 아픈 내용일수가 있을까요...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화 대박잼잇네 입소문
# Original Rating: POS
# Predicted Rating: POS
#
# Review 90년대의 향수나 좀 느껴볼려고 봤지만 그딴건 1도없고 그저 정부까기만 급급한영화.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 신기해서 지루할 틈이 없었고 스토리나 액션도 좋았다. 배우들도 연기에 몰입감이 있었음.다소 산만한 느낌이 있었으나 만족함.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재개봉할 정도의 명작은 아니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 10점 먹어라잉~~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 볼만한 스릴러네요 공효진이 이쁘고 긴장감이 굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그래픽뺴고는 (이마저도 어색한부분 많음) 볼게 없습니다 1. 거의 체감상 1시간반동안 새로운인물, 새로운장소나오면서 몰입도가 떨어지고 피곤합니다2. 뭘 말하려는건지 다보고 나와도 모르겠습니다그냥 한마디로 내용자체가 기-결로 끝입니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 구성이 매끄럽지 않고 극적 개연성이 부족함. 띄엄띄엄 엉성하게 전개하고 관객이 알아서 이해도 하고 감동도 하라는 느낌. 심은하 당시 1년전 영화 8월의크리스마스와 어떻게 이렇게도 느낌이 차이가 나는지. 그게 연출의 힘이라는 생각이 듬.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 조선판 다이하드를 만들고 싶으셨나 봐요...ㅎㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지혜 안 사랑하는 방법 알려달라
# Original Rating: POS
# Predicted Rating: POS
#
# Review 집들어가기가 무서워진다....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인간이 제일 무섭다고 느낀 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기가 정말 최고에요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화를 본게 아니라 퀸 콘서트에 다녀온것 같습니다~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 파리에서 차타고 가면서 대화를 나누고 자연스레 양쪽으로 내리는 장면이 굉장히 인상 깊다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 스릴이 아주 넘쳤어유 ,,
# Original Rating: POS
# Predicted Rating: POS
#
# Review 젊음의 패기가 좋았고 그렇다고 마냥 아마추어 같지않아 좋았습니다. 놀란의 미덕은 준수한 상업영화를 만든다는것인데 그에 대한 오마쥬라면 "어둔밤"이라는 제목부터 좀 더 상업적으로 고민해봤으면 더 좋았겠다는 생각이 듭니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 뱀파이어 영화하면 떠오르는 명작 뱀파이어 무비
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실화같아서 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시사회 봤는데 재미써요 2편 기대중ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 말이 필요없다...라이브 에이드가 모든것을 말해준 영화!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㅋㅋㅋ 1점줄라다가 설리꼭지보고 2점준다 배경과 배우로 어떻게 저런영화를만드냐... 마지막장면은 진짜 ㅋㅋㅋ 시간버릴사람들은보세요 진짜할거없어서 본건데 끝까지본 제가 신기합니다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 인간이 세상에서 제일무서운 존재라는걸 알려줬다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 결말을 미리 알고 봤는데도.. 가슴이 먹먹해졌다...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 동화같은 이야기네요 어린자녀와 함께보면 더욱 좋을영화~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와... 러닝타임 내내 눈을 못 떼고 봤네요... 23살짜리 애엄마가 좀 부담스럽거 오글거리긴 하지만 ....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 먼저 본 지인들이 재미있다고 해서 기대했는데 몰입감도 있고 배우들의 연기력이 대단하네요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴 만점 ;;; 귀신보다 인간이 더 무섭
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최근에 본 스릴러 영화 중에서 가장 만족스러웠던 영화. 후반부는 눈을 뗼 수 없고 몰입하게 만드는 연출이 좋았습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 답답하긴 답답했는데 그것보다 숨막히고 무서운게 더 커서 영화관가서 볼 만함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나에게도 일어날 수도 있다고 생각하니 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역시 사람이 젤 무섭다는걸 또 한번 깨달았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 봐야할 영화~~진한 감동이 밀려오는따스한 영화~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 난 액션영화 좋아해서 재밌게 봤는데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 알바들 평점주작에 마빡을 탁! 쳤다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 현실 반영 안된 픽션 드라마네요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 지들이 평론가야? 즐거웠음됬지
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 실망무지했다 3류 공포영화도 이거보단 재미있을듯... 배우 멋있고 예쁘기만하지 발락이아니고 발가락으로 만든 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 눈물이 나오는 걸 숨겨가면서 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 올해는 더 프레데터 랑 택시5 때문에 연속 두번 당하네/역시나 시리즈 영화는 무조건 걸러야된다는걸 뼈저리게 느낌
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 최고의 음악영화인것 같아요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 무서웠어요 현실공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 새벽에 혼자 있을떄 그 삐삐삐삑 소리 나면 진짜 무섭지
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 재미있는 영화를 봤네요. 정말 재미 있습니다. 추천드립니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 신이 그의 노래를 가까이 듣고싶어서 일찍 데려갔나보다.. 보는 내내 전율이 느껴졌다.
# Original Rating: POS
# Predicted Rating: POS
#
# ...
# Predicted Rating: POS
#
# Review 1편인줄 몰랐어요..  흑 .  요즘 대세가 1편만 하는건지.. 그래도 재미는 있었어요
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 메켄지 포이, 키이라 나이틀리 다 너무 멋있고 이쁘다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와.... 현실감 느껴져서 몰입도 장난아녀요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 돈을 아끼십시오 여러분
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 퀸으로 눈뜨고 전화받고 스트리밍~퀸으로시작 퀸으로 마무리 내 삶의 변화~ 정말 위로받고 흥분하고 감동받았다그리고 감사하다 그들에게...Queen
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딸이 세번이나 보고 왔네요. 생애 최고의 영화라고.. 시디도 두개 사고.. 덩달아 저도 좋네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 기대한 나머지 실망감이 큽니다 ㅠㅠ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 초반부터 마지막까지 숨막혔다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와... 미쳤다 진짜 미쳤다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우리 엄마도 그랬겠지?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 울때 진짜 연기 잘한다고 느꼈다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌었는데 애들이 걸린 병에 대한 설명이 나왔었나요? 전 못본거같아서요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 빼곤 그저 헛웃음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 4점은 그래픽점수. 이런 세계관 스케일에 그지같은 쓰레기내용을 집어넣다니ㅠ 개연성도 없고 억지설정으로 분량늘린느낌ㅋㅋㅋㅋ관객들 어이없어서 실소터지는 부분이 여럿있었음
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 대사 하나하나가 너무 와닿았어요.김민희님 나레이션도 너무 듣기 좋았고..날것의 모습으로 제 주변의 친구들과 제 모습을 보이는 인물들을 보며 위로받기도 다시 돌아보게도 된 영화였어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 유아인 조우진 연기력 오진다..조우진은 그냥 말이 안나올 정도로 잘함..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 연기력은 좋았으나 무서운건 어떡할거니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이거 엔딩이 어떻게 끝난거지? 2탄을 보라는건가?ㅠㅠ 2탄 나오면 집에서 티비로 봐야겠어요ㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 볼만합니다!!??(
# Original Rating: POS
# Predicted Rating: POS
#
# Review 깜짝깜짝 놀래는 편 아닌데 정말 무섭더라고요...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여주얼굴보느라 시간가는줄 몰랐다;;
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막애 눈물이 날뻔....
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㅎㅎ넘나 재밌을 것 같네요 빨리보고싳자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감동적인데.  왜 이런 영화가 묻히는거지?  이해불가네.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미 있어요 국가 부도 이해되네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 두 아이와 즐겁게 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사람들이 생각하는 것보다 강아지는 단순하다는 것, 그만큼 순수하게 사랑할 수 있다는 것
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보면 알거임 얼마나 ㅈ같은지
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내가 오늘 완전 피곤한데 집에 가기 아쉬워서 영화나 볼까했는데 영화보면 택시타고 들어가야해서 고민하고 있었는디. 영화 줄거리 안보고 그냥 영화 포스트에 안나 역 맡은 한국여자의 포스가 너무 멋있어서 보헤미안 말고 이거 봤는데 재밌어. 안나 너무 멋짐.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음부터 끝까지 완전 존예탱 그자체ㅠㅠ 발레장면도 최고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 반전때문에 두번 본영화였는데 두번봐도 재밌네요 김지수행동들도 이해가 되고ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공권력을이딴식으로표현해도되는거?ㅋㅋ그리고 ㅈㄴ답답함진짜공효진연기는봐줄만하다만모료영화풀리면봐라 어후
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 생각보다는...별로였음잔잔...반전 없는하지만 연기자들의 연기는 괜춘
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이게 걸그룹이다라는걸 느낄 수 있었다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영웅은 난세에 등장한다 했던가 어찌됐든 라이터 가진 아주머니 불질러서 나쁜 3병동놈들 싹다 태워죽인거 속시원했음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소름끼치는영화ㅜㅜㅜ 공효진 연기도 최고!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각보다볼만하네요 놀랫어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 예고편만 봤는데도 노잼이라 평점 3점 드립니다.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 숨막히는 현실적 공포로 휩싸이다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 이인좌를 죽이기전에 김호가 말한다. ''이보시오! 그만하시오~!!!!" 내 이 영화가 끝나기전에 감독에게 말하고싶다. "이보시오~!!그만하시오~!!!!"
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기파 배우들의 만남이 더욱 시너지가 된 공포스릴러.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 8점짜리 영화적당히 킬링타임용으로 괜찮습니다 너~무 무서운것은 아니지만 적당히 스릴감있고 다보고나면 재밌게 봣다 이정도 생각 드네요 1점 2점 이런 영화는 아님... 색감 배경음악 등등 괜찮던데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 기대잔뜩하고 이 추운날조조 때리고 왔는데..ㅠㅠ후..님들도 봐보세용
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 전반적인 내용 구성 만족스러운데유아인은 배역에 별로 어울리지 않는 것 같습니다.몰입을 방해하는 느낌이랄까?재밌게 잘봤습니다. 전체적으로 만족합니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 소소 재밌지도 재미없지도 보는 것을 권장하다지도 않지도
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 음악도 좋고 재미있습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이상하다   평점이 왜 낮지~난개인적으로  재미있게 봤는데   색다른  영화  이면서  감동과  스토리  내용도  좋았다.최고~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 차라리 성난황소를 봐라
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 실제로 몇년전에 영화와 비슷한 일을 겪은적이 있어서 보는 내내 그때 일이 생각났습니다. 가족들과 함께 사는데도 누군가 우리집에 들어오려고 한다는게 너무 무서웠는데, 혼자 사시는 여자분들은 오죽할까요. 현실적으로 공감할 수 있는 소재였어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 멋있었던 영화!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 기대보다 재밌게 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화내리기전 한번더 보고왔어요.   두번째보면서도 보는내내 소름돋았어요.   프레디가  안쓰러워 마음아팠지만 다시한번 퀸의 명곡들에 빠져버렸어요.  정말 최고였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보수 성향으로서  좋은평을 주고 싶지만 거짓말을 못하기에 별3개.. 어둡고 지루하고 스토리 전달이 잘 안된다 다만 한국영화로서 시도하기 어려운 특이한 소재와  중요한 메시지이기에 반점 더줌
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 아무생각없이 봤더니 볼만했음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 어릴때 다들 한번쯤은 해볼 수 있던 현대의 총같은 무기를 예전 역사시대로 들고가면 어떨까 라는 상상을 실현시켜준 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화에 똥을 묻혀놨네요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 사랑이 우정이 이리 더럽. . .
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 아메리카국뽕에 치해버렸ㅓ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 연기 진짜 잘함. 나 보는줄 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 진짜 소름 왕소름이었어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화보는내내 답답해서 욕만나왔습니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이병 ㅅㅋ 싸가지까지 겁나 없네 한편으론 저러니 맞지싶다 요즘 이병들 다들 저러나..그리고 영화평은 고구마 10만개 먹은 느낌
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 범인연기개잘함목소리좋음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시원시원 하게 즐기기 딱 좋은 액션ㅋㅋ스트레스 풀리는 느낌ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이렇게 잘 만들어진 영화가 관람 극장이 너무적다는 게 문제야.개 쓰레기 한국영화보다 백번 좋은영화인데....극장수를 좀 늘려라~~`
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 보고 또 봐도 잼있다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아오 알바도 아닌 배급사 직원 새기들 ㅉㅉㅉ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 내인생 최고의 영화이자 완벽한  영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여성들의 연대를 다룬 묵직한 스릴러!
# Original Rating: POS
# Predicted Rating: POS
#
# Review IMF가 왜 일어났는지.. IMF가 무엇을 바꿨는지.. 쇼크 독트린을 같이 읽어보는 것도 좋을듯합니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아 미친 한국 존나 최악이다
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 일상 소재로 공포를 느끼게하는...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 살짝 지루할 수도 있지만 어쨌든 잼난다. !!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 80년대 개봉했어도 흥행참패 했을것 같은 영화.  70년대면 흥행가능.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 방금 영화 보고 나왔습니다 왠만하면 개봉 첫날 예매하지 않는데 예고편 보고 소재가 기발해서 넘 기대됐었고 거기다 피터잭슨 제작이라고 해서 믿고 봤구요 전 기대치만큼 만족한 영화였어요 배우들의 연기력도 좋았고 작품을 통해 말하고자 하는 메세지도 교훈적^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 차운전 연습할때 나온노래 좋아서 기억에 남고 스토리가 아기자기함ㅋㅋㅋㅋ2편도 보고싶음ㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 킬링타임용으로 무난한 영화....잠수함영화의 패턴 그대로 쓰긴 하지만 소재가 잠수함이란거에서 반은 먹고 들어가는듯..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 요소가 많아서 공포감이 더와닿긴했지만 뭔가 질질끄는 면이 있긴함 그냥 보고딱 드는생각은 자취하면 안되겠다 였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감독이 넣고 싶은걸 다 넣어버려서 스토리가 완전 짬뽕이 되버림...차라리 2부작 정도로 만들지...ㄹㅇ 구라 안치고 중간에 졸다가 깸ㅇㅇ cg랑 액션은 화려한데 스토리가 영...돈주고 보긴 아까움
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 스릴있고 시간가는줄 모르고 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 멤버쉽으로공짜로봣는데도아깝다ㅅㅂ팝콘하고먹을꺼만이만원치사서식사하고나옴누가팝콘떨어트렷댓냐 양손가득먹을거쥐고혹시놀라서떨어트리면어떡하나걱정햇다가영화중반부에다머것다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 말해서 10점은 아니지 않나요?
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 디즈니는 진짜 사랑이에요!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무생각없이 볼 수 있는 후련한 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최악..이었다....
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 소재는 참신 그래픽도 멋있음 하지만 내용이 너무 개연성이 없음..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 가볍게 보기에 괜찮았습니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 프렌치 불쌍함.. 그리고 생각보다 많이 안 무서웠음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 첨부터 쫄리는 영화는 겁나 오래만인듯ㅋㅋㅋㅋ완전 강추bbb
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화의 세계관? 각본? 짜임새 좀 허술하지만!그렇게 광고하던 피터잭슨도 감독이 아님!그치만 우리나라 배우인 지혜님의 등장부터~ 영화끝까지 그냥 와! 강한 인상이였뜸.영화 끝나고 이분만 기억에 남음!
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 관객 137명. 현명한 놈들 ㅋㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 엄청 좋아하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 퀸의 명곡만으로도 재밌다!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 완전히 스릴넘침 숨바꼭질이랑 동급 스릴 아니 그 이상
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 오랫동안 생각날것 같음ㅠㅠ 도어락 괜히 봤나ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미있었음 ㅇㅇ...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무재밌어요.콘서트같음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 저냥 볼만함,,,보기전에 IMF사태에 대해 공부하고 가는걸 추천
# Original Rating: POS
# Predicted Rating: POS
#
# Review 맨날먹는 똑같은 밥에 무슨 점수를 주랴
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 사십중반인  내가봐도   이작품만이  유일한  역대급  스파이더맨!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 허준호 배우님 연기 진짜 멋졌어요 과하진않지만 영화보는내내 몰입하게 만들어주심 ㅠㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 런닝맨을 모티브로 만든거라고 해서 신기했어요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현빈ㄴ 응원하면서 보게 된다 ..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 재미잇어해요 근데 마지막이너무허무햇어요 2탄을안볼수없도록...ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실에도 있을수있는일 ㅠ 그래서 더 무서워
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재사회.. 민낯을 드러낸 공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘 보았습니다. 익숙한 노래들이 퀸 노래였네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진의 연기 존재감은 ;; 이번영화 미쳤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고!최고!한번 봤는데 너무 재미있어서 스크린x  화면으로 한번 더 봤어요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌었다고 말하기엔 그시절 견뎌주신분들께 죄송스럽고 보는내내 힘들고 안타깝고 존경스럽다고 생각들었습니다. 지금 영화 말고도 보여지는 저희 나라가 심각한수준이에요 점점 더 우리나라는 힘들어질겁니다. 준비태세 하라는 메세지같아요. 1분1초한눈팔지 못했네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 다들 연기 너무 좋은데 내용이 너무 구식임 20OOO에 이런 내용에 대사라니
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 시간가는줄 모르고 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌습니다 8점짜리는 되는영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무서웠어요ㅠㅠ 스릴감 대에박
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소재가 다 한 영화. 10
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 콘서트 못가보셨던 분들은 추천드려요! 저도 못가본 사람인데 충분히 간접체험 됩니다 원스라면 무조건 관람해보세요!! 살짝 아쉬웠던건 콘서트 전체가 아니라는점?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굿 굿 굿 ㅜㅅ 굿 굿 긋굿굿굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴이 느껴지는 영화.실제일어날수잇는일이라 더 소름끼치는거 같애요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막20분으로 충분하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 현실공포.. 괜히 집 도어락 신경쓰임. 처음에 경찰 나올때 대응이 너무 현실적이라서 소름돋았다. 여주행동이 답답하게 보일수도 있지만 솔직히 그게 진짜 현실적 반응이라고 생각합다. 목숨이 걸렸는데 용기있게 행동할 수 있는 사람이 얼마나 있을까..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범인 진짜 무섭네 ㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사랑이란 무엇인지 알고싶다면..추천합니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현빈 연기력은 만점. 손예진 연기력 꽝에 협상능력도 없는 대본. 연출력 꽝.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 섬뜩하지만 잼있었어요. 연기들도 좋았구요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 좋은 배우들과 좋은 소재 가지고 겨우 이딴 영화를 만드냐 무슨 스토리에 개연성이라곤 하나도 없어서 몰입도 제로. 마지막에 총질도 유치하기 짝이 없고 총알 떨어지는건 무슨 백년전 수법 아직도 갖다붙히냐. 스포일 했다고 짜증내지마라. 안보는게 개이득
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 기대이상으로 너무 재밌음 ~ 굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 크리스마스 시즌 영화로는 최고!!! 매킨지 포이는 세상미모 종합판!!! 키아나 나이틀리는 메쏘드 연기신!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 잼잇겟봣습니다. 바울에 대한 그믿음 더 한층 생각하게 됍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 팝콘라지한통다먹고 음료수도 끝까지 먹으며 버티려했음에도  졸았다. IMF라는 엄청난 역사소재를 이렇게밖에 못쓰고 이렇게 연출할 수 밖에 없었나깊이도 인물간의 개연성도 없어 다 따로 노는것같은..연기는 좋은데 감정이 스크린밖으로 전해지지않는다.
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 꺄아아아아악 오또케에에 ㅠㅜ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 오프닝 널 내게 담아 보자마자 진짜 너무너무 심각하게 이뻐서 머리부터 발까지 소름 쫙 돋고 다음 곡으로 넘어갈때마다 소름돋고 이뻐서 소름돋고 진짜 실력도 너무 늘었고 더 좋아졌다 마지막때 울컥하다가 지효 울고 나도 울었다,,ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들의 영기 줄거리 그리고 액션신 모두 완벽한 영화 다크나이트 라이즈 좋아하셨던 분들이라면 당연히 좋아하실듯 마블 영화중에 단연 최고라 생각한다!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 발레씬들 너무 멋있었어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌다 재밌어 와따야 와따
# Original Rating: POS
# Predicted Rating: POS
#
# Review 누가 뭐래도 인생영화다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 요즘 런닝맨에 푹 빠진 5세 아들.엄청 재밌었다네요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반에만 참신함 ㄹㅇ 터미네이터아재 왜나온거며도시들싸움이라매.. 갑자기 비행기 위주영화가되며 인간들 약탈을 처웃으며 하다가 급 난민코스프레?선악구분없이 태세전환이 너무 급변우디르가 나뭇잎마을에서 살면 저리될듯싶다더까고싶은데 140자 ㅂㄷㅂㄷ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이와의 순지의 재능과 열정이 정점이었던 시기의 영화. 딱 한번만 가질 수 있는 첫 사랑의 기억과 감정을 짧은 시간 속에 잘 담아낸 수작.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 라이프에이드 공연 싱크로율 어마어마하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시간가는줄 모르고 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이영화를 몇번을 봤는데도 여전히 이해가 되질 않아요ㅠㅠ과거와 현재가 공존 한다는 자체가....나두 타임슬립 하고싶다ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 재밌게 봐서 기분도 좋아요시사하는바가 큽니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘봤어요....혼자봤다가 넘 무서웠네요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 완벽한 영화. 이 영화를 본 시간이 너무 행복했다. 영화란 이런 것이다 라고 알려주는 그런 느낌..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재밋게봤어용 시간가는줄 모르고 이것저것 생각하게되는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각 했던거 보다는 재밌음~~!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 여자 혼자 살면 신경쓸게 한두가지가 아님..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 긴장감 넘치는 여행속에 피어나는 유대감이 매우 훈훈하다. 원수를 갚기위한 대가가 너무 커서 안타깝다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 심장이 이렇게 두근거리긴 오랜만이다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 재밌게 잘봤습니다. 현 시대였다면 에이즈뿌리고 다닌죄로 감옥일텐데..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 공연은 좋았는데 생각보다 재미는 없었어요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영상만예쁨 노잼 하...
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 혼자사는나에겐 이제 도어락열때마다 당분간 무서울듯해요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 줄거리는 별다른 감흥이 없었다. 다른 멤버와 머큐리와의 인간적인면 표현이 좀약했다. 러브라인이 약했고 성공하기까지의 과정이 너무 어슬펐다. 하지만 영화내내 이어지는 퀸의 노래와 마지막 라이브 에이드 공연은 이 모든 것을 상쇄하기에 족하다. 강추
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내  신파조 영상과 억지 흑백논리로  마음을  무겁게 만드는 영화  .. 이영화를 보고 나오는  순간 이 영화를 보기로 한 자신의 결정을 부도 나게 하는 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 올해 본 영화중 최고!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 싱크로율 99퍼인듯..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아예 현빈을 히어로로 만들던가. 이도저도 아닌..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진 김예원 김성오 현실적이 연기에 푹 빠져서 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재의 헬조선이 시작된 계기를 경제를 공부하면 이미 알고는 있었지맛 영화로 마주하니 분노와 슬픔이 몰려오는  영화였습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굳이 도시를 이동식으로 만들었어야했나?
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 좋았다.. 실화를 베이스로 한 영화라 그런지.. 더 여운이 남는다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개오글거리는 그시절 영국에 두명의 여왕 드립에 1점주고간다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 기대했던것 보다는 ..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 잘봤습니다현실적공포네요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 1점테러가 너무 많아서 10점 줍니다공효진 연기 대박이고보는 내내 심장쫄리면서 봤네요재밌습니다남자들끼리 봤는데 서로 놀라면서 봤습니다ㅋㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아는 내용이고 예상 가능한거같으면서 너무 무섭고 진짜 오랜만에 심장 쫄깃!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 비쥬얼 하나느 끝내주는 구만..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음 리뷰글을 써보는데 이 한마디면 됩니다 진짜 존.나 무섭습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전 아주아주 재밌게 잘봤어요~~ 추천!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review OOO기 발암영화  씨발  이거 쓴 작가 새끼는 생각이란걸 할줄 모르는 새끼인가?   공효진도 이딴 쓰레기 시나리오 받고  출연할 생각을 하다니 으휴  한심하다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 정말 재미있게 봤습니다.아이디어는 최강. 스토리는.약간부진.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재 상영 중인 영화들 거의 다 봐서 볼거 없어서 봤는데 의외로 재밌었음ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS

# %% [markdown]
# #### Using Ridge Regression

# %%
# Ridge Regression
selected_clf = classifiers[1][1]
clf_tfidf = Pipeline([('vect', vectorizer), ('clf', selected_clf)])
clf_tfidf.fit(X_train, y_train)

y_pred = clf_tfidf.predict(X_valid)
for review, answer, predicted in zip(X_valid, y_valid, y_pred):
    print("Review {}\nOriginal Rating: {}\nPredicted Rating: {}\n".format(review, answer, predicted))
# Out:
# Review 재미있어요 좋아요 지루할때쯤 빵빵터짐 무겁지만 재미있게 풀어낸 이야기
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저녕 볼만햇네욯ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공포영화인듯 아닌듯?!ㅋㅋㅋ 근데 공포영화보다 더 무서웡ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 진짜 스토리 탄탄하고 김윤석 배우님은 말할것 없고주지훈 연기 미쳤네요 영화보는내내 답답해죽는줄 알았어요 연기 너무잘해서 마지막에 너무 애잔하고 실화바탕이어서 그런지 마음에 더 와닿는 영화였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여자친구가 귀신은 안무서워 하는데사람은 많이 무서워하넹^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개무서워서 혼낫네 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김성오 배우분이 연기를 너무 잘해서 재밌게봤어요 모든 잘 어울리는 배우인거 같네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아름답고 신비한 영화였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제나 다시봐도 명작 마지막 컷  주인공 가정부와  친구의 대화가 진한 여운을..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미가 너무 아름다웟다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 편집을 심각하게 한건지 영화가 심각한건지 구분이 안된다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 난 정말 재미나게 봤다. 산사태가 어이없었지만 실제 있었던 일이라 그려러니 함.살려달라는 말에 아무도 나와보지 않는.. 그러나 그게 현실이며 나역시 나가보지 않을거임. 영화를 보면서 방관자 입장일때는 공감을 많이 했고 목격자일때는 너무 무서웠던 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 때깔보고 존나 삐급영환가보네 했는데 출연진보고 개놀랐네 어쩐지 연기들은 좋더만
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 영화는 대작인데 견자단이 마지막에 죽은게 안타깝네ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아쉬운 부분이 많지만 브루스칸 액션은 역대급
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 무서운 영화, 혼자라서 더욱 공감되요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 12세딱지때부터 느낌이 싸했으나, 디즈니 느낌으로다 보면 즐겁게 감상하고 올수있음 크게 실망할 정돈아님
# Original Rating: POS
# Predicted Rating: POS
#
# Review 맘에 들고 안들고를 떠나서, 이런 영화는 그냥 10점 줍시다~!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연출도 좋고 다괜찮은데 억지가 좀 있습니다 억지가 한두개가 아니에요ㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 어느 쪽이 알바인지 알수가 없네 ㅎㅎㅎ
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 의심이란 병은 하나님도 치료 하시지 못하는군요. 진실을 보는 현명함을 주소서!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인물들의 행동에 개연성이 없는점,갑작스런 인물등장과 소개미흡 이 두개만으로도 이 영화는 1점이다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 졸라 재미없음 최악. 영화 진짜 현실성없고 억지임. 저정도면 공효진이 공범. 그리고 요즘 저렇게하는 경찰 없음. 이 영화 쓴 사람은 이렇게 돈벌어먹으면 천벌 받음.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 90년대 중반 영화를 감안하면 수준급 연출이나 당시 배우들의 연기력은 안쓰럽다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 최근 본 영화중에는 참..참담하네요 ㅎ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 바람 같던 우리들의 바람
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이때 까지 본 스릴러 장르중에 제일 재밌음ㅋㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 이게 적당하다고 생각합니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 부모를 위험으로 내몰고, 개는 미세먼지에 아무렇지도 않으며,하여간 개연성 없음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 재밌는데 졸린거왜그럼
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 완전 인생영화!!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제일검이 제일검같지도 않고... 현실적인 검대결을 생각하는건 알겠는데.. 검동작은 거의 두가지.. 휘두르고 뒤집어서 휘두르고.. 갑자기 왕내면 얘기가 나오더니.. 진짜 어려운 영화인지.. 어술픈 영화인지 감이 안잡힘..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 초등학생 아이들과 재미나게 잘 봤습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범죄영화의 초점은 늘 여자가 피해 보는 현실성 영화지... 현실같은 영화라 손에 땀이 날 정도로 봤다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 50년도 넘은 세월너머 동화책 속에 빠져있던 어린 내모습이 생생하게 보이네요.이건 나같은 어른들을 위한 영화같습니다. 이야기속에 현실세계를 보여주는 진실함에 고개를 끄덕였습니다.9점정도는 됩니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㄹㅇ 와 예매권 받아서 봤는데 진짜 예쁘누ㅠ뉴뉴ㅠㅠㅠ 반전도 있고 재밌게 봤당 돈 주고 봐도 아깝지 않겠더요 그리고 ?인간들 개웃기누 니들 재미없다고 사람들 다 재미없어야 되냐 수준 유딩이고 ㅋㅋㅋㅋ 난 ㅈㄴ재밌었다 개추천 ㅠㅠ ~~~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 갓에이미세요 주체적인 캐릭터 캬
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 꼭봐야하는 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 염력보다는 재미있었다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진 너무 좋아요ㅠㅠㅠㅠ연기대박
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 심장이 두근두근
# Original Rating: POS
# Predicted Rating: POS
#
# Review 계속 긴장감도 있고 재밌었습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 노래가 좋았습니다, 요즘 맨날듣고 있어요ㅕ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 흠  약간 아바타정도 스케일임   매드맥스보단   재밋다.  제발 알바들  도어락인가 뭐시기랑 비교  ㄴㄴ
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 아 진빠져....영화다보고 너무 힘들었음..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점1점 박고 주디 터는놈들 특: 개 아싸, 비공감 개 많음 ㅋㅋㅋ사회에 섞이지 못함
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 오~~~~의외로 꿀잼
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재미없다 ..돈아깝다..
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 현시대의 상황이 답답하고 답이없다면 왜그러는지 이유라도 알아야돼지 않겠는가? 절대 잊어서는안될 나라가 망한날. 윤리와도덕이 돈앞에 짖밟히기 시작한날.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 고구마 코로 씹어먹는기분 답답하고 답답하고 또답답
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 몰입도ㅆㅅㅌㅊ 이정도면볼만하다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 노잼에 일관성도 부족. 절제미도 없고 양식도 없고 그냥 겉멋만 들어서 모든 것이 너무 과함.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 엄청 무서워요,, 진짜 자취하는 여성분들은 더 더욱 그럴거 같아요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는내내손에땀을쥐게한~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미없어요 보지마세요 조작된고같음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 어릴때 엄마 아빠가 보길래 어린 마음에 쎈 척 하고 싶어서 봤다가 그 트라우마가 10대 시절 내내 날 괴롭힘;;; 이제 내나이 곧 30인데 지금도 불 다 끄고 잠 못잠 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 조조영화 각보고 있는데 평점이랑 CGV 개봉시간 보는데 아다리 맞음 영화 시간대 다른 영화에 비해 현저히 적음 차라리 도어락봐야겠음 ㅋㅋ 개이득
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 학생으로서 공감 가긴 하지만 결국은 일진들에게 기회를 많이 줘야된다는 개소리를 외쳐버리네.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 개봉하자마자 보러갔는데 기절할뻔 친구랑 손 꼭 안잡고보면 기절합니다 강철심장만 보세요 ,, 집와서도 침대밑만 보게되고 싸이코범인 밖에 생각안납니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 재미만 있는데요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연달아서 두번 본 첫 영화입니다. 홍보가 너무 B급스러웠어서 안 유명해진것 같아요. 대화 거의없이 독백이고 설정도 특이한데 연기 톤도 너무 좋아요. 신파도 안좋아하고 멜로도 그닥인 저에게 최고의 영화에요. 지금도 가장 좋아하는 영화는 김씨표류기에요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 옛 군대에서 바뀌어가는 모습을 잘 표현했습니다.근데..군대 다녀온 사람들이한거 맞습니까?요즘 어린 친구들의 군생활이겠죠.요즘에 티비에서 하는 연예인들 군생활하지 않았으면 좋겄습니다.글쓴이 해병1037기 2시단 입니다실무생활 해봤어?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 개연성이없고  각본이나 감독의 연출력도 부족한 수준이 낮은영화. 소재는 참좋았음.좀더 치밀하고 완성도있게 만들었다면 꽤 괜찮았을 영화.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 굳굳굳굳 재미있었어요 ㅎㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이와 시간 보내기에 괜찮은편입니다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 말이 필요없는 명작. 로맨스와 신파의 완벽한 하모니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역사드라마, 공포, 레즈, SF액션을 섞었는데 SF 액션은 없었으면 더 좋았을 것 같다. 키히라 '주보비' 연기는 인상적이었고 박보영은 일본사람으로 태어났더라면 더 인기 많았을 것 같다. 이해영이 소녀들과 일하고 싶어서 찍은게 아닐까?
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 7.8정도가 적당함 주작 8.63 에바 그래서 1점 준다 ㅎㅎ 암튼 돈 아깝지는 않음
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반에는 엄청난 소재와 그래픽에 흥분했고후반에는 엄청난 각본과 중국자본에 흥분하는 박진감 넘치고 손에 땀을 쥐게하며 내적으로 소리지르게되는 스릴만점 영화!!
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 상영관 좀 늘려주세요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 상영관 수가 적어 밤12시에 봤는데졸음이 오지 않는 영화입니다.2시간이 정말 빠르게 지나갑니다.안보면 후회 할 영화입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고최고 발동동 구르며 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 공포감 킬링타임용 강추. 역시사람이 제일무섭다ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화가 이래야죠.관객을긴장하게하는영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 손을 꽉 움켜쥐고,소리내지 말아야겠다하면서 봤는데,역시나.끝까지 긴장감을 가지고 봤어요.강추!!입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김혜수 김혜수 김혜수 이 세글자로 끝이다 이 영화는.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 동심으로 돌아온 것 같아요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화중에 앞사람이 인스타해도 화안나는영화...자극적이지만 더럽게 맛없는 요리같은 영화...
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이준혁씨 모습.연기가 그나마 압권..나머지는 무의미..배우들이 아깝다..감독이 독립영화수준정도..
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 재미있게 보았습니다. 이런게 S F 죠
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 무서워서 도중에 뛰쳐나오고 싶었음...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 혼탁해진 내 정신과 육체가 깨어나는 느낌. 부림사건의 가해자들은 아직도 떵떵거리고 살고 있다는 것에 분노를 느낀다. 진심으로 그 변호사를 존경하며 우리곁에 없다는 것이 정말 그립고 슬프다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 웬만하면 야구 다큐는 기본은 하는데~
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진이연기를너무잘한다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review ㄹㅇ감동적인영화한번더보고싶다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 36개월아들 재미있게 잘 봤어요!ㅎㅎㅎ아빠없는 주말 잘 보냈네용ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 첫번째 봤을때는 음악에 감동하고, 두번째 봤을때는 인생에 감동하는 영화. 세번째 보면 어떤 느낌일지 기대되는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보고나면 찝찝하지만 그만큼 잘만들었음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 모두 난해하다고 평한 것에 비해 나는 즐기며 보았다.영화를 위한 영화라는 표현에 공감.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 순간순간 마음 졸이고 놀라게되니 방심은 금물
# Original Rating: POS
# Predicted Rating: POS
#
# Review 반전의 반전의 서스펜스
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴러 영화의 정석입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 원래 액션 SF 그냥좋아함잘봤어요~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실화라서 더 감동적 이네요 제 인생 영화가 아닐까 합니다. 물론 8분 보고 껐습니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 오랜만에 꿀잠잤다 ....
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 영화는 정말 재미있게 잘 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 감정이입 하나도 안되고 보는 내내 졸았다 하.. 내 11000원
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 말이 필요한가? 일단 봐라
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재미없어요. 졸다 나왔습니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내가 여지껏 경험한 것들 중 가장 완벽한 창작물.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 형제자매들이 죽어가던때 인간적인 마음으로 얼마나 똑같이 응징하고 싶었을까. 그러나 순간마다 예수님의 말씀을 기억하며 그 고난들을 통과해나갔던 제자들..오늘날 우리가 기억해야할 부분..신체가학성 강조한 패션오브크라이스트와 비교안되는 훌륭한 영화.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 알바들이신가.. 물론 지금 개봉한거중에서는 나름 볼만한 급인건 맞는데.. 노잼에 똑같은 래퍼토리 반전스토리.. 개연성 부족하고 답답하기 그지없고 보기 불편한 영화인데
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 공효진 연기 짱잘해 ㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 다른건.이미다른분들이 다써서.. 하필그때와이프가불키고. 하필그때 전화오고..잘싸우다가 망치는 왜두고 도망가고..경찰은 너무쉽게 기습당하고..의도하는바는 알겄으나..ㅜ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 재밋어요 너무 잼있어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 손예진 그냥 여신이다. 커피한잔같이 하면 소원이없을듯
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 각자의 취향에 따라 최고도 최하도 된다. SF 좋아하고 상상력 좋아하고 볼거리를 추구한다면 이 영화가 딱이다. 재미보다 감동, 교훈이 좋은 사람에겐 비추한다. 이런 영화는 시각적으로 환상적이니 이왕이면 대형화면이 좋다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 타임킬링용 영화. 스토리 자체는 누구나 한번쯤 생각했던 스토리. 그래도 스릴은 인정.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이미 있는 동화를 90분 동안 전개하려면 스토리 구성에 신경을 써야했는데 너무 부실함. 영상미도 최근 개봉한 곰돌이푸, 미녀와야수, 신데렐라에 비해 너무 허접함. OCN에서 보여주는 옛날 영화랑 별 다를 게 없음. 클라라와 생쥐가 캐리함.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 차라리 연극을 하는 게... 참으로 불편한 연출.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 똥망 스토리. ㅗ ㅗ ㅗ ㅗ
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 보는 내내 공연에 소름. 예술가의 삶
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소름끼치고 무서웠어요 귀신보다 사람이 더 무섭네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 닥터 스트레인지하고 비슷한 느낌..그래픽은 좋고 스케일도 큰데 스토리나 개연성에 흠이 있음
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 아이들이 좋아하네요^^
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 순수하게 재미있는 영화는 다시봐도 재미있다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청 무서울정도는 아니지만 재밌게 잘 본거같아요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반에는 약간 볼만하다가 나중에는 실소 나옵니다. ㅋㅋㅋ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 컨트롤씨 컨트롤브이 음악시대에좋은 교훈을 주는 아티스트다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말너무너무너무너무잼난다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여운이 깊은 영화였다. 먼가 빨리감기같아서 조금 아쉬웠지만  재미있었고 퀸이 왜 전설인지 알것같았다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이게 전미박스오피스 1위라면 내가 폰으로 아무거나 찍어도 1위 하겠다. 살인마나 등장인물이나 하나같이 암걸리게 만드는 개졸작
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 여기다 스포한ㅅㄲ땜에 18
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화보고  돈 아깝다는 생각이 ...이영화 저영화  짜집기에 유치하기  짝이없고.딱  집에서  보기에  알맞은 정도
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 존x 지루함 진짜..대박이네
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이 영화는 청소년들 보다는 부모님의 곁을 떠난 성인들이나 자식을 둔 부모님들이 보기에 매우 적합한 영화라고 생각합니다.... 진짜 보면서 공감되는 점도 많았고 나중에 기회가 되면 부모님에게 보여드리고 사랑한다고 전해드리고 싶네요ㅠㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몇안되는 평가 정말 조작같다.. 아무리 독립영화라해도 너무 어설픈연기..발음..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 3개의 다른 왕국들이 하나같이 아름답고 예뻤다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 테러하는 것들은 내 기준 다 댓글알바다 그래서 10점짜리는 결코 아닌데 10점 준다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜곡도 정도껏합시다 참
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 0점 못주나.. 철지난 드립 개그 초반 지수와 동철이 차에서 나눈 만담은 내가 창피했고 수 많은 명대사를 기대했지만 그러지 못했다. 결론 평점은 주작쓰다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 심장이 쫄깃!!배우들 연기도 너무 좋았어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미가 장난 아니던데.... 엄청 재밌을것 같습니다!!! 알바 용돈 모으면 이번달 말에 꼭 보고 싶네여!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막장면에 황정민이 유아인 반죽여 놨으면 더 속 시원했을 영화 마지막이 아쉬움
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 뒤에 이야기를 꼭 보셔야 합니다 삼전도의 굴욕 이후에 최명길과 김상헌이 청나라 감옥에서 서로 오해를 플고 화해하며 시로 우정을 나누는 모습이 큰 감동을 줍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한국 영화중 최고인것같아요이런 긴장감주는 스릴러물  드물어요  꼭보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 북한인간들은 뼛속 깊이 통수를 치는 dna를 가진거같다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 좋고, 음악 멋지고, 스펙타클함
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 동상 걸렸다며 업히거나 부축받아 다니던 여기자가 갑자기 총알 쏟아지자, 절벽위로 뛰어가는 모습  ㅋㅋㅋ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 3번봤다... 개인적으로 ABBA도 영화화했으면
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도저히...보기가 힘들정도로 별로였다. 결국 중간에 시청중단..
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 진짜 별한개도아깝다 개뻔한전개 와이딴영화가 20OOO에나온다니ㅋㅋ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 지금 봐도 옛날 영화라는 생각이 안들정도로 촌스럽지 않다..놀랍..(￣O￣;)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼴페미코인 편승하려는 수준낮은 감독이만든 수준낮은 영화.  전작만봐도 이걸 극장에서봐야하나 말아야하나 감이올거임
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반부터 스릴 대박이던데 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 1점 주기도 아깝다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 뮤서워서 혼났어용 ㅠ 으헝 진짜 꼭 보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 수납형침대로 바꿔야겠군..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 눈물나요 ㅠㅠ안타깝고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 메갈들도 보쥣물 질질싸게만들 그래픽만으로도 충분히 아이맥스로 볼 가치가 있다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 손에 땀을 쥐게하는 스릴 넘치는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화가 끝나고도 눈물이 나는 영화 집에있는 우리 강아지들이 너무 보고싶어지는 영화 잘봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리도 너무 좋고 남주여주 케미도 너무 좋아서 너무 재밌게 보았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 라면 지가 다처먹었으면서.. 진짜 팍머리를 쥐어박고싶당ㅎㅎㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 남친이랑 보러갔는데 남친 롱패딩 입은 이유가 무서운 장면 나오면 가릴려고 가림막용으로 갖구 온듯-!그렇게 무섭진 않았는데 긴장감이 컷음ㅎㅎ 하지만 영화가 영화인지라...결말은 안봐두...ㅋㅋㅋㅋ뻔할 뻔 스토리ㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 시작부터 숨막히던데여ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 뒤로갈수록 아는노래 많이나와서 신나게 감상하고 옴
# Original Rating: POS
# Predicted Rating: POS
#
# Review 눈이 즐겁고 기분이 좋아지는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 앞부분은 좀 유치하고 지루함. 뒷부분은 그럭저럭 볼만한데 전개가 아동용 동화스러움. 원래 호두까끼 줄거리가 이런가.. 제일 기억에 남는건 쥐. 쥐가 귀여웠네요. 아무튼 그래도 판타지영화를 좋아해서 5점..후하게 드렸네요..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 인생 최고의 영화...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 결국 또하나의 선택지에서 약을 포기하는걸 보고 아 이게 미소구나. 싶었던.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 참 애매한 영화. 박보영 예쁘고 연기 잘하지만 순 억지 투성이인 전개와 우연에만 의존한 스토리 진행... 영화인걸 감안해도 참 몰입하기 힘든 영화였음. 딱 오락영화, 그 정도 수준.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 걍...기생수 미국판아님?" 스파이더맨 어쩌고해서봣더니 기생수 미국판인데? 그래도 밥먹으면서 볼만함
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 조미료 없는 집밥치유와 화해의 바당
# Original Rating: POS
# Predicted Rating: POS
#
# Review 억지로 공포를 조성하는 다른 영화와는 다르게 일상 생활에서 누구나 겪을만한 일들을 소재로 해서 더 무섭게 다가온것 같습니다. 범인도 누군지 계속 헷갈리는 점도 좋았습니다. 끝까지 긴장을 멈출 수 없엇고 잊혀지지 않는 1784....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화후기 처음 남겨봄. 너무 재미없고 기분이 나쁜 영화였다. 스릴러 장르를 좋아해서 봤는데 돈이 아까울정도... 공효진의 연기는 좋았으나 캐릭터가 너무 고구마였다.  공포심만을 주기 위해 만든 영화같고 반전같지도 않은 반전이 영화를 더 재미없게 함.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 마무리가 조금 아쉽긴했지만 기대했던만큼 재밌게 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 코미디영화인줄 ㅎㅎ 재미있게 봤습니다아~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각지 못했던 달의 의미,꼬이고 꼬인 너저분한 관계,평행세계같은 판타지적인 요소,박민수씨의 하드캐리가 돋보이는 수작.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진이 아깝 지루햇네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 알바 너무 심함 이게 무슨 9점이 넘냐
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 스릴대박 완전 무서웠음ㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한줄평 첨남겨요..슬프거나 그러거전혀없는데 내눈엔 눈물이 주르륵. .
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무신났당 다따라불렀당
# Original Rating: POS
# Predicted Rating: POS
#
# Review 탄탄한 구성과 실감나는 장면이맔은 편안하게 볼 수있는 영화네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 좋은 영화같다. 그렇지만 느린 전개와  기억의 편린들이 뒤죽박죽 섞여  짜증이 난다.  탈북자의 액받이가 된 기분이다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 어린 조카가 너무 좋아해요!!ㅋㅋㅋ 또 보자고 하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어거스트가 웃을때 진짜 행복해 보여ㅜㅜ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화보고 난 후 이 여운만큼은 타이타닉과 견줄만하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도대체 영화가 뭘 말하고 싶은 건지 모르겠다. 좋아하는 CG가 트랜스포머 변신 로봇처럼 멋지게 여러 차례 나왔으나, 영화의 의도를 전혀 모르겠다. '"왜?"를 끊임없이 묻고 싶다..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 정말 즐거워했어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제나 스파이더맨1편은  왜  이리도  엉성하냐!    샘  레이미의  2편은   정말  대역작 이엇구나 라고  다시한번  느낌.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 도어락 정말 무섭게봣어여
# Original Rating: POS
# Predicted Rating: POS
#
# Review 프리미엄관에서 19000주고 본내자신이 ㅈㄴ한심하다 멋진 세계관인건 맞는데 등장인물들 지능수준이 의심될정도로 전개가 엉망
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 너무너무재미있었네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오늘 OCN으로 봤는데, 바토 역을 맏은 배우 연기가 가장 쓰레기고, 모토코와 바토의 관계는 플라토닉해야 원작의 그 맛이 사는데 이건 뭐 진짜 완전 망했다. 보는 내내 욕만 나온다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review ㄹㅇ 1점 주려다 여주 외모때문에 3점 준다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 전설스 최고스 오져스 대박스
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 심장 쫄깃한 영화봤네요 추격자이후로 이렇게 조마조마한건 첨 공블리 연기도 좋았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 되게 뻔한 이야기인줄 알았으나굉장한 수작이 된이야기..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 경민의 모습은 우리 시대의 많은 여성들을 대변하는 듯 하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 긴장감있고 무서웠어요ㅠㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무리 멀리 떨어져 있어도 마음속에 간직하고 있지.기억할게.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이들이 참 좋아하고 잼있습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대한민국 국민, 전세계 사람들이 봐야 한다. 보면서 가슴이 먹먹해지고 억울하고 분노가 치솟았습니다. 더이상의 아픔은 되풀이 되지도, 그저 돈으로만 가치를 매기며 배상이라는 것이라는 이름으로 받아드리면 안된다고 다시 한번 뼈저리게 느꼈습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한 번 더 영화보러 가야겠다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 난 재밌게 봤음. 염정아의 선택이 좀 아쉽지만 아이를 가슴에 묻은엄마의 심정을 헤아릴수없으니 받아들였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 보세요 두번 보세요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굿 입니다 좀더 빨리볼걸
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 결말 행운의 편지ㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴있는영환데 졸려서 힘들었음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이건 진짜 극장에서 안보면 후회할뻔..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한편의 동화 같은 영화. 처음부터 끝까지 아름다운 영상미와 멋진 음악이 함께한다. 스토리는 좀 유치한면이 있지만, 전연령이 볼수 있는 동화를 같이 본다고 생각하면 될듯. 미녀와 야수에 이어서 흑인 배우들을 많이 캐스팅하여 PC적 요소를 넣은건 감점
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여운을 주는 액션 영화 흥미로운 스토리입니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 친구가 새벽에 보러가자해서 저는 제목만 보고서는 "에이 무슨 이런 영화를 봐"라며 투정부렸는데요.. 이 친구가 본인이 티켓살테니 재밌으면 티켓값 돌려달라해서 보러갔습니다. 그리고 영화 끝난 후 9천원 바로 현금으로 줬습니다..갓띵작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무슨 뜻인지 하나도 모를 영화 그냥 아마추어가 대충 짜집기 한 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 덜덜 떨면서 봤음... 도어락이라는 소재로 이렇게 긴장감 넘치게 만들다니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 문득 몇년전 우리집 도어락 누르던 사람이 생각나네
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 긴장감이 최고! 현실에서 일어날 수 있을 법한 이야기라 더 무서웠던거 같아요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사라엄마ㅠㅠ 왜 먼지 속 들어갈 때 물 적신 수건을 안가져간거야..ㅠㅠ 그걸로 입만 막고 갔어도....
# Original Rating: POS
# Predicted Rating: POS
#
# Review
# Original Rating: POS
# Predicted Rating: POS
#
# Review 일단 배우들은 넘좋았음. 김기정역이랑 관리역할 하신분 첨보는 얼굴이었는데 연기 넘잘함. 도어락이란 소재는 현실성이 있어서 와닿았음. 재밌게봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 긴장감이 꾸준하게 이어지는게 좋았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 저 이거 시사회로 봤는데.. 진짜 무섭습니다ㅠㅠ 특히 혼자사는 여자분들 보지 마세요.. 보다가 막판 15분? 정도 못보겠어서 그냥 나왔어요.. 끝날때 들어가서 엔딩크레딧만 보구요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이천희 불쌍하네.... 스릴넘치고 재미써욤
# Original Rating: POS
# Predicted Rating: POS
#
# Review 매켄지 포이의 얼굴과 크리스마스 분위기가 가득한 아름다운 영상미 말고는 노잼인 영화.. CG* 에서만 상영해요
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 유럽에게는 기독교귀신을, 아시아에게는 불교귀신을.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무조건 큰화면에서 봐라. 진짜 재밌음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미는 넘이쁘고 화려한데 스토리가 약하니 보고나서 아쉬움이 많이남네요. 매킨지포이가 헉소리나게 이뻐요.키이라나이틀리 연기는 약간 신동범의 티나가 연상되요ㅋㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 한국 군인은 별거아니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화를 보고난 뒤에 춘천MBC에서 제작한 '코레아일라' 다큐를 보게 되었다. 너무 울어서 얼굴 부었네요~ 문재인정권이 아니였음 흥행도 되고 많이 이슈화되었을듯 한대 아쉽네요. 북괴군의 만행이 너무 적나라하게 고증되니깐 좌빨들 불편하겠죠?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 비주얼이 완전 좋음. 매켄지포이도 완전 예쁨
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아버지 이제야 깨달아요 어찌 그렇게 사셨나요 - 싸이"아버지"中 -
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 북유럽의 경관을 본다는 것만으로도~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점 보고 꾹 참고 봤는데 시간 아깝고 모성애도 없고이기적인 엄마라는 이름의 여자..마지막 장면 뭔지...쓰레기영화
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 똥 같은 주인공. 개 같은 경찰. 멍청한 범인
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 마지막에 좀 서운했지만ㅋㅋ 2편 기다려봅니다 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리는 무난평범 예상가는데연기들이 미쳐서몰입도가 높아서 거의 VR이였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여자분들꼭보시오ㅋㅋ나름공감이지만이쁜사람한테만 꼬이는거
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 최악. 상업성도 없는 B급 영화 수준. 어디 대학교 졸업작도 아닌 입학작이 아닌가 생각이 드는 클라스. 저 밑에 별점들은 다 지인들인가여배우 연기는 좋았음. 근데 남자주인공 발연기;;
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 마트를 벗어나는 순간이 거의 없이 같은 톤의 전개인데도 신기할정도로 졸립거나 지루하지 않았다. 누구나 기저에 깔고 살아가는 삶의 고독을 인지할 수 있는 사람이라면 충분히 몰입 가능한 영화. 특히 추운 겨울밤 심야영화로써 멋진 선택.
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 살아생전 못 본 프레디 머큐리의 모습을 보았습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감동이 있네요..ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고의 영화임 반전도 쩔고 이상하게 몰입 잘되는 영화.근데 결말 잦 같아서 6점 드림 그냥 짜증남 싫음 마음에 안듦재미있는건 확실함.훌륭한 영화임 결말은 꺼져
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 한참 이슈된지 지나고봤는데 정말 수작이긴 수작임..할리우드판 곡성이라는데 곡성은 생각조차나지않을정도로 기괴하고 우아하고 소름끼친다.엄마역의 토니콜렛 표정연기가 다 한 영화...캐스팅도 찰떡같이 잘한듯,공포스럽게 스멀스멀 옥죄여오는 작품성있는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 잼있는영화 봤음 ^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘만든 영화 재밌게 보고왔어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 한국산 좀비물 영화인데기대한 만큼 재미있지는 않았다뜬금없이 주인공이 좀비가 되는 설정도 좀 아쉬웠다
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 여주인공이 사라지는 이유의 타당성을 받아들일 수 있어야지  이 영화를 재밌다고 감동적이라고 할 수 있을거 같다. 늘 하루를 밝게 최선을 다해 살던 소녀의 결말이 저런거라니 너무 허무해서 뒷 내용은 전혀 눈에 들어오지 않았다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 잠이나잘껄... 가슴이답답하다 답답해
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 비주얼은 정말 뛰어났지만 내용을 전달하는 능력은 부족했던 영화. 극중 대부분의 사건을 극적인 장치로만 연결지어버리면 감독은 편할지 몰라도 관객은 흥미를 잃고 지쳐간다. 또한 너무나도 익숙한 레퍼토리는 영화를 보며 앞으로의 내용전개의 기대감을 떨어뜨렸다
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 재미있네요  기대감 크네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 예뻐요 , 재밌게 잘봤어요 !
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기도 만족스럽고 볼만한 스릴..?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜진짜 너무 무섭고 스릴넘쳤다 ㅠㅠ 너무 재맜다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이영화보고 내가 아미라는게 너무 자랑스럽고 오빠들한테도 정말 수고했고 앞으로 건강 잘 챙겼으면 좋겠다고 말하고싶었다ㅜㅜㅜㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사상 최고의 히어로 무비
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌게 봤습니다 아버지들이 가정을 위해 얼마나 힘들게 사시는지를 다시 깨닫게 해준 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이상하게 눈물 나는 영화!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아오..힘들어 디지것네
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 보면서 계속 데드풀이랑 비교했는데 데드풀보다는 별로였던 것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 볼만햇네요ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어휴....이러니까 우리 한국영화가 발전이 없지.이좋은배우들로.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 슈라이크가 아쉬워서 2점 깍음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오랜만에 액션영화 잘봤어요시원시원하고 영화관서 보기 좋아요 사운드ㅎㅎ평점테러하시는 분은 보고 차이셨나ㅡㅡ;;리벤져 흥해라~!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 약간 무서운 내용이지만... 2시간 킬링타임이다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점이 좋아 보고 왔는데요퀸만 알았지 프레디에 대해선 잘 몰랐던 부분을 영화를 보고서 알 수 있었네요 안타깝고 얼마나 외로웠을지 중간중간 울컥했습니다 마지막 10분 공연 첫 피아노 치면서 부르는 노래 마음이 아프고 먹먹했습니다 재밌게 잘 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 행복했던 시간이었습니다 :)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 남들하고 다르다는거 그거 참 힘들어.강동원을 괴물로 만든건 편견과 차별 그리고 남과 다름을 인정하지않는 세상이 아닐까..점점 평범하게 사는게 힘든 세상이 되고있는것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 하이퍼리얼리즘의 공포영화....독박육아는 이렇게 위험합니다....그럼에도불구하고 좋아요 ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실제로 있을법한 일이고 현재 원룸 살아서 넘 무서웠는데 침대프레임이 없어 다행이에요 ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무섭다는 애들 진심인지.. 에휴
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 사랑해요.. 어제부터 키스신 무한반복으로 돌리고 있습니당..ㅠㅠ헝 오승훈씨 잘생겼어요 ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 많은 의미를 담기에는 영화가 너무 작다. 새로운 소재와 주제이긴 하나 워터보이즈와 비교하게 되는건 소재때문일 것이다. 제주도 구경했다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 김혜수님.. 자기관리 짱.. 멋져요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이 영화 볼 돈으로 똥 닦는게 더 이득이다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 믿고 보는 배우 공효진, 집이라는 공간이 주는 공포감이란.. 영화를 보고 집에 가는 길이 너무나 무서웠다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점이 언좋아서 별로인가 했는데 괜찮았음 여주도 그렇게 답답하지 않고 다만 좀 잔인..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 실화같아서 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 리차드 매든 ~~멋있어^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 청불 받을만한 수위가 아닌데...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이런 걸 보고 혁신이라 부르나보다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 유치하다. 아직도 이런 영화만드는 종자들이 있네^^
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 진세연 비키니 뻬고는 볼 게 없음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내용이 개연성이 없고, 마지막 장면을 보고 나면 왜 봤지라는 말이 자연스럽게 나옴.
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 무서윗어요실감나고 혼자산다고생각하믄무섭네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미와 스릴도 도어락으로 잠궜음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 재밌다 미나 너무 이뻐 잘하자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무슨말이필요하랴..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개인적으로 너무 뻔했음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 극장에서 해볼 수 없었던 경험을 선사해주는 영화! 최고다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 브르스 칸의 액션은 마치 과거 이소룡을 보는 것 같았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 노잼인데 테데우스 딸이 예뻐서 별 두개
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 억지스런 스토리 이상한 사투리 모든게 이상하다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 구겨진 부도어음들고 연기하는 허준호님 보고 눈물났네요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 남자들을 잠재적 범죄자로 몰고 가더군요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 난 오늘 전설을 보았다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 어허였음....
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 믿고보는 갓혜수! 오열하면서 봤어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김혜수가 다 했다... 하이퍼리얼리즘
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜때문에 생각보다 재밌는거죠? 진심 놀람.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 가장 재밌게 본 영화들 중 하나.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어이없이끝나네요아쉬여요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 와 실력파 배우들 대단하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 개무섭네요 시간가는줄 모름 재밌음ㅇㅇ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 혜수언니.. 진짜 너무 멋있었어요. 영화 보는 내내 집중해서 숨멎해서 봤어요. 영화 보다가 너무 암담해서 중간에 울었습니다 ㅠㅠ 혜수언니 평생 연기해주세요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 계속 울고울고또울고 꼭보세여
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공배우의 최고의 열연작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 항상 그는 우리곁에 있었다.  그게 퀸이였다는걸 지금 알게 되엇다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 레이디가가가 노래를 이리잘불렀다니! 노래도 너무좋고 최고!최소 100만은 넘겨야하는 영환데 흥행은 실패ㅡㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 유쾌하고 재밌어요 보는내내 재밌네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전범기 논란 있었던 거 알면서도 왜 이렇게 보는지 모르겠다 전범기 CG처리하고 나온 배우 중 하나는 전범기 찍어서 인스타에까지 올렸던데ㅋㅋ 욱일기 빨아주는 것도 아니고 더러워
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 친구 팔 잡고 봤는데 공효진이 너무 연기를 잘해서 내가 격은쥴알앗다 손떨려서 리뷰도 잘못쓰겠음 후 진짜 무서웠다 갑툭튀랑 달리 심리적 압박감 진짜...ㅎㅏ...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 심장이 파탁파탁 투쿤투쿤
# Original Rating: POS
# Predicted Rating: POS
#
# Review 애들이 좋아하네요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고.. 숨죽이고 볼 수 밖에..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 트와이스 좋아하는데 콘서트 못간 원스라면 꼭 보시길 추천드립니다!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 침대 밑과 죽을 조심하라...난 침대 프레임없이 매트리스만 있지롱..오늘은 고양이 안고 자야겟다 덜덜
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반부 15분정도후  부터  흥미진진해집니다.영화 잘감상하세요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공포영화에 정치색을 너무 넣었다;
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 숨 막히게 그럴싸한 이야기여서....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 너무 예쁘미ㅜㅜ 역시 믿고보는 디즈니 !!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보헤미안 랩소디 넘~넘 감동적임 영화가 끝난후에도 관객석에서 쉽게 일어나지못함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 솔직히 공포 그자체로는 좋았으나, 생각이 있고 영화 볼 줄 안다면 좀 시시하지 않았음 솔직히?? 연출력도 코웃음나는 수준이고..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지나친 비현실성이 무시될 정도로 시나리오의 완성도가 높네요... 아울러 주.조연 가릴거 없이 전 배우들의 연기도 나무랄데 없구 예전의 김수현 작가의 드라마를 보는듯..오랜만에 귀가 호강한건 특별보너스인가...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대의가 뭔지 알려주는 슬로운
# Original Rating: POS
# Predicted Rating: POS
#
# Review 도어락떼고 열쇠달아야 할정도로 무서웠음  ㅠㅠ몰입도 최고임
# Original Rating: POS
# Predicted Rating: POS
#
# Review 지붕이 없다면 하늘을 뚫어내자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜ㄹㅇ개노잼임...웬만한거 다보는데..진짜 노잼
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 영화가 끝나고도 느껴지는 공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몰입도 짱~시간 금방가요 너무 무서워요모두들 집에 cctv  달아요ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 연출 하나하나가 다 주옥같아서 놓칠 수 없어요...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 많은 생각이 들게 만드는 영화입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 미쳤고 여주도 너무 아름다워요 ㅠㅠ근데 아쉽게도 스토리 부분에선 조금 부족 했던거 같아요 그래도 재밌게 잘 보고 왔습니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 동화속을 그대로 들여보는 기분!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 이쁘고 보는내내 집중해서 재밌게 잘봤어요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 가서 직접 보시면 압니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 막달라마리아의 한국적해석
# Original Rating: POS
# Predicted Rating: POS
#
# Review 오랜만에 긴장감으로 즐긴 한국 스릴러 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그때 생각이 나면서 울컥하더이다...공감하면서 보는 40대들 많을듯요.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음에 판도라 쇼~~!!하면서 계속 언급되서 엄청난 인물인줄 알았더니....실망....주인공인 그 딸도 엄청난 활약을 할줄알았는데 실망....중간부터 지루해지기 시작해요 ㅠㅠ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 수작이네요 고민하고있다면 보세요.하늘에 맹세코 꿀잼입니다 다른사람들도 봐야되요 알바한테 속지말고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제가 트와이스 팬이어서 영화가 나왔다길레 바로 보았습니다.저 트와이흐 랜드보고 감동 받았습니다ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무 정보 없이 봐서인지 꽤 신선하고 초반에 압도적인 영상과 스케일에 빠져들게 함, 상상력에 감탄했고 이런 영화에 동일한 돈을 내고 봐도 될까 싶었으나.. 후반부로 갈수록 전형적인 용두사미. 그럼에도 한번은 볼만한 영화였음.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 저 또 보러갑니다 이영화는 혼자 곱씹으며 봐야해요 음악에 영혼을 맡기세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역시 네이버평점은 믿어선 안됩니다.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 좀비영화도 아니고  재난영화도아니고  코메디도아니고  감독연출로 말아먹은 영화  현빈연기만 남았네
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 댓글 존나웃겨서 보는중 ....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시간여행을 다룬 영화 중 최고다!
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 귀신 나오는 공포영화보다 훨씬 무섭고 스릴있고 진짜 시간가는 줄 모르고 봤습니다 ㅠㅠ 배우분들 다 연기 짱짱
# Original Rating: POS
# Predicted Rating: POS
#
# Review 내 인생 최고의 영화였습니다 현빈과 손예진 여러 조연들의 열연과 뛰어난 시나리오와 연출 어느 것 하나 빠진거 없이 한국 영화 사상 최고의 영화였습니다 그래서 저는 감히 추천합니다 곧 vod가 나오니 망설이지 말고 바로 구매해서 감상하시길 바랍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 언제쯤이라야 국민을 위한 정치가 오려나요~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소재는 좋았는대 내용이 구리네여 역시 중국 자본들어간 영화는 내용구림
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 동생이랑 엄마 모시고 봤는데 너무 재밌게봤어요 :)
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미있었어요 마동석 겁나조음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 음악 영화로써가 아니라 올해 최고의 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기력이 엄청나네요 실제 콘서트장 같아요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 미국과 IMF와 대한민국과의 관계를 파고들고 그것이 영화를 보는 시간동안 답답하게 만들었지만 Not bad, 김혜수의 연기는 정말 대단함...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 왜 평점이 이리 높은지 이해가 잘..,   최근 본 영화중 제일 남는게 없네요...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 스릴있고 혼자사는 여성분들 보시면 진짜 무서울듯 공블리 연기 좋았어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 재미있었어요~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여러분 주문토끼가 평점테러를 당하고 있습니다! 도와주세요! 할짓없는 백수들에 의하여 테러당하고 있습니다! 물론 노겜노라 주문토끼 둘다 재밌게 다 봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 몰입도 현실감 공포감 다 좋습니다. 너무 재밌는데 너무 무서워서 두번은 못보겠어요ㅠㅠㅠ도어락 바꾸려구요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범인이 있는 집으로 계속 들어가는 주인공... 뜬금없는 야채죽... 영화보고 약간 체한느낌이에요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 보자마자 인생영화 됐어요.주인공 너무 멋있습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기가 좋았어요 현실에 있을 법한 일이라 무서웠음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 제정 러시아의 초호화 비쥬얼. 그러나 스토리는 범상하다.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 진짜 웃겨요 소리지르면서 웃었어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥.. 남는게 없는영화..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 잠시나마 행복했다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 미국에서 망한 이유가 있었음 스토리 부실
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 막 엄청 재밌진 않았는데 영화보는 내내 지루하지않고 상영시간이 금방 갔어요 ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사실 디즈니영화는 다 좋아하고 해서 기대를 많이 했는데..생각보다 지루했고..그치만 갈수록 잔잔함과감동이 있긴했어요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review Jihye 지혜!!개간지작살 ㄷㄷㄷㄷ "I'm late for church"스타워즈 새로운희망+미국:악의축+트럼프vs중국무역전쟁
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 감독의 중요성을 알겠다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 영화 스토리는 좋은거같은데 주인공 ㄹㅇ 개답답함 진짜 극암영화 보면 암걸려요 진짜로
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 메켄지 포이 짱짱!!완전 멋있어!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 올해 본 영화중 최고다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 당시에는 두루마리 휴지 썼던영화지금보니 개뿔...갔다버려라
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 ...어설픈 장면이 하나둘이 아니었어요,킬링타임용 이상은 아님요,
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 싫어함 이런거..;;;
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 아버지 어머니 생각이나서 계속 울컥했네요그 시절 힘든티 안 내시고 버티시느라 고생하셨겠구나..우리자식들이 사는 세상은 더 나은 세상이되도록 관심가지고 깨어있어야겠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 웃음포인트는 9점을 줄수 있지 않을까 싶은데~ 그동안의 마형의 액션영화들 중 평균이상 찍은거 같고 개그콤비 브라더는 정말 호흡이 환상적이었어요~ 배꼽잡음~ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우와진짜 방금 영화 보고 나왔는데 심장이 아파요 놀래서 ㅠㅠ 아오 혼자 사시는분들 보고나면 좀 무서울듯 왠만한 공포영화보다 더 무서워요 저희 신랑도 저한테 막 기대어 눈가리고 봤어요 흐엉 대박입니당 진짜로
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전쟁은 어쩔 수 없다고? 전쟁 없는 역사는 없었다고? 이 영화를 봐라 그 잘난 전쟁이라는 실체가 뭔 줄 알거다. 레전드 전쟁 영화 명작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아이랑 너무 재미나게 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청난 영화. 희대의 명작
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기는 좋았는데,, 줄거리랑 마무리도 좀 아쉽네요..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 남자중에 누가범인일까 알아맞춰보세요인데 남자가죄다범인같아 멀쩡한놈이없음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review We are the Champion
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나도 펀치를 날리고 사랑하고싶다 OO은 세상
# Original Rating: POS
# Predicted Rating: POS
#
# Review 10년도 넘게 전에 본 걸 오늘 다시 감독판으로 보고... 하... 이걸 어쩌지... 너무 좋아... 하- 책으로 보기 다시 도전해보렵니다♡
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무섭네요ㅠㅠ 되게 현실적이고 평범한영화 그런데도 무서운영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 라이브에이드때 눈물좀찔끔함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각했던거보다는 ㅠ..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이 영화는 평점높게 준거면 알바다 진짜;
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 다시 30년 전 대학시절로 간 것 같다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 참나  보다보다 시간 아깝다    현빈 멱린인줄알았다   역린도 내용부진이였는데  이건  불쌍타  정해인 연기는  또 저게뭔지 ㅉㅉ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 집중좀 하려고하면 바로 뒤에 여자들은 중간중간 계속 소리지르고 저뒤에서 아줌마들은 소리지르는것도 모자라 웃고 떠들고 최악이었다 좀 조용히 집중해서 보자니까 아줌마들왈 무서운데 집중이 되냐고 하더라 진짜 욕을 한바가지 해주려다 참았다
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 뚠뚠뚜~~뚠뚠뚜~ 브금..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 평생 잊지 못 할 영화, 정말 감명깊었다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 메켄지 포이는 이쁘고 영상미 좋은데 내용이 없음.. 뭘 말하고 싶은지도 머르겠고 조금 지루함..전쟁할때 졸았고.. 어떤사람 코골고 자더라..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 정말 재미있게 보았습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 콘서트를 주제로해서 새로웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 하....  오늘도 낚였습니다 알바들 진짜 걸러야됨 ㅋㅋㅋㅋ 도어락 제목부터 걸렀어야하는데 비싼 도어락 광고인줄..공효진 상두야 학교가자 찍니??ㅋㅋ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 내 생애 아름답던 날 강추!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 10점 짜리 알바들 아이디 클릭하면 예전 영화 평가한거 보고  끄덕 끄덕
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 잔인한 잔인하고 잔인하...
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 볼만 합니다 한번쯤 볼만해요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 OST. 빼곤 아쉬움. 가득
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 시대흐름 못따라가는 최악의영화
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 초반엔 설국열차+하울의움직이는성 느낌으로 재밌었는데 뒤로 갈수록 뭐가..없음..여주가 처음엔 존멋이었는데 남주 만나고 급 소극적+나약하게변함.. 클라이막스를 향해 가다가 빵터뜨리는게 없고 한 7할은 도망다니는것만 보여줌..스케일은 쩌는데 알맹이가 없당
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 대본쓴사람 빠따 때리고 싶다. 긴장도없고옥의타도 많고
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 오늘 내 심장이 잘뛰고 있다는거 지대로 느낌
# Original Rating: POS
# Predicted Rating: POS
#
# Review 엄청 무서운데 엄청 재밌는 영화임!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 김원희보다 유진화가 더 이쁘던데? ㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 딱 이정도 점수다 ! 답답
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 전체적인 개연성도 떨어지고 그냥 반전없는 누구니 생각할 수 있는 뻔한영화. 재미없었음 다만 경각심은 느끼게해주네요 아니다 이것도 없다. 0점은 없나?
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 재미없습니다 졸았습니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 어른 입장에서는 황당; 아이들은 좋아하네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 재밌다 ㄹㅇ 오늘 아침 9시35분꺼봄
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미는 예뻤으나 스토리는 빈약 그자체..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 야이 색히야 기예르모 빨리 원위치 안시키냐?
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 최고최고! 아이와 나랑 정말 재미있게 잘봄... 결말이...ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 재밌는데 중간에 나온 러시아어 좀 해석해주세요
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 단 한가지의 관점만 있는 기록. 구제금융을 받는 입장에서 과연 한팀장같은 자세와 태도가 맞는가?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 봐야할 영화 무지하지 말자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고의 영화 보고나서 내내 여운이 남습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잼잼잼 노잼잼잼~ㅠㅠ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 예진님나오니무조건10점
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인생영화 등극 소름소름소름
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우리 냄새 다음 작품이 기대됩니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나름 볼만했고 그냥 한번 보기에 나쁘지 않은 영화였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 초반 좋은데 뒤에 정리가 좀 안되는... 그리고 시점이나 실내 배경은 장화 홍련, 야외는 링이나 곡성의 미장센만 뽑았어도 좋았을것을...감독이 전작 숨바꼭질만큼 공들이지 않은 느낌.
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 간만에 괜찮은 영화 본거 아염
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잔잔한 반전과 소름인데 너무 가슴이아파서 오랫동안 생각하게하는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 평점내리기하니?....
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 어떻게 살아가야 잘사는 모습인가???를 생각하게 해줍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 지루할틈없이시간순삭.이가섭뒷모습다부져서멋짐.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 원작이 너무 재밌어서 그런가... 실망한 영화. 그리고 너무 뻔한 신파극 이게 천만이 넘는건 아이러니...
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 경각심을 일깨워 준 영화..그 시대, 시기를 겪어내신 부모님들 존경합니다...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잼은그닥  지루해서 중간에 나오고싶었다는
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 굿이네요 정말 재밌습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그래픽은 확실히 좋네요 시나리오가 살짝 평범한편인듯요~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 홈아이오티 광고 및 저상형 침대 홍보 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 내 시간도 거꾸로 간다면 이렇게 살 수 있을까?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 20대분들 안보셨으면.. 애기라면 좋아하겠네요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 뭔가 모를 이 비참함...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무조건 봐야합니다 희대의 한국 최고의 명작영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 퀸 콘서트에 갔다 온 기분입니다!!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 공포감 최고에요
# Original Rating: NEU
# Predicted Rating: POS
#
# Review imf란걸 잘몰랐으나이영화를 보고 윗대가리들이 얼마나 무능하고 자기배 채우기 바쁜지 알았다 쓰렉이 색퀴들
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에저예산굿영화~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 왜 사람들이 그렇게 김혜수 김혜수 하는지 알겠다. 새삼 연기 소름끼치게 잘하네. 작품 고르는 안목도 좋은 듯. 올해 나온 한국영화 중 단연 돋보였다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아니 요새 혼자살아서 무서움에 떠는 여자가 얼마나 많은데 티비 틀어놓을때마다 이거 광고에 자주 나오면 짜증나죽겠습니다. 솔직히 감독 이 영화 무슨 생각으로 만든건지
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영화 보고 깜짝 놀랐어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review '환상적인 꿈을 꾼 느낌'
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어떻게 이 영화를 욕 할수 있지;;
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 하는 평타치는 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지금은 역변했다는 클로이 모레츠가 눈에 띈다. 정적이면서도 동적인 액션연출이 만족스러웠다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아부지랑 같이 보러가기 겁나는 영화 ㅜㅜ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 어른에게도 꽤 재밌었던영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 빨리 통일이 이루어지길 바라며
# Original Rating: POS
# Predicted Rating: POS
#
# Review 냄비근성들!그렇게 매니아아니면 모르는 그룹인디? 남들이 좋다면 뜻도모르고 좋다는...이영화보단 쎄OO이 훨 낫더라~.알아들을수 있고 따라부를수 있어서
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 반전이 많아 좀 어렵네요. 원작을 읽어야 할 듯. 으스스한 추리물이 딱 내 스타일~
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 친절한금자씨의 평점이 너무 낮아 10점드림
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이 영화의 최대피해자는 누렁이임 아지매와 한방에서 잘살다가 노인과 청년에게 다뺏기고.. 노인과 읍읍씬에서 얼마나 화가 났으면 문지방붙들고 으르렁거렸겠노 이 영화에서 누렁이를 빼놓고 아지매와 노인 청년 새댁의 관점에서만 봤다면 당신은 영화볼줄 모르는것임
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜..보세요두세번보세요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아놔 진짜 너무 웃겨ㅋㅋ이거왜이리웃겨 엉뚱하고 넘 재밌음 ㅎ이렇게재밌을줄알았으면 진작봤을걸. 주변추천으로뒤늦게봤는데 완전 소장각임..이시영 오정세 정말 넘 능청스럽게 연기잘하고 각본도넘웃김, 작가누구야 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인생최고영화중하나였다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 리벤져 액션  넘나 취향인 것....섹시 그 자체
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고입니다  영화를 춤추며보긴첨입니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스토리가 진부하다고 느낄 수 있으나 여지 껏 보지 못한 활 액션은 진짜라고 생각함  완전 참신한 시도보다 익숙함 속에 파격적 인 시도를 한 영화였다고 생각함  평점 한 7.5. 점  정도 되겠으나  1점 대가 많이 보여서 10점
# Original Rating: POS
# Predicted Rating: NEG
#
# Review ....펭귄을 사고 싶다
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 평점이 낮아서 기대 안했는데 기대 이상이에요^^ 애인이랑 같이 봤는데 너~무 좋아하네요! 추천합니다. -글 작성시 이 문구는 삭제후 올리시길 바랍니다.-
# Original Rating: POS
# Predicted Rating: POS
#
# Review 깜짝놀래키기와 비명소리의 영화
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이 영화들 안봤나? 러닝타임내내 계속 웃으면서 봤는데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 대한민국의 현재진행형 ~ing
# Original Rating: POS
# Predicted Rating: POS
#
# Review 암걸리니깐 보지마세요
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 그냥저냥이었습니다 ㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 너무재미있게 봤습니다 재밌어요!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고다. 크리스마스에는 이런 영화.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나 룸메랑 봤는데 난 무서운거 잘 봐서 이건 그럭저럭했음 재미뜸 현실적이고 실제로 일어날수도있는거 같아서 흥미진진함 꼭 보셈♥
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 별루.. 아이들은 잘봣는데 끝맺음이 드라마 처럼 찝찝해요 ㅠㅠ그냥 대놓고 궁굼하면 2편보시오 ㅋㅋ 하는
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이들이 재미있게 웃으며보내요 ㅎㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이렇게 마음 아픈 내용일수가 있을까요...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화 대박잼잇네 입소문
# Original Rating: POS
# Predicted Rating: POS
#
# Review 90년대의 향수나 좀 느껴볼려고 봤지만 그딴건 1도없고 그저 정부까기만 급급한영화.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 신기해서 지루할 틈이 없었고 스토리나 액션도 좋았다. 배우들도 연기에 몰입감이 있었음.다소 산만한 느낌이 있었으나 만족함.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재개봉할 정도의 명작은 아니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 10점 먹어라잉~~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 볼만한 스릴러네요 공효진이 이쁘고 긴장감이 굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그래픽뺴고는 (이마저도 어색한부분 많음) 볼게 없습니다 1. 거의 체감상 1시간반동안 새로운인물, 새로운장소나오면서 몰입도가 떨어지고 피곤합니다2. 뭘 말하려는건지 다보고 나와도 모르겠습니다그냥 한마디로 내용자체가 기-결로 끝입니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 구성이 매끄럽지 않고 극적 개연성이 부족함. 띄엄띄엄 엉성하게 전개하고 관객이 알아서 이해도 하고 감동도 하라는 느낌. 심은하 당시 1년전 영화 8월의크리스마스와 어떻게 이렇게도 느낌이 차이가 나는지. 그게 연출의 힘이라는 생각이 듬.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 조선판 다이하드를 만들고 싶으셨나 봐요...ㅎㅎ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 지혜 안 사랑하는 방법 알려달라
# Original Rating: POS
# Predicted Rating: POS
#
# Review 집들어가기가 무서워진다....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 인간이 제일 무섭다고 느낀 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들 연기가 정말 최고에요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화를 본게 아니라 퀸 콘서트에 다녀온것 같습니다~~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 파리에서 차타고 가면서 대화를 나누고 자연스레 양쪽으로 내리는 장면이 굉장히 인상 깊다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내 스릴이 아주 넘쳤어유 ,,
# Original Rating: POS
# Predicted Rating: POS
#
# Review 젊음의 패기가 좋았고 그렇다고 마냥 아마추어 같지않아 좋았습니다. 놀란의 미덕은 준수한 상업영화를 만든다는것인데 그에 대한 오마쥬라면 "어둔밤"이라는 제목부터 좀 더 상업적으로 고민해봤으면 더 좋았겠다는 생각이 듭니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 뱀파이어 영화하면 떠오르는 명작 뱀파이어 무비
# Original Rating: POS
# Predicted Rating: POS
#
# Review 실화같아서 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시사회 봤는데 재미써요 2편 기대중ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 말이 필요없다...라이브 에이드가 모든것을 말해준 영화!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㅋㅋㅋ 1점줄라다가 설리꼭지보고 2점준다 배경과 배우로 어떻게 저런영화를만드냐... 마지막장면은 진짜 ㅋㅋㅋ 시간버릴사람들은보세요 진짜할거없어서 본건데 끝까지본 제가 신기합니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 인간이 세상에서 제일무서운 존재라는걸 알려줬다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 결말을 미리 알고 봤는데도.. 가슴이 먹먹해졌다...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 동화같은 이야기네요 어린자녀와 함께보면 더욱 좋을영화~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와... 러닝타임 내내 눈을 못 떼고 봤네요... 23살짜리 애엄마가 좀 부담스럽거 오글거리긴 하지만 ....
# Original Rating: POS
# Predicted Rating: POS
#
# Review 먼저 본 지인들이 재미있다고 해서 기대했는데 몰입감도 있고 배우들의 연기력이 대단하네요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴 만점 ;;; 귀신보다 인간이 더 무섭
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최근에 본 스릴러 영화 중에서 가장 만족스러웠던 영화. 후반부는 눈을 뗼 수 없고 몰입하게 만드는 연출이 좋았습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 답답하긴 답답했는데 그것보다 숨막히고 무서운게 더 커서 영화관가서 볼 만함
# Original Rating: POS
# Predicted Rating: POS
#
# Review 나에게도 일어날 수도 있다고 생각하니 더 무서웠어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 역시 사람이 젤 무섭다는걸 또 한번 깨달았다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 꼭 봐야할 영화~~진한 감동이 밀려오는따스한 영화~^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 난 액션영화 좋아해서 재밌게 봤는데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 알바들 평점주작에 마빡을 탁! 쳤다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 현실 반영 안된 픽션 드라마네요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 지들이 평론가야? 즐거웠음됬지
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 실망무지했다 3류 공포영화도 이거보단 재미있을듯... 배우 멋있고 예쁘기만하지 발락이아니고 발가락으로 만든 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 눈물이 나오는 걸 숨겨가면서 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 올해는 더 프레데터 랑 택시5 때문에 연속 두번 당하네/역시나 시리즈 영화는 무조건 걸러야된다는걸 뼈저리게 느낌
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 최고의 음악영화인것 같아요!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 무서웠어요 현실공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 새벽에 혼자 있을떄 그 삐삐삐삑 소리 나면 진짜 무섭지
# Original Rating: POS
# Predicted Rating: POS
#
# Review 간만에 재미있는 영화를 봤네요. 정말 재미 있습니다. 추천드립니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 신이 그의 노래를 가까이 듣고싶어서 일찍 데려갔나보다.. 보는 내내 전율이 느껴졌다.
# Original Rating: POS
# Predicted Rating: POS
#
# ...
# Predicted Rating: POS
#
# Review 1편인줄 몰랐어요..  흑 .  요즘 대세가 1편만 하는건지.. 그래도 재미는 있었어요
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 메켄지 포이, 키이라 나이틀리 다 너무 멋있고 이쁘다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와.... 현실감 느껴져서 몰입도 장난아녀요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 돈을 아끼십시오 여러분
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 퀸으로 눈뜨고 전화받고 스트리밍~퀸으로시작 퀸으로 마무리 내 삶의 변화~ 정말 위로받고 흥분하고 감동받았다그리고 감사하다 그들에게...Queen
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딸이 세번이나 보고 왔네요. 생애 최고의 영화라고.. 시디도 두개 사고.. 덩달아 저도 좋네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 기대한 나머지 실망감이 큽니다 ㅠㅠ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 초반부터 마지막까지 숨막혔다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와... 미쳤다 진짜 미쳤다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 우리 엄마도 그랬겠지?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 울때 진짜 연기 잘한다고 느꼈다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌었는데 애들이 걸린 병에 대한 설명이 나왔었나요? 전 못본거같아서요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영상미 빼곤 그저 헛웃음
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 4점은 그래픽점수. 이런 세계관 스케일에 그지같은 쓰레기내용을 집어넣다니ㅠ 개연성도 없고 억지설정으로 분량늘린느낌ㅋㅋㅋㅋ관객들 어이없어서 실소터지는 부분이 여럿있었음
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 대사 하나하나가 너무 와닿았어요.김민희님 나레이션도 너무 듣기 좋았고..날것의 모습으로 제 주변의 친구들과 제 모습을 보이는 인물들을 보며 위로받기도 다시 돌아보게도 된 영화였어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 유아인 조우진 연기력 오진다..조우진은 그냥 말이 안나올 정도로 잘함..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 연기력은 좋았으나 무서운건 어떡할거니
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이거 엔딩이 어떻게 끝난거지? 2탄을 보라는건가?ㅠㅠ 2탄 나오면 집에서 티비로 봐야겠어요ㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 볼만합니다!!??(
# Original Rating: POS
# Predicted Rating: POS
#
# Review 깜짝깜짝 놀래는 편 아닌데 정말 무섭더라고요...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여주얼굴보느라 시간가는줄 몰랐다;;
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막애 눈물이 날뻔....
# Original Rating: POS
# Predicted Rating: POS
#
# Review ㅎㅎ넘나 재밌을 것 같네요 빨리보고싳자
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감동적인데.  왜 이런 영화가 묻히는거지?  이해불가네.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미 있어요 국가 부도 이해되네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 두 아이와 즐겁게 봤어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사람들이 생각하는 것보다 강아지는 단순하다는 것, 그만큼 순수하게 사랑할 수 있다는 것
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보면 알거임 얼마나 ㅈ같은지
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 내가 오늘 완전 피곤한데 집에 가기 아쉬워서 영화나 볼까했는데 영화보면 택시타고 들어가야해서 고민하고 있었는디. 영화 줄거리 안보고 그냥 영화 포스트에 안나 역 맡은 한국여자의 포스가 너무 멋있어서 보헤미안 말고 이거 봤는데 재밌어. 안나 너무 멋짐.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음부터 끝까지 완전 존예탱 그자체ㅠㅠ 발레장면도 최고
# Original Rating: POS
# Predicted Rating: POS
#
# Review 반전때문에 두번 본영화였는데 두번봐도 재밌네요 김지수행동들도 이해가 되고ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공권력을이딴식으로표현해도되는거?ㅋㅋ그리고 ㅈㄴ답답함진짜공효진연기는봐줄만하다만모료영화풀리면봐라 어후
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 생각보다는...별로였음잔잔...반전 없는하지만 연기자들의 연기는 괜춘
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이게 걸그룹이다라는걸 느낄 수 있었다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영웅은 난세에 등장한다 했던가 어찌됐든 라이터 가진 아주머니 불질러서 나쁜 3병동놈들 싹다 태워죽인거 속시원했음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소름끼치는영화ㅜㅜㅜ 공효진 연기도 최고!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각보다볼만하네요 놀랫어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 예고편만 봤는데도 노잼이라 평점 3점 드립니다.
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 숨막히는 현실적 공포로 휩싸이다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 이인좌를 죽이기전에 김호가 말한다. ''이보시오! 그만하시오~!!!!" 내 이 영화가 끝나기전에 감독에게 말하고싶다. "이보시오~!!그만하시오~!!!!"
# Original Rating: POS
# Predicted Rating: POS
#
# Review 연기파 배우들의 만남이 더욱 시너지가 된 공포스릴러.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 딱 8점짜리 영화적당히 킬링타임용으로 괜찮습니다 너~무 무서운것은 아니지만 적당히 스릴감있고 다보고나면 재밌게 봣다 이정도 생각 드네요 1점 2점 이런 영화는 아님... 색감 배경음악 등등 괜찮던데
# Original Rating: POS
# Predicted Rating: POS
#
# Review 기대잔뜩하고 이 추운날조조 때리고 왔는데..ㅠㅠ후..님들도 봐보세용
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 전반적인 내용 구성 만족스러운데유아인은 배역에 별로 어울리지 않는 것 같습니다.몰입을 방해하는 느낌이랄까?재밌게 잘봤습니다. 전체적으로 만족합니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥저냥 소소 재밌지도 재미없지도 보는 것을 권장하다지도 않지도
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 음악도 좋고 재미있습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이상하다   평점이 왜 낮지~난개인적으로  재미있게 봤는데   색다른  영화  이면서  감동과  스토리  내용도  좋았다.최고~
# Original Rating: POS
# Predicted Rating: POS
#
# Review 차라리 성난황소를 봐라
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 실제로 몇년전에 영화와 비슷한 일을 겪은적이 있어서 보는 내내 그때 일이 생각났습니다. 가족들과 함께 사는데도 누군가 우리집에 들어오려고 한다는게 너무 무서웠는데, 혼자 사시는 여자분들은 오죽할까요. 현실적으로 공감할 수 있는 소재였어요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 멋있었던 영화!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 기대보다 재밌게 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화내리기전 한번더 보고왔어요.   두번째보면서도 보는내내 소름돋았어요.   프레디가  안쓰러워 마음아팠지만 다시한번 퀸의 명곡들에 빠져버렸어요.  정말 최고였습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보수 성향으로서  좋은평을 주고 싶지만 거짓말을 못하기에 별3개.. 어둡고 지루하고 스토리 전달이 잘 안된다 다만 한국영화로서 시도하기 어려운 특이한 소재와  중요한 메시지이기에 반점 더줌
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 아무생각없이 봤더니 볼만했음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 어릴때 다들 한번쯤은 해볼 수 있던 현대의 총같은 무기를 예전 역사시대로 들고가면 어떨까 라는 상상을 실현시켜준 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화에 똥을 묻혀놨네요
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 사랑이 우정이 이리 더럽. . .
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 아메리카국뽕에 치해버렸ㅓ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진 연기 진짜 잘함. 나 보는줄 ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 와 진짜 소름 왕소름이었어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화보는내내 답답해서 욕만나왔습니다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 이병 ㅅㅋ 싸가지까지 겁나 없네 한편으론 저러니 맞지싶다 요즘 이병들 다들 저러나..그리고 영화평은 고구마 10만개 먹은 느낌
# Original Rating: NEU
# Predicted Rating: NEG
#
# Review 범인연기개잘함목소리좋음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시원시원 하게 즐기기 딱 좋은 액션ㅋㅋ스트레스 풀리는 느낌ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이렇게 잘 만들어진 영화가 관람 극장이 너무적다는 게 문제야.개 쓰레기 한국영화보다 백번 좋은영화인데....극장수를 좀 늘려라~~`
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 보고 또 봐도 잼있다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아오 알바도 아닌 배급사 직원 새기들 ㅉㅉㅉ
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 내인생 최고의 영화이자 완벽한  영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 여성들의 연대를 다룬 묵직한 스릴러!
# Original Rating: POS
# Predicted Rating: POS
#
# Review IMF가 왜 일어났는지.. IMF가 무엇을 바꿨는지.. 쇼크 독트린을 같이 읽어보는 것도 좋을듯합니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아 미친 한국 존나 최악이다
# Original Rating: POS
# Predicted Rating: NEG
#
# Review 일상 소재로 공포를 느끼게하는...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 살짝 지루할 수도 있지만 어쨌든 잼난다. !!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 80년대 개봉했어도 흥행참패 했을것 같은 영화.  70년대면 흥행가능.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 방금 영화 보고 나왔습니다 왠만하면 개봉 첫날 예매하지 않는데 예고편 보고 소재가 기발해서 넘 기대됐었고 거기다 피터잭슨 제작이라고 해서 믿고 봤구요 전 기대치만큼 만족한 영화였어요 배우들의 연기력도 좋았고 작품을 통해 말하고자 하는 메세지도 교훈적^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 차운전 연습할때 나온노래 좋아서 기억에 남고 스토리가 아기자기함ㅋㅋㅋㅋ2편도 보고싶음ㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 킬링타임용으로 무난한 영화....잠수함영화의 패턴 그대로 쓰긴 하지만 소재가 잠수함이란거에서 반은 먹고 들어가는듯..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실적인 요소가 많아서 공포감이 더와닿긴했지만 뭔가 질질끄는 면이 있긴함 그냥 보고딱 드는생각은 자취하면 안되겠다 였음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 감독이 넣고 싶은걸 다 넣어버려서 스토리가 완전 짬뽕이 되버림...차라리 2부작 정도로 만들지...ㄹㅇ 구라 안치고 중간에 졸다가 깸ㅇㅇ cg랑 액션은 화려한데 스토리가 영...돈주고 보긴 아까움
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 스릴있고 시간가는줄 모르고 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 멤버쉽으로공짜로봣는데도아깝다ㅅㅂ팝콘하고먹을꺼만이만원치사서식사하고나옴누가팝콘떨어트렷댓냐 양손가득먹을거쥐고혹시놀라서떨어트리면어떡하나걱정햇다가영화중반부에다머것다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 솔직히 말해서 10점은 아니지 않나요?
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 디즈니는 진짜 사랑이에요!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아무생각없이 볼 수 있는 후련한 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최악..이었다....
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 소재는 참신 그래픽도 멋있음 하지만 내용이 너무 개연성이 없음..
# Original Rating: NEU
# Predicted Rating: NEU
#
# Review 가볍게 보기에 괜찮았습니다.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 프렌치 불쌍함.. 그리고 생각보다 많이 안 무서웠음
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 첨부터 쫄리는 영화는 겁나 오래만인듯ㅋㅋㅋㅋ완전 강추bbb
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화의 세계관? 각본? 짜임새 좀 허술하지만!그렇게 광고하던 피터잭슨도 감독이 아님!그치만 우리나라 배우인 지혜님의 등장부터~ 영화끝까지 그냥 와! 강한 인상이였뜸.영화 끝나고 이분만 기억에 남음!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 관객 137명. 현명한 놈들 ㅋㅋㅋ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 엄청 좋아하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 퀸의 명곡만으로도 재밌다!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 완전히 스릴넘침 숨바꼭질이랑 동급 스릴 아니 그 이상
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 오랫동안 생각날것 같음ㅠㅠ 도어락 괜히 봤나ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재미있었음 ㅇㅇ...
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무재밌어요.콘서트같음
# Original Rating: POS
# Predicted Rating: POS
#
# Review 그냥 저냥 볼만함,,,보기전에 IMF사태에 대해 공부하고 가는걸 추천
# Original Rating: POS
# Predicted Rating: POS
#
# Review 맨날먹는 똑같은 밥에 무슨 점수를 주랴
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 사십중반인  내가봐도   이작품만이  유일한  역대급  스파이더맨!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 허준호 배우님 연기 진짜 멋졌어요 과하진않지만 영화보는내내 몰입하게 만들어주심 ㅠㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 런닝맨을 모티브로 만든거라고 해서 신기했어요^^
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현빈ㄴ 응원하면서 보게 된다 ..
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 아이가 재미잇어해요 근데 마지막이너무허무햇어요 2탄을안볼수없도록...ㅎ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현실에도 있을수있는일 ㅠ 그래서 더 무서워
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재사회.. 민낯을 드러낸 공포
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘 보았습니다. 익숙한 노래들이 퀸 노래였네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 공효진의 연기 존재감은 ;; 이번영화 미쳤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 최고!최고!한번 봤는데 너무 재미있어서 스크린x  화면으로 한번 더 봤어요!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌었다고 말하기엔 그시절 견뎌주신분들께 죄송스럽고 보는내내 힘들고 안타깝고 존경스럽다고 생각들었습니다. 지금 영화 말고도 보여지는 저희 나라가 심각한수준이에요 점점 더 우리나라는 힘들어질겁니다. 준비태세 하라는 메세지같아요. 1분1초한눈팔지 못했네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 다들 연기 너무 좋은데 내용이 너무 구식임 20OOO에 이런 내용에 대사라니
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 시간가는줄 모르고 본 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌습니다 8점짜리는 되는영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 무서웠어요ㅠㅠ 스릴감 대에박
# Original Rating: POS
# Predicted Rating: POS
#
# Review 소재가 다 한 영화. 10
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 콘서트 못가보셨던 분들은 추천드려요! 저도 못가본 사람인데 충분히 간접체험 됩니다 원스라면 무조건 관람해보세요!! 살짝 아쉬웠던건 콘서트 전체가 아니라는점?
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굿 굿 굿 ㅜㅅ 굿 굿 긋굿굿굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 스릴이 느껴지는 영화.실제일어날수잇는일이라 더 소름끼치는거 같애요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막20분으로 충분하다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 현실공포.. 괜히 집 도어락 신경쓰임. 처음에 경찰 나올때 대응이 너무 현실적이라서 소름돋았다. 여주행동이 답답하게 보일수도 있지만 솔직히 그게 진짜 현실적 반응이라고 생각합다. 목숨이 걸렸는데 용기있게 행동할 수 있는 사람이 얼마나 있을까..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 범인 진짜 무섭네 ㅠㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 사랑이란 무엇인지 알고싶다면..추천합니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현빈 연기력은 만점. 손예진 연기력 꽝에 협상능력도 없는 대본. 연출력 꽝.
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 섬뜩하지만 잼있었어요. 연기들도 좋았구요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 좋은 배우들과 좋은 소재 가지고 겨우 이딴 영화를 만드냐 무슨 스토리에 개연성이라곤 하나도 없어서 몰입도 제로. 마지막에 총질도 유치하기 짝이 없고 총알 떨어지는건 무슨 백년전 수법 아직도 갖다붙히냐. 스포일 했다고 짜증내지마라. 안보는게 개이득
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 기대이상으로 너무 재밌음 ~ 굿
# Original Rating: POS
# Predicted Rating: POS
#
# Review 크리스마스 시즌 영화로는 최고!!! 매킨지 포이는 세상미모 종합판!!! 키아나 나이틀리는 메쏘드 연기신!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 잼잇겟봣습니다. 바울에 대한 그믿음 더 한층 생각하게 됍니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 팝콘라지한통다먹고 음료수도 끝까지 먹으며 버티려했음에도  졸았다. IMF라는 엄청난 역사소재를 이렇게밖에 못쓰고 이렇게 연출할 수 밖에 없었나깊이도 인물간의 개연성도 없어 다 따로 노는것같은..연기는 좋은데 감정이 스크린밖으로 전해지지않는다.
# Original Rating: NEG
# Predicted Rating: NEU
#
# Review 꺄아아아아악 오또케에에 ㅠㅜ
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 오프닝 널 내게 담아 보자마자 진짜 너무너무 심각하게 이뻐서 머리부터 발까지 소름 쫙 돋고 다음 곡으로 넘어갈때마다 소름돋고 이뻐서 소름돋고 진짜 실력도 너무 늘었고 더 좋아졌다 마지막때 울컥하다가 지효 울고 나도 울었다,,ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 배우들의 영기 줄거리 그리고 액션신 모두 완벽한 영화 다크나이트 라이즈 좋아하셨던 분들이라면 당연히 좋아하실듯 마블 영화중에 단연 최고라 생각한다!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 발레씬들 너무 멋있었어요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 재밌다 재밌어 와따야 와따
# Original Rating: POS
# Predicted Rating: POS
#
# Review 누가 뭐래도 인생영화다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 요즘 런닝맨에 푹 빠진 5세 아들.엄청 재밌었다네요.
# Original Rating: POS
# Predicted Rating: NEU
#
# Review 초반에만 참신함 ㄹㅇ 터미네이터아재 왜나온거며도시들싸움이라매.. 갑자기 비행기 위주영화가되며 인간들 약탈을 처웃으며 하다가 급 난민코스프레?선악구분없이 태세전환이 너무 급변우디르가 나뭇잎마을에서 살면 저리될듯싶다더까고싶은데 140자 ㅂㄷㅂㄷ
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 이와의 순지의 재능과 열정이 정점이었던 시기의 영화. 딱 한번만 가질 수 있는 첫 사랑의 기억과 감정을 짧은 시간 속에 잘 담아낸 수작.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 라이프에이드 공연 싱크로율 어마어마하네요
# Original Rating: POS
# Predicted Rating: POS
#
# Review 시간가는줄 모르고 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 이영화를 몇번을 봤는데도 여전히 이해가 되질 않아요ㅠㅠ과거와 현재가 공존 한다는 자체가....나두 타임슬립 하고싶다ㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 너무 재밌게 봐서 기분도 좋아요시사하는바가 큽니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 잘봤어요....혼자봤다가 넘 무서웠네요..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 완벽한 영화. 이 영화를 본 시간이 너무 행복했다. 영화란 이런 것이다 라고 알려주는 그런 느낌..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 정말 재밋게봤어용 시간가는줄 모르고 이것저것 생각하게되는 영화
# Original Rating: POS
# Predicted Rating: POS
#
# Review 생각 했던거 보다는 재밌음~~!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 진짜 여자 혼자 살면 신경쓸게 한두가지가 아님..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 긴장감 넘치는 여행속에 피어나는 유대감이 매우 훈훈하다. 원수를 갚기위한 대가가 너무 커서 안타깝다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 심장이 이렇게 두근거리긴 오랜만이다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 영화는 재밌게 잘봤습니다. 현 시대였다면 에이즈뿌리고 다닌죄로 감옥일텐데..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 마지막 공연은 좋았는데 생각보다 재미는 없었어요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 영상만예쁨 노잼 하...
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 혼자사는나에겐 이제 도어락열때마다 당분간 무서울듯해요ㅠㅠ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 줄거리는 별다른 감흥이 없었다. 다른 멤버와 머큐리와의 인간적인면 표현이 좀약했다. 러브라인이 약했고 성공하기까지의 과정이 너무 어슬펐다. 하지만 영화내내 이어지는 퀸의 노래와 마지막 라이브 에이드 공연은 이 모든 것을 상쇄하기에 족하다. 강추
# Original Rating: POS
# Predicted Rating: POS
#
# Review 보는 내내  신파조 영상과 억지 흑백논리로  마음을  무겁게 만드는 영화  .. 이영화를 보고 나오는  순간 이 영화를 보기로 한 자신의 결정을 부도 나게 하는 영화
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 올해 본 영화중 최고!!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 싱크로율 99퍼인듯..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아예 현빈을 히어로로 만들던가. 이도저도 아닌..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 공효진 김예원 김성오 현실적이 연기에 푹 빠져서 봤습니다
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재의 헬조선이 시작된 계기를 경제를 공부하면 이미 알고는 있었지맛 영화로 마주하니 분노와 슬픔이 몰려오는  영화였습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 굳이 도시를 이동식으로 만들었어야했나?
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 좋았다.. 실화를 베이스로 한 영화라 그런지.. 더 여운이 남는다..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 개오글거리는 그시절 영국에 두명의 여왕 드립에 1점주고간다
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 기대했던것 보다는 ..
# Original Rating: NEG
# Predicted Rating: POS
#
# Review 잘봤습니다현실적공포네요.
# Original Rating: NEU
# Predicted Rating: POS
#
# Review 1점테러가 너무 많아서 10점 줍니다공효진 연기 대박이고보는 내내 심장쫄리면서 봤네요재밌습니다남자들끼리 봤는데 서로 놀라면서 봤습니다ㅋㅋㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
#
# Review 아는 내용이고 예상 가능한거같으면서 너무 무섭고 진짜 오랜만에 심장 쫄깃!
# Original Rating: POS
# Predicted Rating: POS
#
# Review 비쥬얼 하나느 끝내주는 구만..
# Original Rating: POS
# Predicted Rating: POS
#
# Review 처음 리뷰글을 써보는데 이 한마디면 됩니다 진짜 존.나 무섭습니다.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 전 아주아주 재밌게 잘봤어요~~ 추천!!
# Original Rating: POS
# Predicted Rating: POS
#
# Review OOO기 발암영화  씨발  이거 쓴 작가 새끼는 생각이란걸 할줄 모르는 새끼인가?   공효진도 이딴 쓰레기 시나리오 받고  출연할 생각을 하다니 으휴  한심하다
# Original Rating: NEG
# Predicted Rating: NEG
#
# Review 정말 재미있게 봤습니다.아이디어는 최강. 스토리는.약간부진.
# Original Rating: POS
# Predicted Rating: POS
#
# Review 현재 상영 중인 영화들 거의 다 봐서 볼거 없어서 봤는데 의외로 재밌었음ㅋㅋ
# Original Rating: POS
# Predicted Rating: POS
